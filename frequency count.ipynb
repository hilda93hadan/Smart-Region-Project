# %% [markdown]
# ##### Reference:
# 1. Python PDF to Text: https://medium.com/@rqaiserr/how-to-convert-pdfs-into-searchable-key-words-with-python-85aab86c544f
# 2. clean text file: https://machinelearningmastery.com/clean-text-machine-learning-python/
# 3. count word frequency:https://programminghistorian.org/en/lessons/counting-frequencies
# 4. separate nouns, adjective, verbs, etc. using pos_tag in python:https://www.nltk.org/book/ch05.html
# 5. meaning of pos_tagged words: https://medium.com/@gianpaul.r/tokenization-and-parts-of-speech-pos-tagging-in-pythons-nltk-library-2d30f70af13b

# %% [markdown]
# #### The following code is grouped by four sections
# Section 1: Import packages
# <br/>Section 2: option 1 - Convert PDF to Text / option 2 - Read in Text file
# <br/>Section 3: Pre-process the Text File
# <br/>Section 4: Count Uni-gram Frequency
# <br/>Section 5: Separate the part of speech (with stemming the content)
# <br/>Section 6: Count Bi-gram Frequency
# <br/>Section 7: Count 3-gram Frequency
# <br/>Section 8: print everthing into Excel tab

# %% [markdown]
# ### Section 1. import packages

# %%
import pandas as pd
import numpy as np
import nltk
import glob
import errno
import os.path
import string
import re
import PyPDF2
from collections import Counter
from openpyxl import load_workbook
import xlsxwriter
from xlsxwriter import Workbook
from nltk.tokenize import word_tokenize
from itertools import tee, islice
from nltk.corpus import stopwords
from nltk.util import ngrams
from nltk.stem.porter import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hilda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hilda\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hilda\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ### Section 2: read the coverted text file

# %%
filename = 'C:\\Users\\hilda\\OneDrive\\文档\\Indiana University Bloomington\\Research Topic - Smart City Initiatives\\Frequency counts\\Bloomingtontexts\\AllinOneBloomington.txt'
file = open(filename, 'r', encoding = 'utf-8')
text = file.read()

# %% [markdown]
# ### Section 3: clean the text. only keep alphabet characters and make them lowercase

# %% [markdown]
# ##### 1) make lowercase, remove words less than 4 characters, remove punctuations

# %%
clean_text = text.replace('\n',' ').lower()   #replace \n with space, make all characters lowercase
clean_text = re.sub(r'\d+', '', clean_text) 
clean_text = re.sub(r'\b\w{1,3}\b', '', clean_text) #remove words with less than 4 characters
clean_text = clean_text.translate(str.maketrans('', '', string.punctuation+'Œœ˚˜`™˘˝˛˙—\\’“”…©––↣↢·→↡⁰•▪●'))   #remove punctuation
clean_text
# Out:
# '  bloomington joins  green building council leed  cities  communities program  city  bloomington indiana  city  bloomington indiana mayor john hamilton  feedback  type here  news release        bloomington joins  green building council leed  cities  communities program share    morton street suite  bloomington     connect  facebook       more information please contact alex crowley director economic  sustainable development department crowleyabloomington    bloomington joins  green building council leed  cities  communities program bloomington   today  city  bloomington announces  participation    green building council usgbc leed  cities  communities grant program   process  becoming  leedcertiﬁed city bloomington will receive ﬁnancial assistance educational resources  technical support  increase  enhance practices that support  sustainable healthy  equitable   life  usgbc leed program will also support  city existing efforts  track  verify performance   wide variety  sustainability indicators including energy water transportation education health  more bloomington demonstrates  commitment  sustainability  multiple fronts  from  efforts  increase renewable energy generation expand  trail infrastructure maintain  safe water supply  other environmental initiatives  furthering equity  economic development said bloomington mayor john httpsbloomingtonnews    \x0c  bloomington joins  green building council leed  cities  communities program  city  bloomington indiana  hamilton achieving leed certiﬁcation will provide  nationally recognized framework   practices  promote  identity   sustainability leader having developed  leed green building certiﬁcation system    usgbc expanded  purview beyond individual buildings  launching  leed  cities  communities grant program   designed  encourage  development  smart cities  resilient communities  program launched with  participating  cities with support from  bank  america charitable foundation  program  expanded   more cities  communities including bloomington according   announcement released   usgbc today applications from cities seeking leed certiﬁcation were evaluated  demonstrated need leadership support commitment  datadriven decisionmaking staff capacity  coordination with other local initiatives  city sustainability action plan  established practices  tracking  sharing data were considered assets   application representatives from  participating cities will attend   person orientation  usgbc headquarters  washington   early june  usgbc staff will walk   communities through  rating system  evaluation measures  lead them through  number  hands exercises  calculate scores  develop  action plan   year after  training cities  communities will start  align their existing programs  plans with  leed rating system using project management tools  resources provided  usgbc then they will gather data   evaluation measures  their choice from  rating system  enter data into reporting tools  cohort  local governments will meet regularly throughout  year  report progress  share best practices learn more about  usgbc leed  cities  communities programs   httpsbloomingtonnews    \x0c  bloomington joins  green building council leed  cities  communities program  city  bloomington indiana  related categories department economic  sustainable development    morton  bloomington    connect  facebook follow   twitter city jobs subscribe  email lists  policy report  problem city intranet home login  httpsbloomingtonnews    \x0c  city  bloomington utilities moving forward  smart meter installation  city  bloomington indiana  city  bloomington indiana mayor john hamilton  feedback  type here  news release    january    city  bloomington utilities moving forward  smart meter installation share    miller  bloomington      january     more information please contact  kelson director  city  bloomington utilities kelsonvbloomington   city  bloomington utilities moving forward  smart meter installation bloomington     ...

# %% [markdown]
# ###### 2) Tokenize

# %%
#break text string into individual words using word_tokenize() function
tokens = word_tokenize(clean_text)
tokens
# Out:
# ['bloomington',
#  'joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'city',
#  'bloomington',
#  'indiana',
#  'city',
#  'bloomington',
#  'indiana',
#  'mayor',
#  'john',
#  'hamilton',
#  'feedback',
#  'type',
#  'here',
#  'news',
#  'release',
#  'bloomington',
#  'joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'share',
#  'morton',
#  'street',
#  'suite',
#  'bloomington',
#  'connect',
#  'facebook',
#  'more',
#  'information',
#  'please',
#  'contact',
#  'alex',
#  'crowley',
#  'director',
#  'economic',
#  'sustainable',
#  'development',
#  'department',
#  'crowleyabloomington',
#  'bloomington',
#  'joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'bloomington',
#  'today',
#  'city',
#  'bloomington',
#  'announces',
#  'participation',
#  'green',
#  'building',
#  'council',
#  'usgbc',
#  'leed',
#  'cities',
#  'communities',
#  'grant',
#  'program',
#  'process',
#  'becoming',
#  'leedcertiﬁed',
#  'city',
#  'bloomington',
#  'will',
#  'receive',
#  'ﬁnancial',
#  'assistance',
#  'educational',
#  'resources',
#  'technical',
#  'support',
#  'increase',
#  'enhance',
#  'practices',
#  'that',
#  'support',
#  'sustainable',
#  'healthy',
#  'equitable',
#  'life',
#  'usgbc',
#  'leed',
#  'program',
#  'will',
#  'also',
#  'support',
#  'city',
#  'existing',
#  'efforts',
#  'track',
#  'verify',
#  'performance',
#  'wide',
#  'variety',
#  'sustainability',
#  'indicators',
#  'including',
#  'energy',
#  'water',
#  'transportation',
#  'education',
#  'health',
#  'more',
#  'bloomington',
#  'demonstrates',
#  'commitment',
#  'sustainability',
#  'multiple',
#  'fronts',
#  'from',
#  'efforts',
#  'increase',
#  'renewable',
#  'energy',
#  'generation',
#  'expand',
#  'trail',
#  'infrastructure',
#  'maintain',
#  'safe',
#  'water',
#  'supply',
#  'other',
#  'environmental',
#  'initiatives',
#  'furthering',
#  'equity',
#  'economic',
#  'development',
#  'said',
#  'bloomington',
#  'mayor',
#  'john',
#  'httpsbloomingtonnews',
#  'bloomington',
#  'joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'city',
#  'bloomington',
#  'indiana',
#  'hamilton',
#  'achieving',
#  'leed',
#  'certiﬁcation',
#  'will',
#  'provide',
#  'nationally',
#  'recognized',
#  'framework',
#  'practices',
#  'promote',
#  'identity',
#  'sustainability',
#  'leader',
#  'having',
#  'developed',
#  'leed',
#  'green',
#  'building',
#  'certiﬁcation',
#  'system',
#  'usgbc',
#  'expanded',
#  'purview',
#  'beyond',
#  'individual',
#  'buildings',
#  'launching',
#  'leed',
#  'cities',
#  'communities',
#  'grant',
#  'program',
#  'designed',
#  'encourage',
#  'development',
#  'smart',
#  'cities',
#  'resilient',
#  'communities',
#  'program',
#  'launched',
#  'with',
#  'participating',
#  'cities',
#  'with',
#  'support',
#  'from',
#  'bank',
#  'america',
#  'charitable',
#  'foundation',
#  'program',
#  'expanded',
#  'more',
#  'cities',
#  'communities',
#  'including',
#  'bloomington',
#  'according',
#  'announcement',
#  'released',
#  'usgbc',
#  'today',
#  'applications',
#  'from',
#  'cities',
#  'seeking',
#  'leed',
#  'certiﬁcation',
#  'were',
#  'evaluated',
#  'demonstrated',
#  'need',
#  'leadership',
#  'support',
#  'commitment',
#  'datadriven',
#  'decisionmaking',
#  'staff',
#  'capacity',
#  'coordination',
#  'with',
#  'other',
#  'local',
#  'initiatives',
#  'city',
#  'sustainability',
#  'action',
#  'plan',
#  'established',
#  'practices',
#  'tracking',
#  'sharing',
#  'data',
#  'were',
#  'considered',
#  'assets',
#  'application',
#  'representatives',
#  'from',
#  'participating',
#  'cities',
#  'will',
#  'attend',
#  'person',
#  'orientation',
#  'usgbc',
#  'headquarters',
#  'washington',
#  'early',
#  'june',
#  'usgbc',
#  'staff',
#  'will',
#  'walk',
#  'communities',
#  'through',
#  'rating',
#  'system',
#  'evaluation',
#  'measures',
#  'lead',
#  'them',
#  'through',
#  'number',
#  'hands',
#  'exercises',
#  'calculate',
#  'scores',
#  'develop',
#  'action',
#  'plan',
#  'year',
#  'after',
#  'training',
#  'cities',
#  'communities',
#  'will',
#  'start',
#  'align',
#  'their',
#  'existing',
#  'programs',
#  'plans',
#  'with',
#  'leed',
#  'rating',
#  'system',
#  'using',
#  'project',
#  'management',
#  'tools',
#  'resources',
#  'provided',
#  'usgbc',
#  'then',
#  'they',
#  'will',
#  'gather',
#  'data',
#  'evaluation',
#  'measures',
#  'their',
#  'choice',
#  'from',
#  'rating',
#  'system',
#  'enter',
#  'data',
#  'into',
#  'reporting',
#  'tools',
#  'cohort',
#  'local',
#  'governments',
#  'will',
#  'meet',
#  'regularly',
#  'throughout',
#  'year',
#  'report',
#  'progress',
#  'share',
#  'best',
#  'practices',
#  'learn',
#  'more',
#  'about',
#  'usgbc',
#  'leed',
#  'cities',
#  'communities',
#  'programs',
#  'httpsbloomingtonnews',
#  'bloomington',
#  'joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'city',
#  'bloomington',
#  'indiana',
#  'related',
#  'categories',
#  'department',
#  'economic',
#  'sustainable',
#  'development',
#  'morton',
#  'bloomington',
#  'connect',
#  'facebook',
#  'follow',
#  'twitter',
#  'city',
#  'jobs',
#  'subscribe',
#  'email',
#  'lists',
#  'policy',
#  'report',
#  'problem',
#  'city',
#  'intranet',
#  'home',
#  'login',
#  'httpsbloomingtonnews',
#  'city',
#  'bloomington',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'city',
#  'bloomington',
#  'indiana',
#  'city',
#  'bloomington',
#  'indiana',
#  'mayor',
#  'john',
#  'hamilton',
#  'feedback',
#  'type',
#  'here',
#  'news',
#  'release',
#  'january',
#  'city',
#  'bloomington',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'share',
#  'miller',
#  'bloomington',
#  'january',
#  'more',
#  'information',
#  'please',
#  'contact',
#  'kelson',
#  'director',
#  'city',
#  'bloomington',
#  'utilities',
#  'kelsonvbloomington',
#  'city',
#  'bloomington',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'bloomington',
#  'their',
#  'meeting',
#  'this',
#  'evening',
#  'utilities',
#  'service',
#  'board',
#  'scheduled',
#  'consider',
#  'million',
#  'agreement',
#  'with',
#  'utility',
#  'metering',
#  'solutions',
#  'oversee',
#  'transition',
#  'bloomington',
#  'water',
#  'meters',
#  'advanced',
#  'metering',
#  'infrastructure',
#  'approved',
#  'contractor',
#  'will',
#  'agent',
#  'city',
#  'bloomington',
#  'utilities',
#  'install',
#  'meters',
#  'software',
#  'conduct',
#  'community',
#  'outreach',
#  'other',
#  'measures',
#  'ensuring',
#  'smooth',
#  'conversion',
#  'installation',
#  'anticipated',
#  'complete',
#  'march',
#  'december',
#  'city',
#  'council',
#  'approved',
#  'leasepurchase',
#  'agreement',
#  'fund',
#  'implementation',
#  'system',
#  'serving',
#  'customers',
#  'integrated',
#  'system',
#  'smart',
#  'meters',
#  'communications',
#  'networks',
#  'data',
#  'management',
#  'systems',
#  'enables',
#  'communication',
#  'between',
#  'utilities',
#  'customers',
#  'system',
#  'provides',
#  'number',
#  'important',
#  'functions',
#  'that',
#  'were',
#  'previously',
#  'possible',
#  'performed',
#  'manually',
#  'including',
#  'demand',
#  'reading',
#  'ability',
#  'measure',
#  'water',
#  'usage',
#  'automatically',
#  'remotely',
#  'connect',
#  'disconnect',
#  'service',
#  'detect',
#  'tampering',
#  'identify',
#  'isolate',
#  'pressure',
#  'issues',
#  'potential',
#  'leaks',
#  'both',
#  'utility',
#  'customer',
#  'will',
#  'have',
#  'access',
#  'more',
#  'detailed',
#  'water',
#  'usage',
#  'information',
#  'with',
#  'meters',
#  'httpsbloomingtonnews',
#  'city',
#  'bloomington',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'city',
#  'bloomington',
#  'indiana',
#  'water',
#  'metering',
#  'ﬁrst',
#  'application',
#  'system',
#  'will',
#  'serve',
#  'base',
#  'stations',
#  'also',
#  'serve',
#  'high',
#  'security',
#  'radio',
#  'communications',
#  'network',
#  'other',
#  'smart',
#  'city',
#  'applications',
#  'addition',
#  'water',
#  'meters',
#  'network',
#  'communicate',
#  'with',
#  'other',
#  'smart',
#  'devices',
#  'across',
#  'city',
#  'supporting',
#  'future',
#  'applications',
#  'that',
#  'coordinate',
#  'streamline',
#  'delivery',
#  'city',
#  'services',
#  'these',
#  'applications',
#  'reduce',
#  'environmental',
#  'impacts',
#  'improve',
#  'data',
#  'quality',
#  'overall',
#  'cost',
#  'project',
#  'including',
#  'contingencies',
#  'estimated',
#  'million',
#  'immediate',
#  'beneﬁts',
#  'this',
#  'modernized',
#  'metering',
#  'system',
#  'will',
#  'heighten',
#  'efﬁciency',
#  'with',
#  'which',
#  'able',
#  'respond',
#  'infrastructure',
#  'issues',
#  'empower',
#  'customers',
#  'make',
#  'more',
#  'informed',
#  'decisions',
#  'managing',
#  'water',
#  'consumption',
#  'said',
#  'mayor',
#  'john',
#  'hamilton',
#  'beyond',
#  'application',
#  'water',
#  'metering',
#  'innovative',
#  'network',
#  'like',
#  'offers',
#  'reaching',
#  'potential',
#  'create',
#  'efﬁciencies',
#  'costs',
#  'conserve',
#  'natural',
#  'resources',
#  'meets',
#  'every',
#  'other',
#  'monday',
#  'except',
#  'city',
#  'holidays',
#  'utilities',
#  'service',
#  'center',
#  'bloomington',
#  'miller',
#  'drive',
#  'everyone',
#  'welcome',
#  'time',
#  'reserved',
#  'each',
#  'meeting',
#  'public',
#  'comment',
#  'more',
#  'information',
#  'found',
#  'website',
#  'bloomingtonutilities',
#  'their',
#  'facebook',
#  'page',
#  'city',
#  'bloomington',
#  'utilities',
#  'pictured',
#  'water',
#  'meters',
#  'iperl',
#  'httpsbloomingtonnews',
#  'city',
#  'bloomington',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'city',
#  'bloomington',
#  'indiana',
#  'related',
#  'categories',
#  'department',
#  'utilities',
#  'department',
#  'morton',
#  'bloomington',
#  'connect',
#  'facebook',
#  'follow',
#  'twitter',
#  'city',
#  'jobs',
#  'subscribe',
#  'email',
#  'lists',
#  'policy',
#  'report',
#  'problem',
#  'city',
#  'intranet',
#  'home',
#  'login',
#  'httpsbloomingtonnews',
#  'indiana',
#  'city',
#  'controversial',
#  'online',
#  'overdose',
#  'modified',
#  'following',
#  'numerous',
#  'complaints',
#  'american',
#  'city',
#  'county',
#  'smart',
#  'cities',
#  'technology',
#  'httpsamericancityandcountytypesmartcities',
#  'technology',
#  'article',
#  'indiana',
#  'city',
#  'controversial',
#  'online',
#  'overdose',
#  'modi',
#  'following',
#  'numerous',
#  'complaints',
#  'sharing',
#  'information',
#  'with',
#  'public',
#  'important',
#  'function',
#  'government',
#  'sometimes',
#  'that',
#  'information',
#  'personal',
#  'share',
#  'such',
#  'case',
#  'when',
#  'bloomington',
#  'ofﬁcials',
#  'began',
#  'tracking',
#  'opioid',
#  'overdose',
#  'deaths',
#  'online',
#  'through',
#  'that',
#  'pinpoints',
#  'addresses',
#  'overdose',
#  'victims',
#  'within',
#  'city',
#  'limits',
#  'written',
#  'jason',
#  'axelrod',
#  'httpsamericancityandcountyauthorjasonaxelrod',
#  'july',
#  'sharing',
#  'information',
#  'with',
#  'public',
#  'important',
#  'function',
#  'government',
#  'sometimes',
#  'that',
#  'information',
#  'personal',
#  'share',
#  'httpsamericancityandcountyindianacityscontroversialonlineoverdosemodifiedfollowingnumerouscomplaints',
#  'such',
#  'controversial',
#  'online',
#  'overdose',
#  'modified',
#  'numerous',
#  'complaints',
#  'american',
#  'city',
#  'county',
#  'caseindiana',
#  'whencity',
#  'bloomington',
#  'ofﬁcials',
#  'beganfollowing',
#  'tracking',
#  'opioid',
#  'overdose',
#  'deaths',
#  'online',
#  'through',
#  'that',
#  'pinpoints',
#  'addresses',
#  'overdose',
#  'victims',
#  'within',
#  'city',
#  'limits',
#  'according',
#  'indiana',
#  'public',
#  'media',
#  'after',
#  'criticism',
#  'mounted',
#  'from',
#  'people',
#  'across',
#  'bloomington',
#  'monroe',
#  'county',
#  'city',
#  'ofﬁcials',
#  'altered',
#  'july',
#  'display',
#  'street',
#  'addresses',
#  'instead',
#  'only',
#  'show',
#  'overdose',
#  'locations',
#  'residences',
#  'businesses',
#  'public',
#  'property',
#  'indiana',
#  'radio',
#  'station',
#  'wbiw',
#  'reports',
#  'launched',
#  'march',
#  'part',
#  'bloomington',
#  'revealed',
#  'public',
#  'information',
#  'transparency',
#  'site',
#  'that',
#  'mayor',
#  'ofﬁce',
#  'innovation',
#  'created',
#  'according',
#  'wbiw',
#  'best',
#  'recipe',
#  'success',
#  'terms',
#  'addressing',
#  'problem',
#  'making',
#  'data',
#  'more',
#  'accessible',
#  'bloomington',
#  'communications',
#  'director',
#  'yael',
#  'ksander',
#  'told',
#  'indianapolis',
#  'station',
#  'wthr',
#  'residents',
#  'ofﬁcials',
#  'alike',
#  'have',
#  'reacted',
#  'negatively',
#  'bloomington',
#  'heather',
#  'harlow',
#  'uncle',
#  'john',
#  'harlow',
#  'passed',
#  'away',
#  'from',
#  'drug',
#  'overdose',
#  'three',
#  'years',
#  'harlow',
#  'grandparents',
#  'home',
#  'harlow',
#  'voiced',
#  'concerns',
#  'that',
#  'viewers',
#  'could',
#  'grandparents',
#  'house',
#  'listed',
#  'wthr',
#  'reports',
#  'there',
#  'more',
#  'constructive',
#  'ways',
#  'display',
#  'this',
#  'information',
#  'than',
#  'pinpointing',
#  'people',
#  'individual',
#  'homes',
#  'told',
#  'wthr',
#  'adding',
#  'that',
#  'ensuring',
#  'people',
#  'safety',
#  'greater',
#  'issue',
#  'than',
#  'hiding',
#  'statistics',
#  'monroe',
#  'county',
#  'commissioner',
#  'amanda',
#  'clerking',
#  'barge',
#  'took',
#  'facebook',
#  'vent',
#  'frustrations',
#  'with',
#  'criticized',
#  'ofﬁcials',
#  'justiﬁcation',
#  'using',
#  'government',
#  'resources',
#  'post',
#  'private',
#  'health',
#  'information',
#  'also',
#  ...]

# %% [markdown]
# ###### 2) remove punctuations, stop words, and city and state names

# %%
#create a list of punctuations which we wish to eliminate
punctuations = ['(',')',';',':','[',']',',','-','Œ','*','$','%','/','.','&','œ','˚','~','!','@','#','˛','•','','\x0c','\ue603','\uf0e0','\uf09a','\uf099','\uf0e1','\uf098','\uf104','\uf106','\t\t','\uf0b7']
#create a list of stopwords such as "the", "a", "and", etc.
stop_words = stopwords.words('english')
#create a list of city and state names (lowercase we wish to remove
city_names = ['bloomington','bloomingtons','in','indiana','indianas']

# %%
#remove stopwords and punctunations from keywords
keywords = [word for word in tokens if not word in stop_words and not word in punctuations and not word in city_names and not word.startswith("https") and not word.startswith("http") and not len(word)>20]
keywords
# Out:
# ['joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'city',
#  'city',
#  'mayor',
#  'john',
#  'hamilton',
#  'feedback',
#  'type',
#  'news',
#  'release',
#  'joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'share',
#  'morton',
#  'street',
#  'suite',
#  'connect',
#  'facebook',
#  'information',
#  'please',
#  'contact',
#  'alex',
#  'crowley',
#  'director',
#  'economic',
#  'sustainable',
#  'development',
#  'department',
#  'crowleyabloomington',
#  'joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'today',
#  'city',
#  'announces',
#  'participation',
#  'green',
#  'building',
#  'council',
#  'usgbc',
#  'leed',
#  'cities',
#  'communities',
#  'grant',
#  'program',
#  'process',
#  'becoming',
#  'leedcertiﬁed',
#  'city',
#  'receive',
#  'ﬁnancial',
#  'assistance',
#  'educational',
#  'resources',
#  'technical',
#  'support',
#  'increase',
#  'enhance',
#  'practices',
#  'support',
#  'sustainable',
#  'healthy',
#  'equitable',
#  'life',
#  'usgbc',
#  'leed',
#  'program',
#  'also',
#  'support',
#  'city',
#  'existing',
#  'efforts',
#  'track',
#  'verify',
#  'performance',
#  'wide',
#  'variety',
#  'sustainability',
#  'indicators',
#  'including',
#  'energy',
#  'water',
#  'transportation',
#  'education',
#  'health',
#  'demonstrates',
#  'commitment',
#  'sustainability',
#  'multiple',
#  'fronts',
#  'efforts',
#  'increase',
#  'renewable',
#  'energy',
#  'generation',
#  'expand',
#  'trail',
#  'infrastructure',
#  'maintain',
#  'safe',
#  'water',
#  'supply',
#  'environmental',
#  'initiatives',
#  'furthering',
#  'equity',
#  'economic',
#  'development',
#  'said',
#  'mayor',
#  'john',
#  'joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'city',
#  'hamilton',
#  'achieving',
#  'leed',
#  'certiﬁcation',
#  'provide',
#  'nationally',
#  'recognized',
#  'framework',
#  'practices',
#  'promote',
#  'identity',
#  'sustainability',
#  'leader',
#  'developed',
#  'leed',
#  'green',
#  'building',
#  'certiﬁcation',
#  'system',
#  'usgbc',
#  'expanded',
#  'purview',
#  'beyond',
#  'individual',
#  'buildings',
#  'launching',
#  'leed',
#  'cities',
#  'communities',
#  'grant',
#  'program',
#  'designed',
#  'encourage',
#  'development',
#  'smart',
#  'cities',
#  'resilient',
#  'communities',
#  'program',
#  'launched',
#  'participating',
#  'cities',
#  'support',
#  'bank',
#  'america',
#  'charitable',
#  'foundation',
#  'program',
#  'expanded',
#  'cities',
#  'communities',
#  'including',
#  'according',
#  'announcement',
#  'released',
#  'usgbc',
#  'today',
#  'applications',
#  'cities',
#  'seeking',
#  'leed',
#  'certiﬁcation',
#  'evaluated',
#  'demonstrated',
#  'need',
#  'leadership',
#  'support',
#  'commitment',
#  'datadriven',
#  'decisionmaking',
#  'staff',
#  'capacity',
#  'coordination',
#  'local',
#  'initiatives',
#  'city',
#  'sustainability',
#  'action',
#  'plan',
#  'established',
#  'practices',
#  'tracking',
#  'sharing',
#  'data',
#  'considered',
#  'assets',
#  'application',
#  'representatives',
#  'participating',
#  'cities',
#  'attend',
#  'person',
#  'orientation',
#  'usgbc',
#  'headquarters',
#  'washington',
#  'early',
#  'june',
#  'usgbc',
#  'staff',
#  'walk',
#  'communities',
#  'rating',
#  'system',
#  'evaluation',
#  'measures',
#  'lead',
#  'number',
#  'hands',
#  'exercises',
#  'calculate',
#  'scores',
#  'develop',
#  'action',
#  'plan',
#  'year',
#  'training',
#  'cities',
#  'communities',
#  'start',
#  'align',
#  'existing',
#  'programs',
#  'plans',
#  'leed',
#  'rating',
#  'system',
#  'using',
#  'project',
#  'management',
#  'tools',
#  'resources',
#  'provided',
#  'usgbc',
#  'gather',
#  'data',
#  'evaluation',
#  'measures',
#  'choice',
#  'rating',
#  'system',
#  'enter',
#  'data',
#  'reporting',
#  'tools',
#  'cohort',
#  'local',
#  'governments',
#  'meet',
#  'regularly',
#  'throughout',
#  'year',
#  'report',
#  'progress',
#  'share',
#  'best',
#  'practices',
#  'learn',
#  'usgbc',
#  'leed',
#  'cities',
#  'communities',
#  'programs',
#  'joins',
#  'green',
#  'building',
#  'council',
#  'leed',
#  'cities',
#  'communities',
#  'program',
#  'city',
#  'related',
#  'categories',
#  'department',
#  'economic',
#  'sustainable',
#  'development',
#  'morton',
#  'connect',
#  'facebook',
#  'follow',
#  'twitter',
#  'city',
#  'jobs',
#  'subscribe',
#  'email',
#  'lists',
#  'policy',
#  'report',
#  'problem',
#  'city',
#  'intranet',
#  'home',
#  'login',
#  'city',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'city',
#  'city',
#  'mayor',
#  'john',
#  'hamilton',
#  'feedback',
#  'type',
#  'news',
#  'release',
#  'january',
#  'city',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'share',
#  'miller',
#  'january',
#  'information',
#  'please',
#  'contact',
#  'kelson',
#  'director',
#  'city',
#  'utilities',
#  'kelsonvbloomington',
#  'city',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'meeting',
#  'evening',
#  'utilities',
#  'service',
#  'board',
#  'scheduled',
#  'consider',
#  'million',
#  'agreement',
#  'utility',
#  'metering',
#  'solutions',
#  'oversee',
#  'transition',
#  'water',
#  'meters',
#  'advanced',
#  'metering',
#  'infrastructure',
#  'approved',
#  'contractor',
#  'agent',
#  'city',
#  'utilities',
#  'install',
#  'meters',
#  'software',
#  'conduct',
#  'community',
#  'outreach',
#  'measures',
#  'ensuring',
#  'smooth',
#  'conversion',
#  'installation',
#  'anticipated',
#  'complete',
#  'march',
#  'december',
#  'city',
#  'council',
#  'approved',
#  'leasepurchase',
#  'agreement',
#  'fund',
#  'implementation',
#  'system',
#  'serving',
#  'customers',
#  'integrated',
#  'system',
#  'smart',
#  'meters',
#  'communications',
#  'networks',
#  'data',
#  'management',
#  'systems',
#  'enables',
#  'communication',
#  'utilities',
#  'customers',
#  'system',
#  'provides',
#  'number',
#  'important',
#  'functions',
#  'previously',
#  'possible',
#  'performed',
#  'manually',
#  'including',
#  'demand',
#  'reading',
#  'ability',
#  'measure',
#  'water',
#  'usage',
#  'automatically',
#  'remotely',
#  'connect',
#  'disconnect',
#  'service',
#  'detect',
#  'tampering',
#  'identify',
#  'isolate',
#  'pressure',
#  'issues',
#  'potential',
#  'leaks',
#  'utility',
#  'customer',
#  'access',
#  'detailed',
#  'water',
#  'usage',
#  'information',
#  'meters',
#  'city',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'city',
#  'water',
#  'metering',
#  'ﬁrst',
#  'application',
#  'system',
#  'serve',
#  'base',
#  'stations',
#  'also',
#  'serve',
#  'high',
#  'security',
#  'radio',
#  'communications',
#  'network',
#  'smart',
#  'city',
#  'applications',
#  'addition',
#  'water',
#  'meters',
#  'network',
#  'communicate',
#  'smart',
#  'devices',
#  'across',
#  'city',
#  'supporting',
#  'future',
#  'applications',
#  'coordinate',
#  'streamline',
#  'delivery',
#  'city',
#  'services',
#  'applications',
#  'reduce',
#  'environmental',
#  'impacts',
#  'improve',
#  'data',
#  'quality',
#  'overall',
#  'cost',
#  'project',
#  'including',
#  'contingencies',
#  'estimated',
#  'million',
#  'immediate',
#  'beneﬁts',
#  'modernized',
#  'metering',
#  'system',
#  'heighten',
#  'efﬁciency',
#  'able',
#  'respond',
#  'infrastructure',
#  'issues',
#  'empower',
#  'customers',
#  'make',
#  'informed',
#  'decisions',
#  'managing',
#  'water',
#  'consumption',
#  'said',
#  'mayor',
#  'john',
#  'hamilton',
#  'beyond',
#  'application',
#  'water',
#  'metering',
#  'innovative',
#  'network',
#  'like',
#  'offers',
#  'reaching',
#  'potential',
#  'create',
#  'efﬁciencies',
#  'costs',
#  'conserve',
#  'natural',
#  'resources',
#  'meets',
#  'every',
#  'monday',
#  'except',
#  'city',
#  'holidays',
#  'utilities',
#  'service',
#  'center',
#  'miller',
#  'drive',
#  'everyone',
#  'welcome',
#  'time',
#  'reserved',
#  'meeting',
#  'public',
#  'comment',
#  'information',
#  'found',
#  'website',
#  'bloomingtonutilities',
#  'facebook',
#  'page',
#  'city',
#  'utilities',
#  'pictured',
#  'water',
#  'meters',
#  'iperl',
#  'city',
#  'utilities',
#  'moving',
#  'forward',
#  'smart',
#  'meter',
#  'installation',
#  'city',
#  'related',
#  'categories',
#  'department',
#  'utilities',
#  'department',
#  'morton',
#  'connect',
#  'facebook',
#  'follow',
#  'twitter',
#  'city',
#  'jobs',
#  'subscribe',
#  'email',
#  'lists',
#  'policy',
#  'report',
#  'problem',
#  'city',
#  'intranet',
#  'home',
#  'login',
#  'city',
#  'controversial',
#  'online',
#  'overdose',
#  'modified',
#  'following',
#  'numerous',
#  'complaints',
#  'american',
#  'city',
#  'county',
#  'smart',
#  'cities',
#  'technology',
#  'technology',
#  'article',
#  'city',
#  'controversial',
#  'online',
#  'overdose',
#  'modi',
#  'following',
#  'numerous',
#  'complaints',
#  'sharing',
#  'information',
#  'public',
#  'important',
#  'function',
#  'government',
#  'sometimes',
#  'information',
#  'personal',
#  'share',
#  'case',
#  'ofﬁcials',
#  'began',
#  'tracking',
#  'opioid',
#  'overdose',
#  'deaths',
#  'online',
#  'pinpoints',
#  'addresses',
#  'overdose',
#  'victims',
#  'within',
#  'city',
#  'limits',
#  'written',
#  'jason',
#  'axelrod',
#  'july',
#  'sharing',
#  'information',
#  'public',
#  'important',
#  'function',
#  'government',
#  'sometimes',
#  'information',
#  'personal',
#  'share',
#  'controversial',
#  'online',
#  'overdose',
#  'modified',
#  'numerous',
#  'complaints',
#  'american',
#  'city',
#  'county',
#  'caseindiana',
#  'whencity',
#  'ofﬁcials',
#  'beganfollowing',
#  'tracking',
#  'opioid',
#  'overdose',
#  'deaths',
#  'online',
#  'pinpoints',
#  'addresses',
#  'overdose',
#  'victims',
#  'within',
#  'city',
#  'limits',
#  'according',
#  'public',
#  'media',
#  'criticism',
#  'mounted',
#  'people',
#  'across',
#  'monroe',
#  'county',
#  'city',
#  'ofﬁcials',
#  'altered',
#  'july',
#  'display',
#  'street',
#  'addresses',
#  'instead',
#  'show',
#  'overdose',
#  'locations',
#  'residences',
#  'businesses',
#  'public',
#  'property',
#  'radio',
#  'station',
#  'wbiw',
#  'reports',
#  'launched',
#  'march',
#  'part',
#  'revealed',
#  'public',
#  'information',
#  'transparency',
#  'site',
#  'mayor',
#  'ofﬁce',
#  'innovation',
#  'created',
#  'according',
#  'wbiw',
#  'best',
#  'recipe',
#  'success',
#  'terms',
#  'addressing',
#  'problem',
#  'making',
#  'data',
#  'accessible',
#  'communications',
#  'director',
#  'yael',
#  'ksander',
#  'told',
#  'indianapolis',
#  'station',
#  'wthr',
#  'residents',
#  'ofﬁcials',
#  'alike',
#  'reacted',
#  'negatively',
#  'heather',
#  'harlow',
#  'uncle',
#  'john',
#  'harlow',
#  'passed',
#  'away',
#  'drug',
#  'overdose',
#  'three',
#  'years',
#  'harlow',
#  'grandparents',
#  'home',
#  'harlow',
#  'voiced',
#  'concerns',
#  'viewers',
#  'could',
#  'grandparents',
#  'house',
#  'listed',
#  'wthr',
#  'reports',
#  'constructive',
#  'ways',
#  'display',
#  'information',
#  'pinpointing',
#  'people',
#  'individual',
#  'homes',
#  'told',
#  'wthr',
#  'adding',
#  'ensuring',
#  'people',
#  'safety',
#  'greater',
#  'issue',
#  'hiding',
#  'statistics',
#  'monroe',
#  'county',
#  'commissioner',
#  'amanda',
#  'clerking',
#  'barge',
#  'took',
#  'facebook',
#  'vent',
#  'frustrations',
#  'criticized',
#  'ofﬁcials',
#  'justiﬁcation',
#  'using',
#  'government',
#  'resources',
#  'post',
#  'private',
#  'health',
#  'information',
#  'also',
#  'shows',
#  'type',
#  'drug',
#  'victims',
#  'overdosed',
#  'instead',
#  'barge',
#  'said',
#  'resources',
#  'used',
#  'educate',
#  'government',
#  'leaders',
#  'substance',
#  'abuse',
#  'government',
#  'needs',
#  'stop',
#  'treating',
#  'people',
#  'disease',
#  'horriﬁc',
#  'mindset',
#  'encourages',
#  'shame',
#  'invades',
#  'privacy',
#  'someone',
#  'courage',
#  'help',
#  'call',
#  'barge',
#  'wrote',
#  'facebook',
#  'post',
#  'city',
#  'leaders',
#  'justiﬁed',
#  'saying',
#  'makes',
#  'public',
#  'information',
#  'accessible',
#  'public',
#  'proximity',
#  'overdoses',
#  'make',
#  'matter',
#  'meaningful',
#  'residents',
#  'deaths',
#  'happening',
#  'public',
#  'places',
#  'like',
#  'parks',
#  'public',
#  'facilities',
#  'happening',
#  'residences',
#  'residence',
#  'next',
#  'door',
#  'brings',
#  'home',
#  'ksander',
#  'told',
#  'wthr',
#  'however',
#  'ofﬁcials',
#  'behavioral',
#  'health',
#  'groups',
#  'july',
#  'discuss',
#  'july',
#  'mayor',
#  'john',
#  'hamilton',
#  'announced',
#  'city',
#  'would',
#  'change',
#  'display',
#  'speciﬁc',
#  'address',
#  'information',
#  'within',
#  'according',
#  'public',
#  'media',
#  'wbiw',
#  'however',
#  'speciﬁc',
#  'address',
#  'information',
#  'still',
#  'publicly',
#  'available',
#  'download',
#  'site',
#  'different',
#  'part',
#  'site',
#  'sharing',
#  'controversial',
#  'overdose',
#  'mapare',
#  'modified',
#  'following',
#  'numerous',
#  'complaints',
#  'american',
#  'city',
#  'andtoward',
#  'county',
#  'public',
#  'datacity',
#  'whereonline',
#  'deaths',
#  'occurring',
#  'help',
#  'give',
#  'working',
#  'solution',
#  'tools',
#  'help',
#  'suffering',
#  'mayor',
#  'john',
#  'hamilton',
#  'said',
#  'city',
#  'news',
#  'release',
#  'time',
#  'understand',
#  'sensitive',
#  'issue',
#  'done',
#  'since',
#  'launching',
#  'site',
#  'continue',
#  'consult',
#  'front',
#  'lines',
#  'crisis',
#  'follow',
#  'best',
#  'practices',
#  'connected',
#  'stay',
#  'date',
#  'similar',
#  ...]

# %% [markdown]
# ### Section 4: count unigrem frequnecy

# %% [markdown]
# ##### 3)count word frequency

# %%
#count unigram frequency
word_frequency = Counter(ngrams(keywords, 1)).most_common()
word_frequency
# Out:
# [(('city',), 1578),
#  (('housing',), 1465),
#  (('bike',), 1217),
#  (('plan',), 1137),
#  (('neighborhood',), 968),
#  (('community',), 918),
#  (('lane',), 885),
#  (('public',), 848),
#  (('street',), 758),
#  (('transportation',), 715),
#  (('development',), 671),
#  (('greenway',), 633),
#  (('shall',), 560),
#  (('provide',), 555),
#  (('bicycle',), 546),
#  (('services',), 545),
#  (('road',), 541),
#  (('state',), 498),
#  (('program',), 440),
#  (('streets',), 437),
#  (('traffic',), 430),
#  (('protected',), 429),
#  (('path',), 421),
#  (('needs',), 415),
#  (('walnut',), 412),
#  (('downtown',), 405),
#  (('local',), 378),
#  (('service',), 375),
#  (('also',), 366),
#  (('units',), 351),
#  (('facilities',), 349),
#  (('areas',), 349),
#  (('number',), 344),
#  (('area',), 344),
#  (('support',), 343),
#  (('water',), 340),
#  (('multi‐',), 338),
#  (('data',), 336),
#  (('monroe',), 335),
#  (('need',), 327),
#  (('control',), 325),
#  (('assistance',), 322),
#  (('high',), 314),
#  (('parking',), 310),
#  (('county',), 308),
#  (('planning',), 308),
#  (('affordable',), 308),
#  (('consolidated',), 308),
#  (('policy',), 307),
#  (('park',), 306),
#  (('income',), 306),
#  (('year',), 304),
#  (('infrastructure',), 300),
#  (('work',), 299),
#  (('department',), 293),
#  (('residents',), 291),
#  (('transit',), 291),
#  (('health',), 287),
#  (('households',), 287),
#  (('access',), 281),
#  (('system',), 280),
#  (('programs',), 277),
#  (('college',), 276),
#  (('pedestrian',), 273),
#  (('energy',), 272),
#  (('safety',), 272),
#  (('total',), 270),
#  (('urban',), 268),
#  (('within',), 267),
#  (('existing',), 263),
#  (('economic',), 261),
#  (('university',), 261),
#  (('land',), 259),
#  (('grant',), 254),
#  (('waste',), 252),
#  (('action',), 251),
#  (('center',), 250),
#  (('design',), 248),
#  (('cost',), 246),
#  (('type',), 245),
#  (('improve',), 245),
#  (('network',), 244),
#  (('home',), 241),
#  (('would',), 241),
#  (('increase',), 235),
#  (('quality',), 234),
#  (('time',), 234),
#  (('people',), 230),
#  (('residential',), 229),
#  (('lead',), 228),
#  (('include',), 226),
#  (('projects',), 225),
#  (('platinum',), 217),
#  (('rental',), 215),
#  (('make',), 214),
#  (('dunn',), 212),
#  (('percent',), 210),
#  (('rogers',), 210),
#  (('education',), 208),
#  (('table',), 203),
#  (('change',), 201),
#  (('based',), 201),
#  (('persons',), 201),
#  (('many',), 198),
#  (('create',), 197),
#  (('years',), 197),
#  (('population',), 197),
#  (('including',), 195),
#  (('hand',), 195),
#  (('source',), 194),
#  (('market',), 194),
#  (('comprehensive',), 193),
#  (('open',), 193),
#  (('homeless',), 193),
#  (('develop',), 192),
#  (('used',), 192),
#  (('complete',), 189),
#  (('businesses',), 189),
#  (('environmental',), 187),
#  (('minimum',), 187),
#  (('pike',), 187),
#  (('chapter',), 186),
#  (('parks',), 185),
#  (('problems',), 185),
#  (('report',), 184),
#  (('reduce',), 184),
#  (('resources',), 183),
#  (('future',), 183),
#  (('lanes',), 181),
#  (('opportunities',), 180),
#  (('goals',), 178),
#  (('must',), 177),
#  (('level',), 176),
#  (('provided',), 175),
#  (('neighborhoods',), 175),
#  (('agency',), 175),
#  (('goal',), 175),
#  (('project',), 174),
#  (('employment',), 174),
#  (('information',), 172),
#  (('growth',), 172),
#  (('lincoln',), 170),
#  (('general',), 169),
#  (('emissions',), 169),
#  (('social',), 165),
#  (('families',), 164),
#  (('costs',), 162),
#  (('district',), 162),
#  (('available',), 161),
#  (('current',), 161),
#  (('provides',), 160),
#  (('help',), 160),
#  (('food',), 158),
#  (('description',), 158),
#  (('building',), 155),
#  (('council',), 155),
#  (('american',), 155),
#  (('activity',), 155),
#  (('blvd',), 154),
#  (('short',), 152),
#  (('school',), 151),
#  (('additional',), 148),
#  (('along',), 147),
#  (('smith',), 146),
#  (('survey',), 146),
#  (('policies',), 144),
#  (('business',), 144),
#  (('accessed',), 144),
#  (('trail',), 143),
#  (('going',), 143),
#  (('travel',), 143),
#  (('facility',), 143),
#  (('life',), 142),
#  (('walking',), 141),
#  (('improvements',), 141),
#  (('buildings',), 140),
#  (('uses',), 140),
#  (('funding',), 140),
#  (('encourage',), 139),
#  (('management',), 139),
#  (('individuals',), 139),
#  (('well',), 138),
#  (('following',), 137),
#  (('homelessness',), 136),
#  (('washington',), 135),
#  (('less',), 135),
#  (('target',), 133),
#  (('routes',), 133),
#  (('vehicles',), 133),
#  (('green',), 132),
#  (('like',), 132),
#  (('vehicle',), 132),
#  (('bicycling',), 132),
#  (('continue',), 131),
#  (('south',), 131),
#  (('children',), 130),
#  (('operations',), 130),
#  (('attached',), 130),
#  (('government',), 129),
#  (('changes',), 128),
#  (('funds',), 127),
#  (('construction',), 127),
#  (('bicyclists',), 127),
#  (('figure',), 127),
#  (('focus',), 126),
#  (('important',), 125),
#  (('madison',), 125),
#  (('woodlawn',), 125),
#  (('process',), 122),
#  (('environment',), 122),
#  (('commission',), 122),
#  (('body',), 122),
#  (('sustainability',), 121),
#  (('greater',), 121),
#  (('four',), 121),
#  (('events',), 120),
#  (('creek',), 120),
#  (('household',), 119),
#  (('kirkwood',), 119),
#  (('side',), 119),
#  (('none',), 119),
#  (('site',), 118),
#  (('activities',), 117),
#  (('henderson',), 117),
#  (('providing',), 116),
#  (('speed',), 116),
#  (('unit',), 115),
#  (('fairview',), 115),
#  (('june',), 114),
#  (('utilities',), 114),
#  (('accessible',), 113),
#  (('space',), 113),
#  (('north',), 113),
#  (('appropriate',), 112),
#  (('around',), 112),
#  (('appendix',), 112),
#  (('partners',), 111),
#  (('ridge',), 111),
#  (('start',), 110),
#  (('part',), 110),
#  (('first',), 110),
#  (('meet',), 109),
#  (('order',), 109),
#  (('sanitation',), 109),
#  (('efforts',), 108),
#  (('strategy',), 108),
#  (('cities',), 107),
#  (('vision',), 107),
#  (('benefits',), 107),
#  (('enhance',), 106),
#  (('maintain',), 106),
#  (('delivery',), 106),
#  (('natural',), 106),
#  (('multimodal',), 106),
#  (('options',), 106),
#  (('bypass',), 106),
#  (('using',), 105),
#  (('locations',), 105),
#  (('section',), 105),
#  (('five',), 105),
#  (('sare',), 105),
#  (('sidewalks',), 105),
#  (('recycling',), 105),
#  (('ensure',), 104),
#  (('commercial',), 104),
#  (('estimated',), 103),
#  (('house',), 103),
#  (('safe',), 102),
#  (('historic',), 102),
#  (('study',), 102),
#  (('sidewalk',), 102),
#  (('technology',), 101),
#  (('members',), 101),
#  (('major',), 101),
#  (('priority',), 101),
#  (('large',), 101),
#  (('outreach',), 100),
#  (('agencies',), 100),
#  (('staff',), 99),
#  (('active',), 99),
#  (('rate',), 99),
#  (('maple',), 99),
#  (('analysis',), 98),
#  (('please',), 97),
#  (('organizations',), 97),
#  (('final',), 97),
#  (('special',), 97),
#  (('better',), 96),
#  (('owneroccupied',), 96),
#  (('width',), 96),
#  (('common',), 95),
#  (('physical',), 95),
#  (('national',), 95),
#  (('maintenance',), 95),
#  (('morton',), 94),
#  (('promote',), 94),
#  (('identify',), 94),
#  (('recreation',), 94),
#  (('context',), 94),
#  (('census',), 94),
#  (('connections',), 94),
#  (('could',), 93),
#  (('includes',), 93),
#  (('currently',), 93),
#  (('located',), 93),
#  (('right',), 93),
#  (('training',), 92),
#  (('overall',), 92),
#  (('summary',), 92),
#  (('proposed',), 92),
#  (('police',), 92),
#  (('annual',), 92),
#  (('pedestrians',), 92),
#  (('require',), 91),
#  (('group',), 91),
#  (('status',), 91),
#  (('fess',), 91),
#  (('silver',), 90),
#  (('risk',), 90),
#  (('private',), 89),
#  (('regional',), 89),
#  (('centers',), 89),
#  (('emergency',), 89),
#  (('standards',), 89),
#  (('code',), 88),
#  (('items',), 88),
#  (('multiuse',), 88),
#  (('hillside',), 88),
#  (('mayor',), 87),
#  (('higher',), 87),
#  (('family',), 87),
#  (('profit',), 87),
#  (('properties',), 87),
#  (('started',), 87),
#  (('average',), 87),
#  (('jordan',), 87),
#  (('related',), 86),
#  (('however',), 86),
#  (('impact',), 86),
#  (('capital',), 86),
#  (('efficiency',), 86),
#  (('federal',), 86),
#  (('communities',), 85),
#  (('winslow',), 85),
#  (('works',), 85),
#  (('sustainable',), 84),
#  (('redevelopment',), 84),
#  (('trees',), 84),
#  (('median',), 84),
#  (('describe',), 84),
#  (('summit',), 84),
#  (('take',), 82),
#  (('actions',), 82),
#  (('roadway',), 82),
#  (('capacity',), 81),
#  (('million',), 81),
#  (('addition',), 81),
#  (('much',), 81),
#  (('built',), 81),
#  (('place',), 81),
#  (('care',), 81),
#  (('increased',), 81),
#  (('living',), 81),
#  (('friendly',), 81),
#  (('block',), 81),
#  (('hunter',), 81),
#  (('best',), 80),
#  (('main',), 80),
#  (('levels',), 80),
#  (('schools',), 80),
#  (('shared',), 80),
#  (('jackson',), 80),
#  (('atwater',), 80),
#  (('plans',), 79),
#  (('fund',), 79),
#  (('demand',), 79),
#  (('jurisdiction',), 79),
#  (('made',), 79),
#  (('users',), 79),
#  (('motor',), 79),
#  (('enforcement',), 79),
#  (('club',), 79),
#  (('smart',), 78),
#  (('making',), 78),
#  (('front',), 78),
#  (('comments',), 78),
#  (('expected',), 78),
#  (('required',), 78),
#  (('implement',), 78),
#  (('line',), 78),
#  (('issues',), 77),
#  (('property',), 77),
#  (('range',), 77),
#  (('especially',), 77),
#  (('mall',), 77),
#  (('force',), 77),
#  (('extension',), 77),
#  (('across',), 76),
#  (('ways',), 76),
#  (('identified',), 76),
#  (('west',), 76),
#  (('assessment',), 76),
#  (('tree',), 76),
#  (('wylie',), 76),
#  (('maxwell',), 76),
#  (('educational',), 75),
#  (('according',), 75),
#  (('homes',), 75),
#  (('working',), 75),
#  (('needed',), 75),
#  (('climate',), 75),
#  (('biking',), 75),
#  (('campus',), 75),
#  (('students',), 75),
#  (('supportive',), 75),
#  (('solid',), 75),
#  (('serve',), 74),
#  (('drive',), 74),
#  (('review',), 74),
#  (('amount',), 74),
#  (('fire',), 74),
#  (('info',), 74),
#  (('comm',), 74),
#  (('address',), 73),
#  (('location',), 73),
#  (('structures',), 73),
#  (('employees',), 73),
#  (('improvement',), 73),
#  (('name',), 73),
#  (('ordinance',), 73),
#  (('indicators',), 72),
#  (('systems',), 72),
#  (('recommendations',), 72),
#  (('strategies',), 72),
#  (('inventory',), 72),
#  (('improved',), 72),
#  (('committee',), 71),
#  (('without',), 71),
#  (('greenhouse',), 71),
#  (('gold',), 71),
#  (('share',), 70),
#  (('often',), 70),
#  (('spaces',), 70),
#  (('least',), 70),
#  (('rear',), 70),
#  (('kinser',), 70),
#  (('cart',), 70),
#  (('news',), 69),
#  (('jobs',), 69),
#  (('stop',), 69),
#  (('received',), 69),
#  (('clear',), 69),
#  (('arts',), 69),
#  (('approach',), 69),
#  (('opportunity',), 69),
#  (('citywide',), 69),
#  (('practices',), 68),
#  (('wide',), 68),
#  (('expand',), 68),
#  (('consider',), 68),
#  (('small',), 68),
#  (('guide',), 68),
#  (('developers',), 68),
#  (('rehabilitation',), 68),
#  (('density',), 68),
#  (('shelter',), 68),
#  (('potential',), 67),
#  (('since',), 67),
#  (('guidance',), 67),
#  (('types',), 67),
#  (('treatment',), 67),
#  (('burden',), 67),
#  (('every',), 66),
#  (('office',), 66),
#  (('offer',), 66),
#  (('significant',), 66),
#  (('percentage',), 66),
#  (('research',), 66),
#  (('equipment',), 66),
#  (('speeds',), 66),
#  (('native',), 66),
#  (('adams',), 66),
#  (('throughout',), 65),
#  (('three',), 65),
#  (('next',), 65),
#  (('elements',), 65),
#  (('economy',), 65),
#  (('central',), 65),
#  (('approximately',), 65),
#  (('developments',), 65),
#  (('ride',), 65),
#  (('connection',), 65),
#  (('connector',), 65),
#  (('cdbg',), 65),
#  (('variety',), 64),
#  (('designed',), 64),
#  (('implementation',), 64),
#  (('possible',), 64),
#  (('long',), 64),
#  (('limited',), 64),
#  (('reducing',), 64),
#  (('accessibility',), 64),
#  (('buses',), 64),
#  (('developed',), 63),
#  (('walk',), 63),
#  (('impacts',), 63),
#  (('past',), 63),
#  (('included',), 63),
#  (('benefit',), 63),
#  (('last',), 63),
#  (('several',), 63),
#  (('build',), 63),
#  (('daily',), 63),
#  (('partner',), 63),
#  (('factors',), 63),
#  (('truck',), 63),
#  (('grove',), 63),
#  (('john',), 62),
#  (('decisions',), 62),
#  (('character',), 62),
#  (('discussion',), 62),
#  (('event',), 62),
#  (('financial',), 62),
#  (('update',), 62),
#  (('administration',), 61),
#  (('specific',), 61),
#  (('assist',), 61),
#  (('student',), 61),
#  (('farm',), 61),
#  (('good',), 61),
#  (('modes',), 61),
#  (('longterm',), 60),
#  (('efficient',), 60),
#  (('miles',), 60),
#  (('even',), 60),
#  (('allow',), 60),
#  (('master',), 60),
#  (('fuel',), 60),
#  (('league',), 60),
#  (('thornton',), 60),
#  (('meeting',), 59),
#  (('objectives',), 59),
#  (('features',), 59),
#  (('step',), 59),
#  (('changing',), 59),
#  (('destinations',), 59),
#  (('outdoor',), 59),
#  (('authority',), 59),
#  (('participation',), 58),
#  (('groups',), 58),
#  (('introduction',), 58),
#  (('preservation',), 58),
#  (('investments',), 58),
#  (('turn',), 58),
#  (('means',), 58),
#  (('priorities',), 58),
#  (('likely',), 58),
#  (('purchase',), 58),
#  (('town',), 58),
#  (('connectivity',), 58),
#  (('route',), 58),
#  (('given',), 58),
#  (('outlined',), 58),
#  (('places',), 57),
#  (('single',), 57),
#  (('sector',), 57),
#  (('stormwater',), 57),
#  (('corridor',), 57),
#  (('crossing',), 57),
#  (('mixed',), 56),
#  (('trends',), 56),
#  (('collection',), 56),
#  (('near',), 56),
#  (('planned',), 56),
#  (('kitchen',), 56),
#  (('elderly',), 56),
#  (('stands',), 56),
#  (('regulations',), 56),
#  (('times',), 56),
#  (('patterson',), 56),
#  (('volume',), 56),
#  (('trucks',), 56),
#  (('hydraulic',), 56),
#  (('coordination',), 55),
#  (('consumption',), 55),
#  (('roads',), 55),
#  (('statement',), 55),
#  (('necessary',), 55),
#  (('various',), 55),
#  (('upon',), 55),
#  (('positive',), 55),
#  (('multifamily',), 55),
#  (('adults',), 55),
#  (('trails',), 55),
#  (('union',), 55),
#  (('extend',), 55),
#  (('already',), 55),
#  (('compliance',), 55),
#  (('citizen',), 55),
#  (('intersection',), 55),
#  (('concerns',), 54),
#  (('objective',), 54),
#  (('conditions',), 54),
#  (('lower',), 54),
#  (('period',), 54),
#  (('mental',), 54),
#  (('establish',), 54),
#  (('recommended',), 54),
#  (('intersections',), 54),
#  (('noted',), 54),
#  (('morningside',), 54),
#  (('mounted',), 53),
#  (('thinking',), 53),
#  (('outside',), 53),
#  (('reduction',), 53),
#  (('incentives',), 53),
#  (('departments',), 53),
#  (('trips',), 53),
#  (('condition',), 53),
#  (('assisted',), 53),
#  (('team',), 53),
#  (('southern',), 53),
#  (('follows',), 53),
#  (('steel',), 53),
#  (('director',), 52),
#  (('points',), 52),
#  (('mobility',), 52),
#  (('task',), 52),
#  (('adjacent',), 52),
#  (('standard',), 52),
#  (('cars',), 52),
#  (('paint',), 52),
#  (('veterans',), 52),
#  (('highland',), 52),
#  (('initiatives',), 51),
#  (('considered',), 51),
#  (('problem',), 51),
#  (('limits',), 51),
#  (('similar',), 51),
#  (('outcomes',), 51),
#  (('achieve',), 51),
#  (('document',), 51),
#  (('improving',), 51),
#  (('ages',), 51),
#  (('retail',), 51),
#  (('live',), 51),
#  (('evaluate',), 51),
#  (('affordability',), 51),
#  (('requirements',), 51),
#  (('back',), 51),
#  (('drivers',), 51),
#  (('volumes',), 51),
#  (('person',), 50),
#  (('meters',), 50),
#  (('july',), 50),
#  (('away',), 50),
#  (('tool',), 50),
#  (('workforce',), 50),
#  (('negative',), 50),
#  (('municipal',), 50),
#  (('hospital',), 50),
#  (('increasing',), 50),
#  (('approvals',), 50),
#  (('lights',), 50),
#  (('yard',), 50),
#  (('east',), 50),
#  (('rockport',), 50),
#  (('olcott',), 50),
#  (('hamilton',), 49),
#  (('healthy',), 49),
#  (('shows',), 49),
#  (('protection',), 49),
#  (('conservation',), 49),
#  (('full',), 49),
#  (('tapp',), 49),
#  (('united',), 49),
#  (('reported',), 49),
#  (('white',), 49),
#  (('bloomfield',), 49),
#  (('moores',), 49),
#  (('updated',), 48),
#  (('determine',), 48),
#  (('another',), 48),
#  (('requires',), 48),
#  (('expansion',), 48),
#  (('strong',), 48),
#  (('recent',), 48),
#  (('example',), 48),
#  (('assess',), 48),
#  (('resource',), 48),
#  (('prevent',), 48),
#  (('mode',), 48),
#  (('springs',), 48),
#  (('graham',), 48),
#  (('southdowns',), 48),
#  (('individual',), 47),
#  (('role',), 47),
#  (('steps',), 47),
#  (('responsible',), 47),
#  (('carbon',), 47),
#  (('paths',), 47),
#  (('stops',), 47),
#  (('little',), 46),
#  (('become',), 46),
#  (('light',), 46),
#  (('rates',), 46),
#  (('equal',), 46),
#  (('creating',), 46),
#  (('moderate',), 46),
#  (('connect',), 45),
#  (('page',), 45),
#  (('member',), 45),
#  (('direct',), 45),
#  (('region',), 45),
#  (('square',), 45),
#  (('compared',), 45),
#  (('free',), 45),
#  (('results',), 45),
#  (('barriers',), 45),
#  (('frame',), 45),
#  (('rose',), 45),
#  (('forrest',), 45),
#  (('sheridan',), 45),
#  (('established',), 44),
#  (('application',), 44),
#  (('follow',), 44),
#  (('association',), 44),
#  (('critical',), 44),
#  (('grow',), 44),
#  (('zoning',), 44),
#  (('industrial',), 44),
#  (('eligible',), 44),
#  (('feet',), 44),
#  (('maximum',), 44),
#  (('prevention',), 44),
#  (('typology',), 44),
#  (('avenue',), 44),
#  (('allen',), 44),
#  (('installed',), 44),
#  (('winston',), 44),
#  (('rock',), 44),
#  (('govt',), 44),
#  (('release',), 43),
#  (('progress',), 43),
#  (('january',), 43),
#  (('transition',), 43),
#  (('anticipated',), 43),
#  (('overview',), 43),
#  (('regarding',), 43),
#  (('cultural',), 43),
#  (('outcome',), 43),
#  (('form',), 43),
#  (('partnerships',), 43),
#  (('size',), 43),
#  (('populations',), 43),
#  (('among',), 43),
#  (('landscaping',), 43),
#  (('zone',), 43),
#  (('grid',), 43),
#  (('amendment',), 43),
#  (('miller',), 42),
#  (('still',), 42),
#  (('culture',), 42),
#  (('engagement',), 42),
#  (('investment',), 42),
#  (('characteristics',), 42),
#  (('prioritize',), 42),
#  (('structure',), 42),
#  (('supports',), 42),
#  (('essential',), 42),
#  (('sources',), 42),
#  (('production',), 42),
#  (('result',), 42),
#  (('utilize',), 42),
#  (('whole',), 42),
#  (('preserve',), 42),
#  (('lots',), 42),
#  (('interest',), 42),
#  (('either',), 42),
#  (('crashes',), 42),
#  (('severe',), 42),
#  (('shalom',), 42),
#  (('ramble',), 42),
#  (('contact',), 41),
#  (('multiple',), 41),
#  (('renewable',), 41),
#  (('said',), 41),
#  (('list',), 41),
#  (('tech',), 41),
#  (('money',), 41),
#  (('sewer',), 41),
#  (('close',), 41),
#  (('disabilities',), 41),
#  (('districts',), 41),
#  (('alternative',), 41),
#  (('states',), 41),
#  (('interested',), 41),
#  (('cycling',), 41),
#  (('carts',), 41),
#  (('‐line',), 41),
#  (('tenant',), 41),
#  (('evaluation',), 40),
#  (('coordinate',), 40),
#  (('owner',), 40),
#  (('walker',), 40),
#  (('human',), 40),
#  (('core',), 40),
#  (('continues',), 40),
#  (('larger',), 40),
#  (('supported',), 40),
#  (('growing',), 40),
#  (('apartments',), 40),
#  (('associated',), 40),
#  (('senior',), 40),
#  (('older',), 40),
#  (('monitor',), 40),
#  (('participants',), 40),
#  (('global',), 40),
#  (('experiencing',), 40),
#  (('comfort',), 40),
#  (('circulation',), 40),
#  (('palmer',), 40),
#  (('monthly',), 40),
#  (('difficult',), 40),
#  (('covenanter',), 40),
#  (('hawthorne',), 40),
#  (('supply',), 39),
#  (('different',), 39),
#  (('wilson',), 39),
#  (('country',), 39),
#  (('industry',), 39),
#  (('visitors',), 39),
#  (('youth',), 39),
#  (('suburban',), 39),
#  (('congestion',), 39),
#  (('typical',), 39),
#  (('manager',), 39),
#  (('idea',), 39),
#  (('hispanic',), 39),
#  (('chas',), 39),
#  (('able',), 38),
#  (('online',), 38),
#  (('personal',), 38),
#  (('listed',), 38),
#  (('challenge',), 38),
#  (('employee',), 38),
#  (('citizens',), 38),
#  (('intent',), 38),
#  (('towards',), 38),
#  (('asian',), 38),
#  (('adult',), 38),
#  (('estimate',), 38),
#  (('consultation',), 38),
#  (('organization',), 38),
#  (('view',), 38),
#  (('flow',), 38),
#  (('days',), 38),
#  (('curb',), 38),
#  (('valley',), 38),
#  (('think',), 38),
#  (('rent',), 38),
#  (('foundation',), 37),
#  (('categories',), 37),
#  (('usage',), 37),
#  (('detailed',), 37),
#  (('found',), 37),
#  (('connected',), 37),
#  (('bill',), 37),
#  (('hours',), 37),
#  (('together',), 37),
#  (('developing',), 37),
#  (('challenges',), 37),
#  (('basic',), 37),
#  (('automobile',), 37),
#  (('enough',), 37),
#  (('value',), 37),
#  (('revenue',), 37),
#  (('avoid',), 37),
#  (('significantly',), 37),
#  (('black',), 37),
#  (('guidelines',), 37),
#  (('prior',), 37),
#  (('pickup',), 37),
#  (('successful',), 37),
#  (('bicycles',), 37),
#  (('respect',), 37),
#  (('category',), 37),
#  (('bikes',), 37),
#  (('dodds',), 37),
#  (('gallon',), 37),
#  (('fleet',), 37),
#  (('leonard',), 37),
#  (('meadowbrook',), 37),
#  (('rosewood',), 37),
#  (('receive',), 36),
#  (('bryan',), 36),
#  (('protect',), 36),
#  (('response',), 36),
#  (('remain',), 36),
#  (('allows',), 36),
#  (('adopted',), 36),
#  (('typically',), 36),
#  (('basis',), 36),
#  (('domestic',), 36),
#  (('creative',), 36),
#  (('skills',), 36),
#  (('workers',), 36),
#  (('effective',), 36),
#  (('feasible',), 36),
#  (('minimize',), 36),
#  (('room',), 36),
#  (('middle',), 36),
#  (('classes',), 36),
#  (('arlington',), 36),
#  (('yield',), 36),
#  (('billing',), 36),
#  (('officers',), 36),
#  (('values',), 36),
#  (('framework',), 35),
#  (('measures',), 35),
#  (('installation',), 35),
#  (('networks',), 35),
#  (('success',), 35),
#  (('surveys',), 35),
#  (('meetings',), 35),
#  (('great',), 35),
#  (('creation',), 35),
#  (('materials',), 35),
#  (('attract',), 35),
#  (('corridors',), 35),
#  (('employers',), 35),
#  (('addressed',), 35),
#  (('operation',), 35),
#  (('obesity',), 35),
#  (('additionally',), 35),
#  (('women',), 35),
#  (('architectural',), 35),
#  (('point',), 35),
#  (('user',), 35),
#  (('legal',), 35),
#  (('want',), 35),
#  (('gauge',), 35),
#  (('advisory',), 35),
#  (('pass',), 35),
#  (('panel',), 35),
#  (('violence',), 35),
#  (('centerstone',), 35),
#  (('hillsdale',), 35),
#  (('lacks',), 35),
#  (('mailed',), 35),
#  (('applications',), 34),
#  (('assets',), 34),
#  (('reporting',), 34),
#  (('customers',), 34),
#  (('makes',), 34),
#  (('done',), 34),
#  (('date',), 34),
#  (('trash',), 34),
#  (('village',), 34),
#  (('toward',), 34),
#  (('others',), 34),
#  (('integrity',), 34),
#  (('exhibit',), 34),
#  (('bureau',), 34),
#  (('completed',), 34),
#  (('professional',), 34),
#  (('wastewater',), 34),
#  (('certified',), 34),
#  (('targeted',), 34),
#  (('move',), 34),
#  (('hall',), 34),
#  (('disabled',), 34),
#  (('crash',), 34),
#  (('engineering',), 34),
#  (('driving',), 34),
#  (('lighting',), 34),
#  (('subsidy',), 34),
#  (('hopper',), 34),
#  (('○',), 34),
#  (('eastside',), 34),
#  (('choice',), 33),
#  (('regularly',), 33),
#  (('purpose',), 33),
#  (('habitat',), 33),
#  (('providers',), 33),
#  (('budget',), 33),
#  (('explore',), 33),
#  (('gaps',), 33),
#  (('convention',), 33),
#  (('link',), 33),
#  (('medium',), 33),
#  (('roadways',), 33),
#  (('operating',), 33),
#  (('engine',), 33),
#  (('axle',), 33),
#  (('typologies',), 33),
#  (('greenways',), 33),
#  (('motorists',), 33),
#  (('countryside',), 33),
#  (('mitchell',), 33),
#  ...]

# %% [markdown]
# ##### 4) make counts into a table (DataFrame)

# %%
unigram_frequency_pd = pd.DataFrame(word_frequency, columns=['counts', 'words'])
unigram_frequency_pd = unigram_frequency_pd[['words','counts']]

# %% [markdown]
# ### step 5: separate nouns, verb, adjective, adverbs, etc.

# %% [markdown]
# ##### 1) Stem words - reduce words into their basic forms. e.g. 'fished','fisher' -> 'fish'
#
# **because not only 'cities' -> but 'community' -> 'common' too.

# %%
porter = PorterStemmer()
stemmed_keywords = [porter.stem(word) for word in keywords]
stemmed_keywords
# Out:
# ['join',
#  'green',
#  'build',
#  'council',
#  'leed',
#  'citi',
#  'commun',
#  'program',
#  'citi',
#  'citi',
#  'mayor',
#  'john',
#  'hamilton',
#  'feedback',
#  'type',
#  'news',
#  'releas',
#  'join',
#  'green',
#  'build',
#  'council',
#  'leed',
#  'citi',
#  'commun',
#  'program',
#  'share',
#  'morton',
#  'street',
#  'suit',
#  'connect',
#  'facebook',
#  'inform',
#  'pleas',
#  'contact',
#  'alex',
#  'crowley',
#  'director',
#  'econom',
#  'sustain',
#  'develop',
#  'depart',
#  'crowleyabloomington',
#  'join',
#  'green',
#  'build',
#  'council',
#  'leed',
#  'citi',
#  'commun',
#  'program',
#  'today',
#  'citi',
#  'announc',
#  'particip',
#  'green',
#  'build',
#  'council',
#  'usgbc',
#  'leed',
#  'citi',
#  'commun',
#  'grant',
#  'program',
#  'process',
#  'becom',
#  'leedcertiﬁ',
#  'citi',
#  'receiv',
#  'ﬁnancial',
#  'assist',
#  'educ',
#  'resourc',
#  'technic',
#  'support',
#  'increas',
#  'enhanc',
#  'practic',
#  'support',
#  'sustain',
#  'healthi',
#  'equit',
#  'life',
#  'usgbc',
#  'leed',
#  'program',
#  'also',
#  'support',
#  'citi',
#  'exist',
#  'effort',
#  'track',
#  'verifi',
#  'perform',
#  'wide',
#  'varieti',
#  'sustain',
#  'indic',
#  'includ',
#  'energi',
#  'water',
#  'transport',
#  'educ',
#  'health',
#  'demonstr',
#  'commit',
#  'sustain',
#  'multipl',
#  'front',
#  'effort',
#  'increas',
#  'renew',
#  'energi',
#  'gener',
#  'expand',
#  'trail',
#  'infrastructur',
#  'maintain',
#  'safe',
#  'water',
#  'suppli',
#  'environment',
#  'initi',
#  'further',
#  'equiti',
#  'econom',
#  'develop',
#  'said',
#  'mayor',
#  'john',
#  'join',
#  'green',
#  'build',
#  'council',
#  'leed',
#  'citi',
#  'commun',
#  'program',
#  'citi',
#  'hamilton',
#  'achiev',
#  'leed',
#  'certiﬁc',
#  'provid',
#  'nation',
#  'recogn',
#  'framework',
#  'practic',
#  'promot',
#  'ident',
#  'sustain',
#  'leader',
#  'develop',
#  'leed',
#  'green',
#  'build',
#  'certiﬁc',
#  'system',
#  'usgbc',
#  'expand',
#  'purview',
#  'beyond',
#  'individu',
#  'build',
#  'launch',
#  'leed',
#  'citi',
#  'commun',
#  'grant',
#  'program',
#  'design',
#  'encourag',
#  'develop',
#  'smart',
#  'citi',
#  'resili',
#  'commun',
#  'program',
#  'launch',
#  'particip',
#  'citi',
#  'support',
#  'bank',
#  'america',
#  'charit',
#  'foundat',
#  'program',
#  'expand',
#  'citi',
#  'commun',
#  'includ',
#  'accord',
#  'announc',
#  'releas',
#  'usgbc',
#  'today',
#  'applic',
#  'citi',
#  'seek',
#  'leed',
#  'certiﬁc',
#  'evalu',
#  'demonstr',
#  'need',
#  'leadership',
#  'support',
#  'commit',
#  'datadriven',
#  'decisionmak',
#  'staff',
#  'capac',
#  'coordin',
#  'local',
#  'initi',
#  'citi',
#  'sustain',
#  'action',
#  'plan',
#  'establish',
#  'practic',
#  'track',
#  'share',
#  'data',
#  'consid',
#  'asset',
#  'applic',
#  'repres',
#  'particip',
#  'citi',
#  'attend',
#  'person',
#  'orient',
#  'usgbc',
#  'headquart',
#  'washington',
#  'earli',
#  'june',
#  'usgbc',
#  'staff',
#  'walk',
#  'commun',
#  'rate',
#  'system',
#  'evalu',
#  'measur',
#  'lead',
#  'number',
#  'hand',
#  'exercis',
#  'calcul',
#  'score',
#  'develop',
#  'action',
#  'plan',
#  'year',
#  'train',
#  'citi',
#  'commun',
#  'start',
#  'align',
#  'exist',
#  'program',
#  'plan',
#  'leed',
#  'rate',
#  'system',
#  'use',
#  'project',
#  'manag',
#  'tool',
#  'resourc',
#  'provid',
#  'usgbc',
#  'gather',
#  'data',
#  'evalu',
#  'measur',
#  'choic',
#  'rate',
#  'system',
#  'enter',
#  'data',
#  'report',
#  'tool',
#  'cohort',
#  'local',
#  'govern',
#  'meet',
#  'regularli',
#  'throughout',
#  'year',
#  'report',
#  'progress',
#  'share',
#  'best',
#  'practic',
#  'learn',
#  'usgbc',
#  'leed',
#  'citi',
#  'commun',
#  'program',
#  'join',
#  'green',
#  'build',
#  'council',
#  'leed',
#  'citi',
#  'commun',
#  'program',
#  'citi',
#  'relat',
#  'categori',
#  'depart',
#  'econom',
#  'sustain',
#  'develop',
#  'morton',
#  'connect',
#  'facebook',
#  'follow',
#  'twitter',
#  'citi',
#  'job',
#  'subscrib',
#  'email',
#  'list',
#  'polici',
#  'report',
#  'problem',
#  'citi',
#  'intranet',
#  'home',
#  'login',
#  'citi',
#  'util',
#  'move',
#  'forward',
#  'smart',
#  'meter',
#  'instal',
#  'citi',
#  'citi',
#  'mayor',
#  'john',
#  'hamilton',
#  'feedback',
#  'type',
#  'news',
#  'releas',
#  'januari',
#  'citi',
#  'util',
#  'move',
#  'forward',
#  'smart',
#  'meter',
#  'instal',
#  'share',
#  'miller',
#  'januari',
#  'inform',
#  'pleas',
#  'contact',
#  'kelson',
#  'director',
#  'citi',
#  'util',
#  'kelsonvbloomington',
#  'citi',
#  'util',
#  'move',
#  'forward',
#  'smart',
#  'meter',
#  'instal',
#  'meet',
#  'even',
#  'util',
#  'servic',
#  'board',
#  'schedul',
#  'consid',
#  'million',
#  'agreement',
#  'util',
#  'meter',
#  'solut',
#  'overse',
#  'transit',
#  'water',
#  'meter',
#  'advanc',
#  'meter',
#  'infrastructur',
#  'approv',
#  'contractor',
#  'agent',
#  'citi',
#  'util',
#  'instal',
#  'meter',
#  'softwar',
#  'conduct',
#  'commun',
#  'outreach',
#  'measur',
#  'ensur',
#  'smooth',
#  'convers',
#  'instal',
#  'anticip',
#  'complet',
#  'march',
#  'decemb',
#  'citi',
#  'council',
#  'approv',
#  'leasepurchas',
#  'agreement',
#  'fund',
#  'implement',
#  'system',
#  'serv',
#  'custom',
#  'integr',
#  'system',
#  'smart',
#  'meter',
#  'commun',
#  'network',
#  'data',
#  'manag',
#  'system',
#  'enabl',
#  'commun',
#  'util',
#  'custom',
#  'system',
#  'provid',
#  'number',
#  'import',
#  'function',
#  'previous',
#  'possibl',
#  'perform',
#  'manual',
#  'includ',
#  'demand',
#  'read',
#  'abil',
#  'measur',
#  'water',
#  'usag',
#  'automat',
#  'remot',
#  'connect',
#  'disconnect',
#  'servic',
#  'detect',
#  'tamper',
#  'identifi',
#  'isol',
#  'pressur',
#  'issu',
#  'potenti',
#  'leak',
#  'util',
#  'custom',
#  'access',
#  'detail',
#  'water',
#  'usag',
#  'inform',
#  'meter',
#  'citi',
#  'util',
#  'move',
#  'forward',
#  'smart',
#  'meter',
#  'instal',
#  'citi',
#  'water',
#  'meter',
#  'ﬁrst',
#  'applic',
#  'system',
#  'serv',
#  'base',
#  'station',
#  'also',
#  'serv',
#  'high',
#  'secur',
#  'radio',
#  'commun',
#  'network',
#  'smart',
#  'citi',
#  'applic',
#  'addit',
#  'water',
#  'meter',
#  'network',
#  'commun',
#  'smart',
#  'devic',
#  'across',
#  'citi',
#  'support',
#  'futur',
#  'applic',
#  'coordin',
#  'streamlin',
#  'deliveri',
#  'citi',
#  'servic',
#  'applic',
#  'reduc',
#  'environment',
#  'impact',
#  'improv',
#  'data',
#  'qualiti',
#  'overal',
#  'cost',
#  'project',
#  'includ',
#  'conting',
#  'estim',
#  'million',
#  'immedi',
#  'beneﬁt',
#  'modern',
#  'meter',
#  'system',
#  'heighten',
#  'efﬁcienc',
#  'abl',
#  'respond',
#  'infrastructur',
#  'issu',
#  'empow',
#  'custom',
#  'make',
#  'inform',
#  'decis',
#  'manag',
#  'water',
#  'consumpt',
#  'said',
#  'mayor',
#  'john',
#  'hamilton',
#  'beyond',
#  'applic',
#  'water',
#  'meter',
#  'innov',
#  'network',
#  'like',
#  'offer',
#  'reach',
#  'potenti',
#  'creat',
#  'efﬁcienc',
#  'cost',
#  'conserv',
#  'natur',
#  'resourc',
#  'meet',
#  'everi',
#  'monday',
#  'except',
#  'citi',
#  'holiday',
#  'util',
#  'servic',
#  'center',
#  'miller',
#  'drive',
#  'everyon',
#  'welcom',
#  'time',
#  'reserv',
#  'meet',
#  'public',
#  'comment',
#  'inform',
#  'found',
#  'websit',
#  'bloomingtonutil',
#  'facebook',
#  'page',
#  'citi',
#  'util',
#  'pictur',
#  'water',
#  'meter',
#  'iperl',
#  'citi',
#  'util',
#  'move',
#  'forward',
#  'smart',
#  'meter',
#  'instal',
#  'citi',
#  'relat',
#  'categori',
#  'depart',
#  'util',
#  'depart',
#  'morton',
#  'connect',
#  'facebook',
#  'follow',
#  'twitter',
#  'citi',
#  'job',
#  'subscrib',
#  'email',
#  'list',
#  'polici',
#  'report',
#  'problem',
#  'citi',
#  'intranet',
#  'home',
#  'login',
#  'citi',
#  'controversi',
#  'onlin',
#  'overdos',
#  'modifi',
#  'follow',
#  'numer',
#  'complaint',
#  'american',
#  'citi',
#  'counti',
#  'smart',
#  'citi',
#  'technolog',
#  'technolog',
#  'articl',
#  'citi',
#  'controversi',
#  'onlin',
#  'overdos',
#  'modi',
#  'follow',
#  'numer',
#  'complaint',
#  'share',
#  'inform',
#  'public',
#  'import',
#  'function',
#  'govern',
#  'sometim',
#  'inform',
#  'person',
#  'share',
#  'case',
#  'ofﬁcial',
#  'began',
#  'track',
#  'opioid',
#  'overdos',
#  'death',
#  'onlin',
#  'pinpoint',
#  'address',
#  'overdos',
#  'victim',
#  'within',
#  'citi',
#  'limit',
#  'written',
#  'jason',
#  'axelrod',
#  'juli',
#  'share',
#  'inform',
#  'public',
#  'import',
#  'function',
#  'govern',
#  'sometim',
#  'inform',
#  'person',
#  'share',
#  'controversi',
#  'onlin',
#  'overdos',
#  'modifi',
#  'numer',
#  'complaint',
#  'american',
#  'citi',
#  'counti',
#  'caseindiana',
#  'whenciti',
#  'ofﬁcial',
#  'beganfollow',
#  'track',
#  'opioid',
#  'overdos',
#  'death',
#  'onlin',
#  'pinpoint',
#  'address',
#  'overdos',
#  'victim',
#  'within',
#  'citi',
#  'limit',
#  'accord',
#  'public',
#  'media',
#  'critic',
#  'mount',
#  'peopl',
#  'across',
#  'monro',
#  'counti',
#  'citi',
#  'ofﬁcial',
#  'alter',
#  'juli',
#  'display',
#  'street',
#  'address',
#  'instead',
#  'show',
#  'overdos',
#  'locat',
#  'resid',
#  'busi',
#  'public',
#  'properti',
#  'radio',
#  'station',
#  'wbiw',
#  'report',
#  'launch',
#  'march',
#  'part',
#  'reveal',
#  'public',
#  'inform',
#  'transpar',
#  'site',
#  'mayor',
#  'ofﬁc',
#  'innov',
#  'creat',
#  'accord',
#  'wbiw',
#  'best',
#  'recip',
#  'success',
#  'term',
#  'address',
#  'problem',
#  'make',
#  'data',
#  'access',
#  'commun',
#  'director',
#  'yael',
#  'ksander',
#  'told',
#  'indianapoli',
#  'station',
#  'wthr',
#  'resid',
#  'ofﬁcial',
#  'alik',
#  'react',
#  'neg',
#  'heather',
#  'harlow',
#  'uncl',
#  'john',
#  'harlow',
#  'pass',
#  'away',
#  'drug',
#  'overdos',
#  'three',
#  'year',
#  'harlow',
#  'grandpar',
#  'home',
#  'harlow',
#  'voic',
#  'concern',
#  'viewer',
#  'could',
#  'grandpar',
#  'hous',
#  'list',
#  'wthr',
#  'report',
#  'construct',
#  'way',
#  'display',
#  'inform',
#  'pinpoint',
#  'peopl',
#  'individu',
#  'home',
#  'told',
#  'wthr',
#  'ad',
#  'ensur',
#  'peopl',
#  'safeti',
#  'greater',
#  'issu',
#  'hide',
#  'statist',
#  'monro',
#  'counti',
#  'commission',
#  'amanda',
#  'clerk',
#  'barg',
#  'took',
#  'facebook',
#  'vent',
#  'frustrat',
#  'critic',
#  'ofﬁcial',
#  'justiﬁc',
#  'use',
#  'govern',
#  'resourc',
#  'post',
#  'privat',
#  'health',
#  'inform',
#  'also',
#  'show',
#  'type',
#  'drug',
#  'victim',
#  'overdos',
#  'instead',
#  'barg',
#  'said',
#  'resourc',
#  'use',
#  'educ',
#  'govern',
#  'leader',
#  'substanc',
#  'abus',
#  'govern',
#  'need',
#  'stop',
#  'treat',
#  'peopl',
#  'diseas',
#  'horriﬁc',
#  'mindset',
#  'encourag',
#  'shame',
#  'invad',
#  'privaci',
#  'someon',
#  'courag',
#  'help',
#  'call',
#  'barg',
#  'wrote',
#  'facebook',
#  'post',
#  'citi',
#  'leader',
#  'justiﬁ',
#  'say',
#  'make',
#  'public',
#  'inform',
#  'access',
#  'public',
#  'proxim',
#  'overdos',
#  'make',
#  'matter',
#  'meaning',
#  'resid',
#  'death',
#  'happen',
#  'public',
#  'place',
#  'like',
#  'park',
#  'public',
#  'facil',
#  'happen',
#  'resid',
#  'resid',
#  'next',
#  'door',
#  'bring',
#  'home',
#  'ksander',
#  'told',
#  'wthr',
#  'howev',
#  'ofﬁcial',
#  'behavior',
#  'health',
#  'group',
#  'juli',
#  'discuss',
#  'juli',
#  'mayor',
#  'john',
#  'hamilton',
#  'announc',
#  'citi',
#  'would',
#  'chang',
#  'display',
#  'speciﬁc',
#  'address',
#  'inform',
#  'within',
#  'accord',
#  'public',
#  'media',
#  'wbiw',
#  'howev',
#  'speciﬁc',
#  'address',
#  'inform',
#  'still',
#  'publicli',
#  'avail',
#  'download',
#  'site',
#  'differ',
#  'part',
#  'site',
#  'share',
#  'controversi',
#  'overdos',
#  'mapar',
#  'modifi',
#  'follow',
#  'numer',
#  'complaint',
#  'american',
#  'citi',
#  'andtoward',
#  'counti',
#  'public',
#  'datac',
#  'whereonlin',
#  'death',
#  'occur',
#  'help',
#  'give',
#  'work',
#  'solut',
#  'tool',
#  'help',
#  'suffer',
#  'mayor',
#  'john',
#  'hamilton',
#  'said',
#  'citi',
#  'news',
#  'releas',
#  'time',
#  'understand',
#  'sensit',
#  'issu',
#  'done',
#  'sinc',
#  'launch',
#  'site',
#  'continu',
#  'consult',
#  'front',
#  'line',
#  'crisi',
#  'follow',
#  'best',
#  'practic',
#  'connect',
#  'stay',
#  'date',
#  'similar',
#  ...]

# %% [markdown]
# ##### 2) separate part of speech
# NN = noun, singular;VB = verb;JJ = adjective;

# %%
tagged_keywords = nltk.pos_tag(stemmed_keywords)  #separate part of speech
tagged_keywords
# Out:
# [('join', 'NN'),
#  ('green', 'JJ'),
#  ('build', 'NN'),
#  ('council', 'NN'),
#  ('leed', 'VBD'),
#  ('citi', 'JJ'),
#  ('commun', 'NN'),
#  ('program', 'NN'),
#  ('citi', 'NN'),
#  ('citi', 'NN'),
#  ('mayor', 'NN'),
#  ('john', 'NN'),
#  ('hamilton', 'NN'),
#  ('feedback', 'NN'),
#  ('type', 'NN'),
#  ('news', 'NN'),
#  ('releas', 'NNS'),
#  ('join', 'VBP'),
#  ('green', 'JJ'),
#  ('build', 'NN'),
#  ('council', 'NN'),
#  ('leed', 'VBD'),
#  ('citi', 'JJ'),
#  ('commun', 'NN'),
#  ('program', 'NN'),
#  ('share', 'NN'),
#  ('morton', 'NNP'),
#  ('street', 'NN'),
#  ('suit', 'NN'),
#  ('connect', 'VBP'),
#  ('facebook', 'NN'),
#  ('inform', 'NN'),
#  ('pleas', 'NNS'),
#  ('contact', 'VBP'),
#  ('alex', 'JJ'),
#  ('crowley', 'NN'),
#  ('director', 'NN'),
#  ('econom', 'VBD'),
#  ('sustain', 'JJ'),
#  ('develop', 'VB'),
#  ('depart', 'JJ'),
#  ('crowleyabloomington', 'NN'),
#  ('join', 'NN'),
#  ('green', 'JJ'),
#  ('build', 'NN'),
#  ('council', 'NN'),
#  ('leed', 'VBD'),
#  ('citi', 'JJ'),
#  ('commun', 'NN'),
#  ('program', 'NN'),
#  ('today', 'NN'),
#  ('citi', 'VBP'),
#  ('announc', 'NN'),
#  ('particip', 'NN'),
#  ('green', 'JJ'),
#  ('build', 'NN'),
#  ('council', 'NN'),
#  ('usgbc', 'JJ'),
#  ('leed', 'NN'),
#  ('citi', 'NN'),
#  ('commun', 'NN'),
#  ('grant', 'JJ'),
#  ('program', 'NN'),
#  ('process', 'NN'),
#  ('becom', 'NN'),
#  ('leedcertiﬁ', 'NN'),
#  ('citi', 'NN'),
#  ('receiv', 'VBP'),
#  ('ﬁnancial', 'JJ'),
#  ('assist', 'NN'),
#  ('educ', 'NN'),
#  ('resourc', 'NN'),
#  ('technic', 'JJ'),
#  ('support', 'NN'),
#  ('increas', 'NNS'),
#  ('enhanc', 'VBP'),
#  ('practic', 'JJ'),
#  ('support', 'NN'),
#  ('sustain', 'NN'),
#  ('healthi', 'NN'),
#  ('equit', 'NN'),
#  ('life', 'NN'),
#  ('usgbc', 'JJ'),
#  ('leed', 'NN'),
#  ('program', 'NN'),
#  ('also', 'RB'),
#  ('support', 'VB'),
#  ('citi', 'NNS'),
#  ('exist', 'VBP'),
#  ('effort', 'NN'),
#  ('track', 'NN'),
#  ('verifi', 'NN'),
#  ('perform', 'NN'),
#  ('wide', 'JJ'),
#  ('varieti', 'NN'),
#  ('sustain', 'NN'),
#  ('indic', 'JJ'),
#  ('includ', 'NN'),
#  ('energi', 'NN'),
#  ('water', 'NN'),
#  ('transport', 'NN'),
#  ('educ', 'VBZ'),
#  ('health', 'NN'),
#  ('demonstr', 'NN'),
#  ('commit', 'NN'),
#  ('sustain', 'VBP'),
#  ('multipl', 'JJ'),
#  ('front', 'NN'),
#  ('effort', 'NN'),
#  ('increas', 'JJ'),
#  ('renew', 'NN'),
#  ('energi', 'NN'),
#  ('gener', 'NN'),
#  ('expand', 'VBP'),
#  ('trail', 'NN'),
#  ('infrastructur', 'NN'),
#  ('maintain', 'VBP'),
#  ('safe', 'JJ'),
#  ('water', 'NN'),
#  ('suppli', 'NN'),
#  ('environment', 'NN'),
#  ('initi', 'NN'),
#  ('further', 'RBR'),
#  ('equiti', 'RB'),
#  ('econom', 'JJ'),
#  ('develop', 'NN'),
#  ('said', 'VBD'),
#  ('mayor', 'NN'),
#  ('john', 'NN'),
#  ('join', 'NN'),
#  ('green', 'JJ'),
#  ('build', 'NN'),
#  ('council', 'NN'),
#  ('leed', 'VBD'),
#  ('citi', 'JJ'),
#  ('commun', 'NN'),
#  ('program', 'NN'),
#  ('citi', 'VBP'),
#  ('hamilton', 'NN'),
#  ('achiev', 'NNS'),
#  ('leed', 'VBP'),
#  ('certiﬁc', 'JJ'),
#  ('provid', 'JJ'),
#  ('nation', 'NN'),
#  ('recogn', 'NN'),
#  ('framework', 'NN'),
#  ('practic', 'JJ'),
#  ('promot', 'NN'),
#  ('ident', 'NN'),
#  ('sustain', 'NN'),
#  ('leader', 'NN'),
#  ('develop', 'VB'),
#  ('leed', 'NN'),
#  ('green', 'JJ'),
#  ('build', 'NN'),
#  ('certiﬁc', 'NN'),
#  ('system', 'NN'),
#  ('usgbc', 'JJ'),
#  ('expand', 'NN'),
#  ('purview', 'NN'),
#  ('beyond', 'IN'),
#  ('individu', 'JJ'),
#  ('build', 'JJ'),
#  ('launch', 'NN'),
#  ('leed', 'VBD'),
#  ('citi', 'JJ'),
#  ('commun', 'JJ'),
#  ('grant', 'NN'),
#  ('program', 'NN'),
#  ('design', 'NN'),
#  ('encourag', 'VBP'),
#  ('develop', 'VB'),
#  ('smart', 'JJ'),
#  ('citi', 'NN'),
#  ('resili', 'NN'),
#  ('commun', 'NN'),
#  ('program', 'NN'),
#  ('launch', 'NN'),
#  ('particip', 'NN'),
#  ('citi', 'JJ'),
#  ('support', 'NN'),
#  ('bank', 'NN'),
#  ('america', 'IN'),
#  ('charit', 'JJ'),
#  ('foundat', 'JJ'),
#  ('program', 'NN'),
#  ('expand', 'NN'),
#  ('citi', 'NN'),
#  ('commun', 'NN'),
#  ('includ', 'NN'),
#  ('accord', 'NN'),
#  ('announc', 'VBZ'),
#  ('releas', 'JJ'),
#  ('usgbc', 'JJ'),
#  ('today', 'NN'),
#  ('applic', 'JJ'),
#  ('citi', 'NN'),
#  ('seek', 'VBP'),
#  ('leed', 'NN'),
#  ('certiﬁc', 'NN'),
#  ('evalu', 'NN'),
#  ('demonstr', 'VBP'),
#  ('need', 'VBP'),
#  ('leadership', 'NN'),
#  ('support', 'NN'),
#  ('commit', 'NN'),
#  ('datadriven', 'RB'),
#  ('decisionmak', 'JJ'),
#  ('staff', 'NN'),
#  ('capac', 'NN'),
#  ('coordin', 'NN'),
#  ('local', 'JJ'),
#  ('initi', 'NN'),
#  ('citi', 'NN'),
#  ('sustain', 'VBP'),
#  ('action', 'NN'),
#  ('plan', 'NN'),
#  ('establish', 'VB'),
#  ('practic', 'JJ'),
#  ('track', 'NN'),
#  ('share', 'NN'),
#  ('data', 'NNS'),
#  ('consid', 'NN'),
#  ('asset', 'NN'),
#  ('applic', 'JJ'),
#  ('repres', 'VBZ'),
#  ('particip', 'JJ'),
#  ('citi', 'NNS'),
#  ('attend', 'VBP'),
#  ('person', 'NN'),
#  ('orient', 'JJ'),
#  ('usgbc', 'JJ'),
#  ('headquart', 'NN'),
#  ('washington', 'NN'),
#  ('earli', 'VBZ'),
#  ('june', 'JJ'),
#  ('usgbc', 'JJ'),
#  ('staff', 'NN'),
#  ('walk', 'VBP'),
#  ('commun', 'NN'),
#  ('rate', 'NN'),
#  ('system', 'NN'),
#  ('evalu', 'FW'),
#  ('measur', 'JJ'),
#  ('lead', 'NN'),
#  ('number', 'NN'),
#  ('hand', 'NN'),
#  ('exercis', 'VBZ'),
#  ('calcul', 'NN'),
#  ('score', 'NN'),
#  ('develop', 'VB'),
#  ('action', 'NN'),
#  ('plan', 'NN'),
#  ('year', 'NN'),
#  ('train', 'NN'),
#  ('citi', 'NN'),
#  ('commun', 'JJ'),
#  ('start', 'VBP'),
#  ('align', 'JJ'),
#  ('exist', 'VBP'),
#  ('program', 'NN'),
#  ('plan', 'NN'),
#  ('leed', 'VBP'),
#  ('rate', 'NN'),
#  ('system', 'NN'),
#  ('use', 'NN'),
#  ('project', 'NN'),
#  ('manag', 'NN'),
#  ('tool', 'NN'),
#  ('resourc', 'NN'),
#  ('provid', 'NN'),
#  ('usgbc', 'IN'),
#  ('gather', 'NN'),
#  ('data', 'NNS'),
#  ('evalu', 'VBP'),
#  ('measur', 'JJ'),
#  ('choic', 'NN'),
#  ('rate', 'NN'),
#  ('system', 'NN'),
#  ('enter', 'RBR'),
#  ('data', 'NNS'),
#  ('report', 'NN'),
#  ('tool', 'NN'),
#  ('cohort', 'RB'),
#  ('local', 'JJ'),
#  ('govern', 'JJ'),
#  ('meet', 'NN'),
#  ('regularli', 'NN'),
#  ('throughout', 'IN'),
#  ('year', 'NN'),
#  ('report', 'NN'),
#  ('progress', 'NN'),
#  ('share', 'NN'),
#  ('best', 'RBS'),
#  ('practic', 'JJ'),
#  ('learn', 'NN'),
#  ('usgbc', 'JJ'),
#  ('leed', 'NN'),
#  ('citi', 'JJ'),
#  ('commun', 'NN'),
#  ('program', 'NN'),
#  ('join', 'NN'),
#  ('green', 'JJ'),
#  ('build', 'NN'),
#  ('council', 'NN'),
#  ('leed', 'VBD'),
#  ('citi', 'JJ'),
#  ('commun', 'NN'),
#  ('program', 'NN'),
#  ('citi', 'NN'),
#  ('relat', 'JJ'),
#  ('categori', 'JJ'),
#  ('depart', 'NN'),
#  ('econom', 'NN'),
#  ('sustain', 'NN'),
#  ('develop', 'VB'),
#  ('morton', 'NN'),
#  ('connect', 'NN'),
#  ('facebook', 'NN'),
#  ('follow', 'VBP'),
#  ('twitter', 'NN'),
#  ('citi', 'NN'),
#  ('job', 'NN'),
#  ('subscrib', 'JJ'),
#  ('email', 'JJ'),
#  ('list', 'NN'),
#  ('polici', 'JJ'),
#  ('report', 'NN'),
#  ('problem', 'NN'),
#  ('citi', 'JJ'),
#  ('intranet', 'NN'),
#  ('home', 'NN'),
#  ('login', 'NN'),
#  ('citi', 'NN'),
#  ('util', 'JJ'),
#  ('move', 'NN'),
#  ('forward', 'RB'),
#  ('smart', 'JJ'),
#  ('meter', 'NN'),
#  ('instal', 'JJ'),
#  ('citi', 'NN'),
#  ('citi', 'NN'),
#  ('mayor', 'NN'),
#  ('john', 'NN'),
#  ('hamilton', 'NN'),
#  ('feedback', 'NN'),
#  ('type', 'NN'),
#  ('news', 'NN'),
#  ('releas', 'NNS'),
#  ('januari', 'VBP'),
#  ('citi', 'NN'),
#  ('util', 'JJ'),
#  ('move', 'NN'),
#  ('forward', 'RB'),
#  ('smart', 'JJ'),
#  ('meter', 'NN'),
#  ('instal', 'JJ'),
#  ('share', 'NN'),
#  ('miller', 'NN'),
#  ('januari', 'NN'),
#  ('inform', 'NN'),
#  ('pleas', 'NNS'),
#  ('contact', 'VBP'),
#  ('kelson', 'JJ'),
#  ('director', 'NN'),
#  ('citi', 'NN'),
#  ('util', 'JJ'),
#  ('kelsonvbloomington', 'NNP'),
#  ('citi', 'NN'),
#  ('util', 'JJ'),
#  ('move', 'NN'),
#  ('forward', 'RB'),
#  ('smart', 'JJ'),
#  ('meter', 'NN'),
#  ('instal', 'JJ'),
#  ('meet', 'NN'),
#  ('even', 'RB'),
#  ('util', 'JJ'),
#  ('servic', 'FW'),
#  ('board', 'NN'),
#  ('schedul', 'NN'),
#  ('consid', 'NN'),
#  ('million', 'CD'),
#  ('agreement', 'NN'),
#  ('util', 'JJ'),
#  ('meter', 'NN'),
#  ('solut', 'NN'),
#  ('overse', 'JJ'),
#  ('transit', 'NN'),
#  ('water', 'NN'),
#  ('meter', 'NN'),
#  ('advanc', 'NN'),
#  ('meter', 'NN'),
#  ('infrastructur', 'NN'),
#  ('approv', 'NN'),
#  ('contractor', 'NN'),
#  ('agent', 'NN'),
#  ('citi', 'NN'),
#  ('util', 'JJ'),
#  ('instal', 'JJ'),
#  ('meter', 'NN'),
#  ('softwar', 'JJ'),
#  ('conduct', 'NN'),
#  ('commun', 'NN'),
#  ('outreach', 'NN'),
#  ('measur', 'NN'),
#  ('ensur', 'VBP'),
#  ('smooth', 'JJ'),
#  ('convers', 'NNS'),
#  ('instal', 'JJ'),
#  ('anticip', 'JJ'),
#  ('complet', 'NN'),
#  ('march', 'NN'),
#  ('decemb', 'NN'),
#  ('citi', 'NN'),
#  ('council', 'NN'),
#  ('approv', 'NN'),
#  ('leasepurchas', 'FW'),
#  ('agreement', 'NN'),
#  ('fund', 'NN'),
#  ('implement', 'NN'),
#  ('system', 'NN'),
#  ('serv', 'JJ'),
#  ('custom', 'NN'),
#  ('integr', 'NN'),
#  ('system', 'NN'),
#  ('smart', 'JJ'),
#  ('meter', 'NN'),
#  ('commun', 'NN'),
#  ('network', 'NN'),
#  ('data', 'NNS'),
#  ('manag', 'NN'),
#  ('system', 'NN'),
#  ('enabl', 'JJ'),
#  ('commun', 'NN'),
#  ('util', 'JJ'),
#  ('custom', 'NN'),
#  ('system', 'NN'),
#  ('provid', 'JJ'),
#  ('number', 'NN'),
#  ('import', 'NN'),
#  ('function', 'NN'),
#  ('previous', 'JJ'),
#  ('possibl', 'NN'),
#  ('perform', 'NN'),
#  ('manual', 'JJ'),
#  ('includ', 'JJ'),
#  ('demand', 'NN'),
#  ('read', 'VBD'),
#  ('abil', 'JJ'),
#  ('measur', 'JJ'),
#  ('water', 'NN'),
#  ('usag', 'JJ'),
#  ('automat', 'NN'),
#  ('remot', 'NN'),
#  ('connect', 'NN'),
#  ('disconnect', 'NN'),
#  ('servic', 'NN'),
#  ('detect', 'JJ'),
#  ('tamper', 'NN'),
#  ('identifi', 'NN'),
#  ('isol', 'NN'),
#  ('pressur', 'NN'),
#  ('issu', 'NN'),
#  ('potenti', 'NN'),
#  ('leak', 'NN'),
#  ('util', 'JJ'),
#  ('custom', 'NN'),
#  ('access', 'NN'),
#  ('detail', 'NN'),
#  ('water', 'NN'),
#  ('usag', 'JJ'),
#  ('inform', 'NN'),
#  ('meter', 'NN'),
#  ('citi', 'NN'),
#  ('util', 'JJ'),
#  ('move', 'NN'),
#  ('forward', 'RB'),
#  ('smart', 'JJ'),
#  ('meter', 'NN'),
#  ('instal', 'JJ'),
#  ('citi', 'JJ'),
#  ('water', 'NN'),
#  ('meter', 'NN'),
#  ('ﬁrst', 'NNP'),
#  ('applic', 'NN'),
#  ('system', 'NN'),
#  ('serv', 'JJ'),
#  ('base', 'NN'),
#  ('station', 'NN'),
#  ('also', 'RB'),
#  ('serv', 'RB'),
#  ('high', 'JJ'),
#  ('secur', 'NN'),
#  ('radio', 'NN'),
#  ('commun', 'NN'),
#  ('network', 'NN'),
#  ('smart', 'JJ'),
#  ('citi', 'NN'),
#  ('applic', 'JJ'),
#  ('addit', 'NN'),
#  ('water', 'NN'),
#  ('meter', 'NN'),
#  ('network', 'NN'),
#  ('commun', 'JJ'),
#  ('smart', 'JJ'),
#  ('devic', 'NN'),
#  ('across', 'IN'),
#  ('citi', 'JJ'),
#  ('support', 'NN'),
#  ('futur', 'VBD'),
#  ('applic', 'JJ'),
#  ('coordin', 'NN'),
#  ('streamlin', 'NN'),
#  ('deliveri', 'NN'),
#  ('citi', 'NN'),
#  ('servic', 'JJ'),
#  ('applic', 'JJ'),
#  ('reduc', 'NN'),
#  ('environment', 'NN'),
#  ('impact', 'NN'),
#  ('improv', 'NN'),
#  ('data', 'NNS'),
#  ('qualiti', 'RB'),
#  ('overal', 'JJ'),
#  ('cost', 'NN'),
#  ('project', 'NN'),
#  ('includ', 'VBZ'),
#  ('conting', 'VBG'),
#  ('estim', 'JJ'),
#  ('million', 'CD'),
#  ('immedi', 'NN'),
#  ('beneﬁt', 'NN'),
#  ('modern', 'JJ'),
#  ('meter', 'NN'),
#  ('system', 'NN'),
#  ('heighten', 'JJ'),
#  ('efﬁcienc', 'JJ'),
#  ('abl', 'NN'),
#  ('respond', 'NN'),
#  ('infrastructur', 'NN'),
#  ('issu', 'NN'),
#  ('empow', 'NN'),
#  ('custom', 'NN'),
#  ('make', 'VBP'),
#  ('inform', 'NN'),
#  ('decis', 'NN'),
#  ('manag', 'NN'),
#  ('water', 'NN'),
#  ('consumpt', 'NN'),
#  ('said', 'VBD'),
#  ('mayor', 'NN'),
#  ('john', 'NN'),
#  ('hamilton', 'NN'),
#  ('beyond', 'IN'),
#  ('applic', 'JJ'),
#  ('water', 'NN'),
#  ('meter', 'NN'),
#  ('innov', 'NN'),
#  ('network', 'NN'),
#  ('like', 'IN'),
#  ('offer', 'NN'),
#  ('reach', 'VBP'),
#  ('potenti', 'JJ'),
#  ('creat', 'NN'),
#  ('efﬁcienc', 'NN'),
#  ('cost', 'NN'),
#  ('conserv', 'NN'),
#  ('natur', 'JJ'),
#  ('resourc', 'NN'),
#  ('meet', 'NN'),
#  ('everi', 'JJ'),
#  ('monday', 'NN'),
#  ('except', 'IN'),
#  ('citi', 'JJ'),
#  ('holiday', 'NN'),
#  ('util', 'JJ'),
#  ('servic', 'JJ'),
#  ('center', 'NN'),
#  ('miller', 'NN'),
#  ('drive', 'NN'),
#  ('everyon', 'NN'),
#  ('welcom', 'NN'),
#  ('time', 'NN'),
#  ('reserv', 'JJ'),
#  ('meet', 'NN'),
#  ('public', 'JJ'),
#  ('comment', 'NN'),
#  ('inform', 'NN'),
#  ('found', 'VBD'),
#  ('websit', 'NN'),
#  ('bloomingtonutil', 'NN'),
#  ('facebook', 'NN'),
#  ('page', 'NN'),
#  ('citi', 'NN'),
#  ('util', 'JJ'),
#  ('pictur', 'JJ'),
#  ('water', 'NN'),
#  ('meter', 'NN'),
#  ('iperl', 'NN'),
#  ('citi', 'NN'),
#  ('util', 'JJ'),
#  ('move', 'NN'),
#  ('forward', 'RB'),
#  ('smart', 'JJ'),
#  ('meter', 'NN'),
#  ('instal', 'JJ'),
#  ('citi', 'NN'),
#  ('relat', 'JJ'),
#  ('categori', 'JJ'),
#  ('depart', 'NN'),
#  ('util', 'JJ'),
#  ('depart', 'JJ'),
#  ('morton', 'NN'),
#  ('connect', 'NN'),
#  ('facebook', 'NN'),
#  ('follow', 'VBP'),
#  ('twitter', 'NN'),
#  ('citi', 'NN'),
#  ('job', 'NN'),
#  ('subscrib', 'JJ'),
#  ('email', 'JJ'),
#  ('list', 'NN'),
#  ('polici', 'JJ'),
#  ('report', 'NN'),
#  ('problem', 'NN'),
#  ('citi', 'JJ'),
#  ('intranet', 'NN'),
#  ('home', 'NN'),
#  ('login', 'NN'),
#  ('citi', 'NN'),
#  ('controversi', 'NN'),
#  ('onlin', 'NN'),
#  ('overdos', 'VBP'),
#  ('modifi', 'NN'),
#  ('follow', 'JJ'),
#  ('numer', 'RB'),
#  ('complaint', 'NN'),
#  ('american', 'JJ'),
#  ('citi', 'NN'),
#  ('counti', 'NNS'),
#  ('smart', 'VBP'),
#  ('citi', 'JJ'),
#  ('technolog', 'NN'),
#  ('technolog', 'NN'),
#  ('articl', 'NN'),
#  ('citi', 'NN'),
#  ('controversi', 'NN'),
#  ('onlin', 'NN'),
#  ('overdos', 'VBP'),
#  ('modi', 'NN'),
#  ('follow', 'JJ'),
#  ('numer', 'NN'),
#  ('complaint', 'NN'),
#  ('share', 'NN'),
#  ('inform', 'JJ'),
#  ('public', 'JJ'),
#  ('import', 'NN'),
#  ('function', 'NN'),
#  ('govern', 'JJ'),
#  ('sometim', 'NN'),
#  ('inform', 'NN'),
#  ('person', 'NN'),
#  ('share', 'NN'),
#  ('case', 'NN'),
#  ('ofﬁcial', 'JJ'),
#  ('began', 'VBD'),
#  ('track', 'JJ'),
#  ('opioid', 'JJ'),
#  ('overdos', 'NN'),
#  ('death', 'NN'),
#  ('onlin', 'NN'),
#  ('pinpoint', 'NN'),
#  ('address', 'NN'),
#  ('overdos', 'IN'),
#  ('victim', 'NN'),
#  ('within', 'IN'),
#  ('citi', 'JJ'),
#  ('limit', 'NN'),
#  ('written', 'VBN'),
#  ('jason', 'NN'),
#  ('axelrod', 'NN'),
#  ('juli', 'NN'),
#  ('share', 'NN'),
#  ('inform', 'JJ'),
#  ('public', 'JJ'),
#  ('import', 'NN'),
#  ('function', 'NN'),
#  ('govern', 'JJ'),
#  ('sometim', 'NN'),
#  ('inform', 'NN'),
#  ('person', 'NN'),
#  ('share', 'NN'),
#  ('controversi', 'JJ'),
#  ('onlin', 'NN'),
#  ('overdos', 'NN'),
#  ('modifi', 'NN'),
#  ('numer', 'JJ'),
#  ('complaint', 'NN'),
#  ('american', 'JJ'),
#  ('citi', 'NN'),
#  ('counti', 'NN'),
#  ('caseindiana', 'NN'),
#  ('whenciti', 'VBP'),
#  ('ofﬁcial', 'JJ'),
#  ('beganfollow', 'NN'),
#  ('track', 'NN'),
#  ('opioid', 'JJ'),
#  ('overdos', 'JJ'),
#  ('death', 'NN'),
#  ('onlin', 'NN'),
#  ('pinpoint', 'NN'),
#  ('address', 'NN'),
#  ('overdos', 'IN'),
#  ('victim', 'NN'),
#  ('within', 'IN'),
#  ('citi', 'JJ'),
#  ('limit', 'NN'),
#  ('accord', 'NN'),
#  ('public', 'JJ'),
#  ('media', 'NNS'),
#  ('critic', 'JJ'),
#  ('mount', 'NN'),
#  ('peopl', 'NN'),
#  ('across', 'IN'),
#  ('monro', 'NN'),
#  ('counti', 'NN'),
#  ('citi', 'VBP'),
#  ('ofﬁcial', 'JJ'),
#  ('alter', 'NN'),
#  ('juli', 'NN'),
#  ('display', 'NN'),
#  ('street', 'NN'),
#  ('address', 'JJ'),
#  ('instead', 'RB'),
#  ('show', 'VBP'),
#  ('overdos', 'JJ'),
#  ('locat', 'NN'),
#  ('resid', 'NN'),
#  ('busi', 'VBZ'),
#  ('public', 'JJ'),
#  ('properti', 'NN'),
#  ('radio', 'NN'),
#  ('station', 'NN'),
#  ('wbiw', 'WRB'),
#  ('report', 'NN'),
#  ('launch', 'VBZ'),
#  ('march', 'JJ'),
#  ('part', 'NN'),
#  ('reveal', 'VBZ'),
#  ('public', 'JJ'),
#  ('inform', 'NN'),
#  ('transpar', 'NN'),
#  ('site', 'NN'),
#  ('mayor', 'NN'),
#  ('ofﬁc', 'JJ'),
#  ('innov', 'NN'),
#  ('creat', 'NN'),
#  ('accord', 'NN'),
#  ('wbiw', 'NN'),
#  ('best', 'JJS'),
#  ('recip', 'NN'),
#  ('success', 'NN'),
#  ('term', 'NN'),
#  ('address', 'NN'),
#  ('problem', 'NN'),
#  ('make', 'VBP'),
#  ('data', 'NNS'),
#  ('access', 'NN'),
#  ('commun', 'NN'),
#  ('director', 'NN'),
#  ('yael', 'NN'),
#  ('ksander', 'NN'),
#  ('told', 'VBD'),
#  ('indianapoli', 'JJ'),
#  ('station', 'NN'),
#  ('wthr', 'NN'),
#  ('resid', 'VBP'),
#  ('ofﬁcial', 'JJ'),
#  ('alik', 'NN'),
#  ('react', 'NN'),
#  ('neg', 'IN'),
#  ('heather', 'JJR'),
#  ('harlow', 'NN'),
#  ('uncl', 'NN'),
#  ('john', 'NN'),
#  ('harlow', 'JJ'),
#  ('pass', 'NN'),
#  ('away', 'RB'),
#  ('drug', 'NN'),
#  ('overdos', 'NNS'),
#  ('three', 'CD'),
#  ('year', 'NN'),
#  ('harlow', 'NN'),
#  ('grandpar', 'NN'),
#  ('home', 'NN'),
#  ('harlow', 'NN'),
#  ('voic', 'NN'),
#  ('concern', 'NN'),
#  ('viewer', 'NN'),
#  ('could', 'MD'),
#  ('grandpar', 'VB'),
#  ('hous', 'JJ'),
#  ('list', 'NN'),
#  ('wthr', 'JJ'),
#  ('report', 'NN'),
#  ('construct', 'NN'),
#  ('way', 'NN'),
#  ('display', 'NN'),
#  ('inform', 'NN'),
#  ('pinpoint', 'NN'),
#  ('peopl', 'NN'),
#  ('individu', 'NN'),
#  ('home', 'NN'),
#  ('told', 'VBD'),
#  ('wthr', 'JJ'),
#  ('ad', 'NN'),
#  ('ensur', 'NN'),
#  ('peopl', 'NN'),
#  ('safeti', 'NN'),
#  ('greater', 'JJR'),
#  ('issu', 'JJ'),
#  ('hide', 'NN'),
#  ('statist', 'NN'),
#  ('monro', 'NN'),
#  ('counti', 'JJ'),
#  ('commission', 'NN'),
#  ('amanda', 'NN'),
#  ('clerk', 'NN'),
#  ('barg', 'NN'),
#  ('took', 'VBD'),
#  ('facebook', 'NN'),
#  ('vent', 'NN'),
#  ('frustrat', 'NN'),
#  ('critic', 'JJ'),
#  ('ofﬁcial', 'JJ'),
#  ('justiﬁc', 'NN'),
#  ('use', 'NN'),
#  ('govern', 'JJ'),
#  ('resourc', 'NN'),
#  ('post', 'NN'),
#  ('privat', 'NN'),
#  ('health', 'NN'),
#  ('inform', 'NN'),
#  ('also', 'RB'),
#  ('show', 'VBP'),
#  ('type', 'JJ'),
#  ('drug', 'NN'),
#  ('victim', 'NN'),
#  ('overdos', 'NN'),
#  ('instead', 'RB'),
#  ('barg', 'NN'),
#  ('said', 'VBD'),
#  ('resourc', 'NN'),
#  ('use', 'NN'),
#  ('educ', 'JJ'),
#  ('govern', 'JJ'),
#  ('leader', 'NN'),
#  ('substanc', 'NN'),
#  ('abus', 'NN'),
#  ('govern', 'VBP'),
#  ('need', 'MD'),
#  ('stop', 'VB'),
#  ('treat', 'NN'),
#  ('peopl', 'JJ'),
#  ('diseas', 'NNS'),
#  ('horriﬁc', 'VBP'),
#  ('mindset', 'VBN'),
#  ('encourag', 'JJ'),
#  ('shame', 'NN'),
#  ('invad', 'NN'),
#  ('privaci', 'NN'),
#  ('someon', 'NN'),
#  ('courag', 'NN'),
#  ('help', 'NN'),
#  ('call', 'VB'),
#  ('barg', 'JJ'),
#  ('wrote', 'VBD'),
#  ('facebook', 'NN'),
#  ('post', 'NN'),
#  ('citi', 'JJ'),
#  ('leader', 'NN'),
#  ('justiﬁ', 'NNS'),
#  ('say', 'VBP'),
#  ('make', 'VBP'),
#  ('public', 'JJ'),
#  ('inform', 'NN'),
#  ('access', 'NN'),
#  ('public', 'JJ'),
#  ('proxim', 'NN'),
#  ('overdos', 'NNS'),
#  ('make', 'VBP'),
#  ('matter', 'NN'),
#  ('meaning', 'NN'),
#  ('resid', 'NN'),
#  ('death', 'NN'),
#  ('happen', 'VB'),
#  ('public', 'JJ'),
#  ('place', 'NN'),
#  ('like', 'IN'),
#  ('park', 'NN'),
#  ('public', 'JJ'),
#  ('facil', 'NN'),
#  ('happen', 'VB'),
#  ('resid', 'NN'),
#  ('resid', 'NN'),
#  ('next', 'JJ'),
#  ('door', 'NN'),
#  ('bring', 'NN'),
#  ('home', 'NN'),
#  ('ksander', 'NN'),
#  ('told', 'VBD'),
#  ('wthr', 'JJ'),
#  ('howev', 'JJ'),
#  ('ofﬁcial', 'JJ'),
#  ('behavior', 'NN'),
#  ('health', 'NN'),
#  ('group', 'NN'),
#  ('juli', 'NN'),
#  ('discuss', 'NN'),
#  ('juli', 'NN'),
#  ('mayor', 'NN'),
#  ('john', 'NN'),
#  ('hamilton', 'NN'),
#  ('announc', 'NN'),
#  ('citi', 'NN'),
#  ('would', 'MD'),
#  ('chang', 'VB'),
#  ('display', 'NN'),
#  ('speciﬁc', 'NN'),
#  ('address', 'NN'),
#  ('inform', 'NN'),
#  ('within', 'IN'),
#  ('accord', 'JJ'),
#  ('public', 'JJ'),
#  ('media', 'NNS'),
#  ('wbiw', 'VBP'),
#  ('howev', 'JJ'),
#  ('speciﬁc', 'NN'),
#  ('address', 'NN'),
#  ('inform', 'NN'),
#  ('still', 'RB'),
#  ('publicli', 'JJ'),
#  ('avail', 'NN'),
#  ('download', 'NN'),
#  ('site', 'NN'),
#  ('differ', 'VBP'),
#  ('part', 'NN'),
#  ('site', 'NN'),
#  ('share', 'NN'),
#  ('controversi', 'JJ'),
#  ('overdos', 'NN'),
#  ('mapar', 'NN'),
#  ('modifi', 'NN'),
#  ('follow', 'VBP'),
#  ('numer', 'RB'),
#  ('complaint', 'JJ'),
#  ('american', 'JJ'),
#  ('citi', 'NN'),
#  ('andtoward', 'RB'),
#  ('counti', 'VBZ'),
#  ('public', 'JJ'),
#  ('datac', 'NN'),
#  ('whereonlin', 'NN'),
#  ('death', 'NN'),
#  ('occur', 'NN'),
#  ('help', 'NN'),
#  ('give', 'VB'),
#  ('work', 'NN'),
#  ('solut', 'NN'),
#  ('tool', 'NN'),
#  ('help', 'NN'),
#  ('suffer', 'VB'),
#  ('mayor', 'NN'),
#  ('john', 'NN'),
#  ('hamilton', 'NN'),
#  ('said', 'VBD'),
#  ('citi', 'JJ'),
#  ('news', 'NN'),
#  ('releas', 'NNS'),
#  ('time', 'NN'),
#  ('understand', 'JJ'),
#  ('sensit', 'NN'),
#  ('issu', 'NN'),
#  ('done', 'VBN'),
#  ('sinc', 'NN'),
#  ('launch', 'NN'),
#  ('site', 'NN'),
#  ('continu', 'NN'),
#  ('consult', 'NN'),
#  ('front', 'JJ'),
#  ('line', 'NN'),
#  ('crisi', 'NN'),
#  ('follow', 'VBP'),
#  ('best', 'JJS'),
#  ('practic', 'JJ'),
#  ('connect', 'NN'),
#  ('stay', 'NN'),
#  ('date', 'NN'),
#  ('similar', 'JJ'),
#  ...]

# %% [markdown]
# ##### 3) save nouns, verbs, and adjectives

# %%
nouns = [word for word,tag in tagged_keywords if tag in ['NN','NNP','NNS','NNPS']]
verbs = [word for word,tag in tagged_keywords if tag in ['VB','VBD','VBG','VBN','VBP','VBZ'] and not word in nouns]
adjs = [word for word,tag in tagged_keywords if tag in ['JJ','JJR','JJS']]

# %% [markdown]
# count POS frequency and save into dataframes

# %%
nouns_frequency = Counter(ngrams(nouns, 1)).most_common()
verbs_frequency = Counter(ngrams(verbs, 1)).most_common()
adjs_frequency = Counter(ngrams(adjs, 1)).most_common()

# %%
nouns_frequency_pd = pd.DataFrame(nouns_frequency, columns=['nouns', 'nouns'])
verbs_frequency_pd = pd.DataFrame(verbs_frequency, columns=['counts', 'verbs'])
adjs_frequency_pd = pd.DataFrame(adjs_frequency, columns=['counts', 'adjs'])

# %% [markdown]
# ### Section 6: Count bi-gram frequency

# %%
bigram_frequency = Counter(ngrams(keywords, 2)).most_common()
bigram_frequency
# Out:
# [(('bike', 'lane'), 796),
#  (('neighborhood', 'greenway'), 619),
#  (('greenway', 'neighborhood'), 486),
#  (('protected', 'bike'), 395),
#  (('state', 'road'), 348),
#  (('multi‐', 'path'), 338),
#  (('lane', 'protected'), 327),
#  (('consolidated', 'plan'), 307),
#  (('plan', 'control'), 251),
#  (('lane', 'multi‐'), 242),
#  (('monroe', 'county'), 239),
#  (('affordable', 'housing'), 227),
#  (('path', 'bike'), 210),
#  (('road', 'state'), 168),
#  (('lane', 'bike'), 157),
#  (('comprehensive', 'plan'), 150),
#  (('housing', 'problems'), 148),
#  (('walnut', 'walnut'), 147),
#  (('housing', 'units'), 111),
#  (('dunn', 'dunn'), 108),
#  (('lead', 'agency'), 104),
#  (('bike', 'lanes'), 94),
#  (('rogers', 'rogers'), 92),
#  (('road', 'bypass'), 87),
#  (('data', 'source'), 87),
#  (('complete', 'streets'), 86),
#  (('lincoln', 'lincoln'), 86),
#  (('grant', 'grant'), 83),
#  (('path', 'multi‐'), 81),
#  (('public', 'housing'), 79),
#  (('economic', 'development'), 75),
#  (('attached', 'attached'), 75),
#  (('solid', 'waste'), 72),
#  (('smith', 'smith'), 72),
#  (('quality', 'life'), 68),
#  (('parks', 'recreation'), 68),
#  (('henderson', 'henderson'), 66),
#  (('madison', 'madison'), 65),
#  (('cost', 'burden'), 64),
#  (('social', 'service'), 63),
#  (('street', 'parking'), 63),
#  (('multiuse', 'path'), 61),
#  (('public', 'works'), 58),
#  (('bypass', 'state'), 58),
#  (('bicycle', 'pedestrian'), 57),
#  (('housing', 'authority'), 57),
#  (('washington', 'washington'), 57),
#  (('accessed', 'june'), 57),
#  (('four', 'housing'), 56),
#  (('common', 'council'), 55),
#  (('land', 'development'), 55),
#  (('bicycle', 'friendly'), 55),
#  (('pike', 'pike'), 55),
#  (('individuals', 'families'), 54),
#  (('transportation', 'network'), 54),
#  (('fairview', 'fairview'), 54),
#  (('college', 'mall'), 53),
#  (('housing', 'neighborhood'), 53),
#  (('transportation', 'plan'), 53),
#  (('park', 'park'), 53),
#  (('neighborhood', 'development'), 52),
#  (('bicycle', 'facility'), 52),
#  (('woodlawn', 'woodlawn'), 52),
#  (('special', 'needs'), 52),
#  (('task', 'force'), 51),
#  (('college', 'walnut'), 51),
#  (('sare', 'sare'), 51),
#  (('status', 'level'), 51),
#  (('provide', 'funding'), 51),
#  (('development', 'department'), 50),
#  (('community', 'development'), 50),
#  (('climate', 'change'), 49),
#  (('open', 'source'), 48),
#  (('info', 'items'), 48),
#  (('five', 'years'), 47),
#  (('median', 'income'), 47),
#  (('rental', 'assistance'), 47),
#  (('public', 'transit'), 46),
#  (('city', 'utilities'), 45),
#  (('planning', 'department'), 45),
#  (('short', 'short'), 45),
#  (('shall', 'minimum'), 45),
#  (('multimodal', 'transportation'), 43),
#  (('transportation', 'system'), 43),
#  (('kirkwood', 'kirkwood'), 43),
#  (('general', 'fund'), 43),
#  (('hillside', 'hillside'), 43),
#  (('maple', 'maple'), 43),
#  (('within', 'city'), 42),
#  (('walnut', 'street'), 42),
#  (('motor', 'vehicle'), 42),
#  (('area', 'median'), 42),
#  (('rental', 'units'), 42),
#  (('public', 'facilities'), 41),
#  (('active', 'transportation'), 41),
#  (('neighborhood', 'residential'), 41),
#  (('park', 'ridge'), 41),
#  (('‐line', 'trail'), 41),
#  (('supportive', 'housing'), 40),
#  (('kinser', 'pike'), 40),
#  (('fess', 'fess'), 40),
#  (('estimated', 'costs'), 40),
#  (('homeless', 'individuals'), 40),
#  (('vision', 'statement'), 39),
#  (('energy', 'efficiency'), 39),
#  (('income', 'housing'), 39),
#  (('site', 'design'), 39),
#  (('college', 'college'), 39),
#  (('jordan', 'jordan'), 39),
#  (('greenhouse', 'emissions'), 38),
#  (('green', 'infrastructure'), 38),
#  (('bicycle', 'facilities'), 38),
#  (('bicycle', 'network'), 38),
#  (('tenant', 'based'), 38),
#  (('greater', 'need'), 38),
#  (('sustainable', 'development'), 37),
#  (('downtown', 'area'), 37),
#  (('leonard', 'springs'), 37),
#  (('general', 'urban'), 37),
#  (('rock', 'creek'), 37),
#  (('renewable', 'energy'), 36),
#  (('action', 'plan'), 36),
#  (('local', 'food'), 36),
#  (('university', 'university'), 36),
#  (('public', 'transportation'), 36),
#  (('land', 'uses'), 36),
#  (('street', 'trees'), 36),
#  (('pedestrian', 'bicycle'), 36),
#  (('blvd', 'blvd'), 36),
#  (('development', 'approvals'), 35),
#  (('yard', 'waste'), 35),
#  (('morton', 'morton'), 35),
#  (('number', 'type'), 35),
#  (('city', 'council'), 34),
#  (('environmental', 'commission'), 34),
#  (('mental', 'health'), 34),
#  (('south', 'central'), 34),
#  (('start', 'description'), 34),
#  (('olcott', 'blvd'), 34),
#  (('source', 'chas'), 34),
#  (('city', 'limits'), 33),
#  (('public', 'health'), 33),
#  (('community', 'members'), 33),
#  (('street', 'street'), 33),
#  (('walnut', 'college'), 33),
#  (('community', 'center'), 33),
#  (('shared', 'street'), 33),
#  (('monroe', 'monroe'), 33),
#  (('greenway', 'appendix'), 33),
#  (('maxwell', 'maxwell'), 33),
#  (('severe', 'housing'), 33),
#  (('policy', 'decisions'), 33),
#  (('economic', 'sustainable'), 32),
#  (('walking', 'biking'), 32),
#  (('health', 'care'), 32),
#  (('city', 'continue'), 32),
#  (('needs', 'assessment'), 32),
#  (('infrastructure', 'improvements'), 32),
#  (('moores', 'pike'), 32),
#  (('financial', 'assistance'), 32),
#  (('lacks', 'complete'), 32),
#  (('green', 'building'), 31),
#  (('housing', 'needs'), 31),
#  (('master', 'plan'), 31),
#  (('high', 'school'), 31),
#  (('league', 'american'), 31),
#  (('american', 'bicyclists'), 31),
#  (('trees', 'landscaping'), 31),
#  (('jackson', 'jackson'), 31),
#  (('mayor', 'john'), 30),
#  (('local', 'government'), 30),
#  (('profit', 'organizations'), 30),
#  (('water', 'quality'), 30),
#  (('city', 'hall'), 30),
#  (('public', 'service'), 30),
#  (('cottage', 'grove'), 30),
#  (('minimum', 'yield'), 30),
#  (('domestic', 'violence'), 30),
#  (('housing', 'network'), 30),
#  (('income', 'none'), 30),
#  (('john', 'hamilton'), 29),
#  (('local', 'businesses'), 29),
#  (('ages', 'abilities'), 29),
#  (('community', 'survey'), 29),
#  (('programs', 'services'), 29),
#  (('public', 'private'), 29),
#  (('bicycle', 'parking'), 29),
#  (('friendly', 'community'), 29),
#  (('urban', 'services'), 29),
#  (('shalom', 'community'), 29),
#  (('pete', 'ellis'), 29),
#  (('homeless', 'persons'), 29),
#  (('chronically', 'homeless'), 29),
#  (('families', 'children'), 29),
#  (('mailed', 'survey'), 29),
#  (('started', 'started'), 29),
#  (('built', 'environment'), 28),
#  (('housing', 'options'), 28),
#  (('moderate', 'income'), 28),
#  (('shall', 'provided'), 28),
#  (('improve', 'existing'), 28),
#  (('accessed', 'july'), 28),
#  (('indicators', 'status'), 28),
#  (('jack', 'hopkins'), 28),
#  (('complete', 'plumbing'), 28),
#  (('negative', 'income'), 28),
#  (('disproportionately', 'greater'), 28),
#  (('plan', 'city'), 27),
#  (('social', 'services'), 27),
#  (('housing', 'market'), 27),
#  (('line', 'trail'), 27),
#  (('city', 'facilities'), 27),
#  (('main', 'street'), 27),
#  (('housing', 'community'), 27),
#  (('going', 'going'), 27),
#  (('open', 'data'), 27),
#  (('african', 'american'), 27),
#  (('pacific', 'islander'), 27),
#  (('neighborhood', 'connector'), 27),
#  (('suburban', 'connector'), 27),
#  (('walnut', 'grove'), 27),
#  (('rockport', 'rockport'), 27),
#  (('thornton', 'thornton'), 27),
#  (('comments', 'received'), 27),
#  (('grant', 'program'), 26),
#  (('united', 'states'), 26),
#  (('city', 'housing'), 26),
#  (('transit', 'service'), 26),
#  (('city', 'transportation'), 26),
#  (('outdoor', 'market'), 26),
#  (('service', 'delivery'), 26),
#  (('police', 'department'), 26),
#  (('stands', 'stands'), 26),
#  (('union', 'union'), 26),
#  (('morningside', 'morningside'), 26),
#  (('costs', 'lead'), 26),
#  (('outreach', 'program'), 26),
#  (('kitchen', 'facilities'), 26),
#  (('housing', 'assistance'), 26),
#  (('historic', 'preservation'), 25),
#  (('housing', 'stock'), 25),
#  (('drinking', 'water'), 25),
#  (('experiencing', 'homelessness'), 25),
#  (('transportation', 'planning'), 25),
#  (('summit', 'view'), 25),
#  (('winslow', 'winslow'), 25),
#  (('based', 'rental'), 25),
#  (('central', 'housing'), 25),
#  (('operations', 'infrastructure'), 25),
#  (('community', 'services'), 24),
#  (('safe', 'efficient'), 24),
#  (('year', 'year'), 24),
#  (('convention', 'center'), 24),
#  (('traffic', 'calming'), 24),
#  (('physical', 'activity'), 24),
#  (('pleasant', 'ridge'), 24),
#  (('winston', 'winston'), 24),
#  (('department', 'support'), 24),
#  (('works', 'parks'), 24),
#  (('none', 'four'), 24),
#  (('problems', 'household'), 24),
#  (('household', 'negative'), 24),
#  (('none', 'housing'), 24),
#  (('info', 'info'), 24),
#  (('items', 'info'), 24),
#  (('city', 'city'), 23),
#  (('urban', 'village'), 23),
#  (('plan', 'commission'), 23),
#  (('pedestrian', 'safety'), 23),
#  (('community', 'health'), 23),
#  (('meet', 'needs'), 23),
#  (('residents', 'businesses'), 23),
#  (('unified', 'development'), 23),
#  (('service', 'agencies'), 23),
#  (('focus', 'area'), 23),
#  (('market', 'analysis'), 23),
#  (('motor', 'vehicles'), 23),
#  (('traffic', 'flow'), 23),
#  (('education', 'campaigns'), 23),
#  (('fire', 'department'), 23),
#  (('accessed', 'august'), 23),
#  (('streets', 'exempt'), 23),
#  (('kinser', 'kinser'), 23),
#  (('ridge', 'park'), 23),
#  (('road', 'ramp'), 23),
#  (('ramp', 'state'), 23),
#  (('bike', 'work'), 23),
#  (('profit', 'developers'), 23),
#  (('citizen', 'participation'), 23),
#  (('problems', 'none'), 23),
#  (('need', 'housing'), 23),
#  (('persons', 'households'), 23),
#  (('transitional', 'housing'), 23),
#  (('program', 'type'), 23),
#  (('goal', 'name'), 23),
#  (('local', 'economy'), 22),
#  (('number', 'households'), 22),
#  (('trades', 'district'), 22),
#  (('technology', 'park'), 22),
#  (('racial', 'ethnic'), 22),
#  (('city', 'operations'), 22),
#  (('existing', 'structures'), 22),
#  (('thoroughfare', 'plan'), 22),
#  (('allen', 'allen'), 22),
#  (('american', 'asian'), 22),
#  (('respect', 'integrity'), 22),
#  (('integrity', 'service'), 22),
#  (('service', 'excellence'), 22),
#  (('description', 'capacity'), 22),
#  (('wylie', 'farm'), 22),
#  (('forrest', 'forrest'), 22),
#  (('hunter', 'hunter'), 22),
#  (('sheridan', 'sheridan'), 22),
#  (('high', 'high'), 22),
#  (('hillsdale', 'hillsdale'), 22),
#  (('strategy', 'chapter'), 22),
#  (('miss', 'mplementation'), 22),
#  (('program', 'manager'), 22),
#  (('risk', 'homelessness'), 22),
#  (('unaccompanied', 'youth'), 22),
#  (('community', 'kitchen'), 22),
#  (('white', 'black'), 22),
#  (('black', 'african'), 22),
#  (('native', 'pacific'), 22),
#  (('comm', 'energytransport'), 22),
#  (('energytransport', 'transportation'), 22),
#  (('best', 'practices'), 21),
#  (('water', 'meters'), 21),
#  (('high', 'quality'), 21),
#  (('housing', 'choice'), 21),
#  (('planning', 'design'), 21),
#  (('housing', 'cost'), 21),
#  (('funds', 'used'), 21),
#  (('breaking', 'away'), 21),
#  (('next', 'five'), 21),
#  (('provide', 'assistance'), 21),
#  (('social', 'worker'), 21),
#  (('traffic', 'volumes'), 21),
#  (('delivery', 'trucks'), 21),
#  (('clarizz', 'blvd'), 21),
#  (('adams', 'adams'), 21),
#  (('rose', 'rose'), 21),
#  (('rosewood', 'rosewood'), 21),
#  (('graham', 'graham'), 21),
#  (('southdowns', 'southdowns'), 21),
#  (('winslow', 'farm'), 21),
#  (('springs', 'leonard'), 21),
#  (('sheffield', 'sheffield'), 21),
#  (('action', 'items'), 21),
#  (('mplementation', 'strategy'), 21),
#  (('owneroccupied', 'rental'), 21),
#  (('improvement', 'public'), 21),
#  (('service', 'assistance'), 21),
#  (('complete', 'kitchen'), 21),
#  (('total', 'table'), 21),
#  (('developer', 'subsidy'), 21),
#  (('transportation', 'options'), 20),
#  (('census', 'bureau'), 20),
#  (('wastewater', 'treatment'), 20),
#  (('health', 'hospital'), 20),
#  (('policy', 'guidance'), 20),
#  (('income', 'households'), 20),
#  (('employment', 'centers'), 20),
#  (('walking', 'bicycling'), 20),
#  (('shall', 'mounted'), 20),
#  (('body', 'shall'), 20),
#  (('travel', 'lanes'), 20),
#  (('connector', 'street'), 20),
#  (('american', 'indian'), 20),
#  (('indian', 'alaska'), 20),
#  (('alaska', 'native'), 20),
#  (('highland', 'highland'), 20),
#  (('meadowbrook', 'meadowbrook'), 20),
#  (('bryan', 'bryan'), 20),
#  (('ramble', 'ramble'), 20),
#  (('redefining', 'prosperity'), 20),
#  (('final', 'miss'), 20),
#  (('level', 'action'), 20),
#  (('agency', 'support'), 20),
#  (('permanently', 'supportive'), 20),
#  (('accessibility', 'modifications'), 20),
#  (('hopkins', 'council'), 20),
#  (('council', 'social'), 20),
#  (('victims', 'domestic'), 20),
#  (('asian', 'american'), 20),
#  (('target', 'area'), 20),
#  (('valign', 'width'), 20),
#  (('substance', 'abuse'), 19),
#  (('goals', 'policies'), 19),
#  (('growth', 'policies'), 19),
#  (('economic', 'impact'), 19),
#  (('development', 'activity'), 19),
#  (('policy', 'encourage'), 19),
#  (('development', 'ordinance'), 19),
#  (('reduce', 'emissions'), 19),
#  (('clear', 'creek'), 19),
#  (('housing', 'programs'), 19),
#  (('senior', 'housing'), 19),
#  (('master', 'thoroughfare'), 19),
#  (('background', 'intent'), 19),
#  (('short', 'going'), 19),
#  (('advisory', 'committee'), 19),
#  (('street', 'typologies'), 19),
#  (('neighborhood', 'greenways'), 19),
#  (('street', 'typology'), 19),
#  (('bike', 'parking'), 19),
#  (('access', 'drive'), 19),
#  (('allendale', 'allendale'), 19),
#  (('covenanter', 'covenanter'), 19),
#  (('renwick', 'blvd'), 19),
#  (('hawthorne', 'hawthorne'), 19),
#  (('creek', 'rock'), 19),
#  (('provide', 'financial'), 19),
#  (('middle', 'house'), 19),
#  (('inspection', 'program'), 19),
#  (('last', 'modified'), 19),
#  (('services', 'comm'), 19),
#  (('comm', 'energystationary'), 19),
#  (('connect', 'facebook'), 18),
#  (('follow', 'twitter'), 18),
#  (('public', 'places'), 18),
#  (('planning', 'transportation'), 18),
#  (('policies', 'plan'), 18),
#  (('development', 'redevelopment'), 18),
#  (('natural', 'environment'), 18),
#  (('population', 'growth'), 18),
#  (('multifamily', 'residential'), 18),
#  (('american', 'community'), 18),
#  (('increase', 'number'), 18),
#  (('project', 'name'), 18),
#  (('located', 'within'), 18),
#  (('residential', 'rental'), 18),
#  (('disease', 'control'), 18),
#  (('journey', 'platinum'), 18),
#  (('street', 'grid'), 18),
#  (('going', 'short'), 18),
#  (('public', 'education'), 18),
#  (('sanitation', 'division'), 18),
#  (('resource', 'officers'), 18),
#  (('priority', 'areas'), 18),
#  (('multimodal', 'projects'), 18),
#  (('extension', 'extend'), 18),
#  (('trail', '‐line'), 18),
#  (('bloomfield', 'bloomfield'), 18),
#  (('wylie', 'wylie'), 18),
#  (('evaluation', 'planning'), 18),
#  (('bike', 'summit'), 18),
#  (('improve', 'infrastructure'), 18),
#  (('funding', 'profit'), 18),
#  (('families', 'families'), 18),
#  (('homeless', 'special'), 18),
#  (('problems', 'table'), 18),
#  (('problems', 'lacks'), 18),
#  (('jurisdiction', 'whole'), 18),
#  (('whole', 'white'), 18),
#  (('islander', 'hispanic'), 18),
#  (('plumbing', 'facilities'), 18),
#  (('housing', 'residents'), 18),
#  (('service', 'grant'), 18),
#  (('leadbased', 'paint'), 18),
#  (('educational', 'attainment'), 18),
#  (('action', 'lead'), 18),
#  (('thinking', 'thinking'), 18),
#  (('throughout', 'city'), 17),
#  (('food', 'production'), 17),
#  (('certified', 'technology'), 17),
#  (('character', 'areas'), 17),
#  (('housing', 'types'), 17),
#  (('workforce', 'housing'), 17),
#  (('platinum', 'biking'), 17),
#  (('biking', 'task'), 17),
#  (('street', 'design'), 17),
#  (('pedestrians', 'bicyclists'), 17),
#  (('dodds', 'dodds'), 17),
#  (('smart', 'water'), 17),
#  (('global', 'outdoor'), 17),
#  (('general', 'news'), 17),
#  (('yield', 'steel'), 17),
#  (('figure', 'shows'), 17),
#  (('county', 'metropolitan'), 17),
#  (('streets', 'compliant'), 17),
#  (('streets', 'pending'), 17),
#  (('valley', 'forge'), 17),
#  (('spicewood', 'spicewood'), 17),
#  (('sweetbriar', 'sweetbriar'), 17),
#  (('bicycle', 'club'), 17),
#  (('public', 'comments'), 17),
#  (('final', 'chapter'), 17),
#  (('support', 'planning'), 17),
#  (('agency', 'planning'), 17),
#  (('profit', 'profit'), 17),
#  (('create', 'improve'), 17),
#  (('assistance', 'provide'), 17),
#  (('owneroccupied', 'rehabilitation'), 17),
#  (('name', 'goal'), 17),
#  (('goal', 'description'), 17),
#  (('lead', 'partners'), 17),
#  (('timeframe', 'cost'), 17),
#  (('water', 'conservation'), 17),
#  (('invasive', 'species'), 17),
#  (('infrastructure', 'govt'), 17),
#  (('wide', 'variety'), 16),
#  (('utilities', 'department'), 16),
#  (('regional', 'activity'), 16),
#  (('focus', 'areas'), 16),
#  (('public', 'services'), 16),
#  (('waste', 'management'), 16),
#  (('city', 'government'), 16),
#  (('bike', 'share'), 16),
#  (('control', 'prevention'), 16),
#  (('activity', 'centers'), 16),
#  (('grove', 'cottage'), 16),
#  (('mayor', 'hamilton'), 16),
#  (('width', 'feet'), 16),
#  (('labor', 'force'), 16),
#  (('corridor', 'study'), 16),
#  (('planning', 'organization'), 16),
#  (('bike', 'traffic'), 16),
#  (('greenway', 'bike'), 16),
#  (('lane', 'neighborhood'), 16),
#  (('atwater', 'atwater'), 16),
#  (('lane', 'appendix'), 16),
#  (('palmer', 'palmer'), 16),
#  (('patterson', 'patterson'), 16),
#  (('skyline', 'skyline'), 16),
#  (('lindbergh', 'lindbergh'), 16),
#  (('tamarack', 'tamarack'), 16),
#  (('moores', 'moores'), 16),
#  (('tapp', 'tapp'), 16),
#  (('westminster', 'westminster'), 16),
#  (('health', 'promotion'), 16),
#  (('environmental', 'harmony'), 16),
#  (('economic', 'resiliency'), 16),
#  (('team', 'pursuit'), 16),
#  (('pursuit', 'platinum'), 16),
#  (('platinum', 'estimated'), 16),
#  (('assist', 'profit'), 16),
#  (('technical', 'assistance'), 16),
#  (('development', 'affordable'), 16),
#  (('heading', 'home'), 16),
#  (('make', 'homelessness'), 16),
#  (('street', 'social'), 16),
#  (('ethnic', 'group'), 16),
#  (('problems', 'jurisdiction'), 16),
#  (('facilities', 'lacks'), 16),
#  (('room', 'cost'), 16),
#  (('boys', 'girls'), 16),
#  (('girls', 'club'), 16),
#  (('barriers', 'affordable'), 16),
#  (('buildings', 'facilities'), 16),
#  (('decisions', 'govt'), 16),
#  (('facebook', 'follow'), 15),
#  (('employment', 'center'), 15),
#  (('chamber', 'commerce'), 15),
#  (('city', 'staff'), 15),
#  (('public', 'meeting'), 15),
#  (('environmental', 'quality'), 15),
#  (('needs', 'community'), 15),
#  (('household', 'income'), 15),
#  (('supportive', 'services'), 15),
#  (('energy', 'consumption'), 15),
#  (('city', 'common'), 15),
#  (('cost', 'housing'), 15),
#  (('housing', 'projects'), 15),
#  (('housing', 'housing'), 15),
#  (('federal', 'highway'), 15),
#  (('highway', 'administration'), 15),
#  (('physical', 'inactivity'), 15),
#  (('away', 'journey'), 15),
#  (('public', 'right'), 15),
#  (('year', 'total'), 15),
#  (('street', 'network'), 15),
#  (('west', 'side'), 15),
#  (('avenue', 'walnut'), 15),
#  (('short', 'hand'), 15),
#  (('market', 'segmentation'), 15),
#  (('needs', 'city'), 15),
#  (('road', 'user'), 15),
#  (('unit', 'shall'), 15),
#  (('would', 'like'), 15),
#  (('metropolitan', 'planning'), 15),
#  (('urban', 'street'), 15),
#  (('shared', 'streets'), 15),
#  (('facility', 'type'), 15),
#  (('income', 'individuals'), 15),
#  (('interested', 'concerned'), 15),
#  (('cobble', 'creek'), 15),
#  (('wilson', 'wilson'), 15),
#  (('tamarron', 'tamarron'), 15),
#  (('mitchell', 'mitchell'), 15),
#  (('willis', 'willis'), 15),
#  (('platinum', 'bike'), 15),
#  (('time', 'trials'), 15),
#  (('trials', 'five'), 15),
#  (('five', 'priorities'), 15),
#  (('platinum', 'resources'), 15),
#  (('assistance', 'owneroccupied'), 15),
#  (('homeless', 'risk'), 15),
#  (('owner', 'total'), 15),
#  (('estimate', 'number'), 15),
#  (('emergency', 'shelter'), 15),
#  (('chas', 'four'), 15),
#  (('campaigns', 'comm'), 15),
#  (('□', '□'), 15),
#  (('policies', 'programs'), 14),
#  (('city', 'comprehensive'), 14),
#  (('public', 'engagement'), 14),
#  (('student', 'housing'), 14),
#  (('water', 'treatment'), 14),
#  (('continue', 'provide'), 14),
#  (('rental', 'properties'), 14),
#  (('open', 'space'), 14),
#  (('city', 'departments'), 14),
#  (('open', 'spaces'), 14),
#  (('safe', 'routes'), 14),
#  (('routes', 'school'), 14),
#  (('volunteers', 'medicine'), 14),
#  (('public', 'space'), 14),
#  (('fossil', 'fuels'), 14),
#  (('city', 'environmental'), 14),
#  (('food', 'agriculture'), 14),
#  (('parking', 'lots'), 14),
#  (('lake', 'monroe'), 14),
#  (('miles', 'traveled'), 14),
#  (('development', 'housing'), 14),
#  (('throughout', 'community'), 14),
#  (('address', 'needs'), 14),
#  (('multifamily', 'housing'), 14),
#  (('rental', 'housing'), 14),
#  (('transit', 'routes'), 14),
#  (('community', 'resources'), 14),
#  (('income', 'levels'), 14),
#  (('transportation', 'infrastructure'), 14),
#  (('transportation', 'needs'), 14),
#  (('streets', 'policy'), 14),
#  (('bicycle', 'infrastructure'), 14),
#  (('downtown', 'businesses'), 14),
#  (('total', 'number'), 14),
#  (('provide', 'additional'), 14),
#  (('within', 'district'), 14),
#  (('college', 'avenue'), 14),
#  (('dunn', 'grant'), 14),
#  (('hand', 'short'), 14),
#  (('\uf017', 'june'), 14),
#  (('source', 'software'), 14),
#  (('large', 'item'), 14),
#  (('municipal', 'code'), 14),
#  (('committee', 'members'), 14),
#  (('shall', 'installed'), 14),
#  (('geographic', 'area'), 14),
#  (('excellence', 'fire'), 14),
#  (('pedestrian', 'priority'), 14),
#  (('high', 'traffic'), 14),
#  (('typical', 'crosssection'), 14),
#  (('residential', 'street'), 14),
#  (('project', 'team'), 14),
#  (('side', 'road'), 14),
#  (('project', 'based'), 14),
#  (('path', 'appendix'), 14),
#  (('basswood', 'basswood'), 14),
#  (('southern', 'oaks'), 14),
#  (('farm', 'winslow'), 14),
#  (('olcott', 'olcott'), 14),
#  (('summit', 'summit'), 14),
#  (('depar', 'tment'), 14),
#  (('type', 'silver'), 14),
#  (('number', 'number'), 14),
#  (('development', 'block'), 14),
#  (('block', 'grant'), 14),
#  (('persons', 'aids'), 14),
#  (('elderly', 'disabled'), 14),
#  (('facilities', 'services'), 14),
#  (('plan', 'make'), 14),
#  (('homelessness', 'rare'), 14),
#  (('rare', 'brief'), 14),
#  (('summary', 'comments'), 14),
#  (('experienced', 'homelessness'), 14),
#  (('control', 'housing'), 14),
#  (('hamfi', 'hamfi'), 14),
#  (('hispanic', 'four'), 14),
#  (('disabilities', 'persons'), 14),
#  (('delivery', 'system'), 14),
#  (('needs', 'addressed'), 14),
#  (('units', 'improve'), 14),
#  (('metric', 'tons'), 14),
#  (('ordinance', 'changes'), 14),
#  (('responsible', 'party'), 14),
#  (('time', 'frame'), 14),
#  (('industrial', 'residential'), 14),
#  (('total', 'cost'), 14),
#  (('news', 'release'), 13),
#  (('sustainability', 'action'), 13),
#  (('department', 'economic'), 13),
#  (('subscribe', 'email'), 13),
#  (('executive', 'summary'), 13),
#  (('county', 'community'), 13),
#  (('wide', 'range'), 13),
#  (('health', 'safety'), 13),
#  (('future', 'development'), 13),
#  (('including', 'limited'), 13),
#  (('role', 'regional'), 13),
#  (('green', 'space'), 13),
#  (('efficient', 'accessible'), 13),
#  (('single', 'family'), 13),
#  (('parks', 'trails'), 13),
#  (('neighborhood', 'associations'), 13),
#  (('public', 'spaces'), 13),
#  (('organizations', 'provide'), 13),
#  (('urban', 'ecology'), 13),
#  (('peak', 'task'), 13),
#  (('energy', 'challenge'), 13),
#  (('million', 'gallons'), 13),
#  (('greenhouse', 'gases'), 13),
#  (('carbon', 'dioxide'), 13),
#  (('improve', 'quality'), 13),
#  (('vehicle', 'miles'), 13),
#  (('housing', 'development'), 13),
#  (('design', 'guide'), 13),
#  (('housing', 'supportive'), 13),
#  (('travel', 'time'), 13),
#  (('pedestrian', 'transportation'), 13),
#  (('parking', 'street'), 13),
#  (('streets', 'sidewalks'), 13),
#  (('parks', 'open'), 13),
#  (('development', 'review'), 13),
#  (('residential', 'uses'), 13),
#  (('traffic', 'volume'), 13),
#  (('grant', 'lincoln'), 13),
#  (('program', 'general'), 13),
#  (('fund', 'support'), 13),
#  (('goal', 'city'), 13),
#  (('estimated', 'capital'), 13),
#  (('system', 'shall'), 13),
#  (('food', 'waste'), 13),
#  (('east', 'street'), 13),
#  (('plan', 'recommends'), 13),
#  (('bloomingtonmonroe', 'county'), 13),
#  (('pedestrian', 'activity'), 13),
#  (('street', 'candidate'), 13),
#  (('candidate', 'streets'), 13),
#  (('south', 'bend'), 13),
#  (('vulnerable', 'road'), 13),
#  (('country', 'club'), 13),
#  (('dunn', 'street'), 13),
#  (('grove', 'walnut'), 13),
#  (('twin', 'oaks'), 13),
#  (('bell', 'trace'), 13),
#  (('blvd', 'olcott'), 13),
#  (('countryside', 'countryside'), 13),
#  (('heatherwood', 'heatherwood'), 13),
#  (('moss', 'creek'), 13),
#  (('needs', 'identified'), 13),
#  (('agency', 'public'), 13),
#  (('partners', 'action'), 13),
#  (('year', 'platinum'), 13),
#  (('costs', 'none'), 13),
#  (('owneroccupied', 'homes'), 13),
#  (('income', 'individualsfamilies'), 13),
#  (('construction', 'affordable'), 13),
#  (('brief', 'nonrepeating'), 13),
#  (('children', 'veterans'), 13),
#  (('attached', 'mailed'), 13),
#  (('positive', 'link'), 13),
#  (('facilities', 'persons'), 13),
#  (('total', 'owner'), 13),
#  (('type', 'families'), 13),
#  (('based', 'special'), 13),
#  (('special', 'purpose'), 13),
#  (('purpose', 'voucher'), 13),
#  (('voucher', 'veterans'), 13),
#  (('veterans', 'family'), 13),
#  (('choice', 'voucher'), 13),
#  (('bedroom', 'bedroom'), 13),
#  (('case', 'management'), 13),
#  (('buildings', 'energy'), 13),
#  (('urban', 'forest'), 13),
#  (('items', 'started'), 13),
#  (('problem', 'city'), 12),
#  (('across', 'city'), 12),
#  (('community', 'school'), 12),
#  (('school', 'corporation'), 12),
#  (('development', 'corporation'), 12),
#  (('natural', 'systems'), 12),
#  (('plan', 'also'), 12),
#  (('community', 'role'), 12),
#  (('plan', 'chapter'), 12),
#  (('following', 'vision'), 12),
#  (('public', 'safety'), 12),
#  (('objective', 'provide'), 12),
#  (('provide', 'safe'), 12),
#  (('city', 'community'), 12),
#  (('arts', 'entertainment'), 12),
#  (('treatment', 'plant'), 12),
#  (('areas', 'city'), 12),
#  (('policies', 'chapter'), 12),
#  (('community', 'college'), 12),
#  (('facilities', 'public'), 12),
#  (('locally', 'owned'), 12),
#  (('county', 'convention'), 12),
#  (('village', 'centers'), 12),
#  (('city', 'sanitation'), 12),
#  (('number', 'units'), 12),
#  (('autonomous', 'vehicles'), 12),
#  (('extremely', 'income'), 12),
#  (('department', 'hand'), 12),
#  (('accessory', 'dwelling'), 12),
#  (('dwelling', 'units'), 12),
#  (('improve', 'access'), 12),
#  (('high', 'density'), 12),
#  (('services', 'community'), 12),
#  (('condition', 'housing'), 12),
#  (('census', 'block'), 12),
#  (('transit', 'stops'), 12),
#  (('improve', 'safety'), 12),
#  (('bicyclists', 'pedestrians'), 12),
#  (('survey', 'year'), 12),
#  (('access', 'transit'), 12),
#  (('vehicle', 'traffic'), 12),
#  (('activity', 'center'), 12),
#  (('multiuse', 'paths'), 12),
#  (('improved', 'coordination'), 12),
#  (('washington', 'walnut'), 12),
#  (('city', 'general'), 12),
#  (('short', 'parks'), 12),
#  (('education', 'outreach'), 12),
#  (('segmentation', 'analysis'), 12),
#  (('analysis', 'recent'), 12),
#  (('recent', 'trends'), 12),
#  (('trends', 'development'), 12),
#  (('development', 'growth'), 12),
#  (('growth', 'trending'), 12),
#  (('trending', 'regions'), 12),
#  (('capital', 'recovery'), 12),
#  (('sanitation', 'services'), 12),
#  (('capital', 'costs'), 12),
#  (('lights', 'shall'), 12),
#  (('agencies', 'provide'), 12),
#  (('planning', 'approach'), 12),
#  (('facility', 'types'), 12),
#  (('roadway', 'connections'), 12),
#  (('high', 'volumes'), 12),
#  (('bicycle', 'lanes'), 12),
#  (('street', 'neighborhood'), 12),
#  (('medium', 'high'), 12),
#  (('center', 'turn'), 12),
#  (('path', 'protected'), 12),
#  (('capacity', 'expansion'), 12),
#  (('curry', 'pike'), 12),
#  (('description', 'capital'), 12),
#  (('capital', 'assistance'), 12),
#  (('illinois', 'illinois'), 12),
#  (('arlington', 'arlington'), 12),
#  (('delila', 'star'), 12),
#  (('copper', 'beech'), 12),
#  (('street', 'pike'), 12),
#  (('romans', 'romans'), 12),
#  (('davis', 'davis'), 12),
#  (('grimes', 'grimes'), 12),
#  (('pike', 'kinser'), 12),
#  (('jefferson', 'jefferson'), 12),
#  (('longview', 'longview'), 12),
#  (('miller', 'miller'), 12),
#  (('ridge', 'pleasant'), 12),
#  (('sugar', 'maple'), 12),
#  (('view', 'summit'), 12),
#  (('woodburn', 'woodburn'), 12),
#  (('chapter', 'team'), 12),
#  (('alta', 'planning'), 12),
#  (('none', 'none'), 12),
#  (('action', 'status'), 12),
#  (('crawford', 'apartments'), 12),
#  (('payment', 'closing'), 12),
#  (('closing', 'cost'), 12),
#  (('cost', 'assistance'), 12),
#  (('shelter', 'care'), 12),
#  (('home', 'regional'), 12),
#  (('regional', 'plan'), 12),
#  (('survey', 'mailed'), 12),
#  (('burden', 'greater'), 12),
#  (('total', 'project'), 12),
#  (('waiting', 'list'), 12),
#  (('households', 'persons'), 12),
#  (('needs', 'populations'), 12),
#  (('bachelor', 'degree'), 12),
#  (('housing', 'unit'), 12),
#  (('risk', 'assessments'), 12),
#  (('targeted', 'homeless'), 12),
#  (('school', 'graduate'), 12),
#  (('priority', 'needs'), 12),
#  (('subsidy', 'owneroccupied'), 12),
#  (('personal', 'communication'), 12),
#  (('similar', 'action'), 12),
#  (('government', 'industrial'), 12),
#  (('residential', 'unknown'), 12),
#  (('cities', 'communities'), 11),
#  (('program', 'city'), 11),
#  (('city', 'mayor'), 11),
#  (('hamilton', 'feedback'), 11),
#  (('feedback', 'type'), 11),
#  (('please', 'contact'), 11),
#  (('related', 'categories'), 11),
#  (('morton', 'connect'), 11),
#  (('twitter', 'city'), 11),
#  (('city', 'jobs'), 11),
#  (('jobs', 'subscribe'), 11),
#  (('email', 'lists'), 11),
#  (('policy', 'report'), 11),
#  (('report', 'problem'), 11),
#  (('city', 'intranet'), 11),
#  (('utilities', 'service'), 11),
#  (('statement', 'objectives'), 11),
#  (('housing', 'neighborhoods'), 11),
#  (('village', 'center'), 11),
#  (('community', 'resilience'), 11),
#  (('city', 'planning'), 11),
#  (('regional', 'economic'), 11),
#  (('enhance', 'community'), 11),
#  (('community', 'assets'), 11),
#  (('quality', 'public'), 11),
#  (('population', 'density'), 11),
#  (('bureau', 'american'), 11),
#  (('year', 'estimates'), 11),
#  (('current', 'housing'), 11),
#  (('data', 'collection'), 11),
#  (('city', 'parks'), 11),
#  (('services', 'provided'), 11),
#  (('within', 'mile'), 11),
#  (('incentive', 'programs'), 11),
#  (('university', 'campus'), 11),
#  (('energy', 'sources'), 11),
#  (('sanitary', 'sewer'), 11),
#  (('city', 'university'), 11),
#  (('planning', 'efforts'), 11),
#  (('support', 'local'), 11),
#  (('housing', 'developments'), 11),
#  (('housing', 'opportunities'), 11),
#  (('facilities', 'provide'), 11),
#  (('working', 'group'), 11),
#  (('traffic', 'congestion'), 11),
#  (('design', 'elements'), 11),
#  (('shall', 'include'), 11),
#  (('block', 'group'), 11),
#  (('centers', 'disease'), 11),
#  (('traffic', 'signals'), 11),
#  (('existing', 'transportation'), 11),
#  (('residential', 'streets'), 11),
#  (('parking', 'spaces'), 11),
#  (('stop', 'signs'), 11),
#  (('traffic', 'safety'), 11),
#  (('traffic', 'patterns'), 11),
#  (('provide', 'access'), 11),
#  (('level', 'service'), 11),
#  (('redevelopment', 'projects'), 11),
#  (('used', 'development'), 11),
#  (('community', 'needs'), 11),
#  (('chapter', 'apply'), 11),
#  (('lincoln', 'washington'), 11),
#  (('general', 'action'), 11),
#  (('action', 'expected'), 11),
#  (('expected', 'timeline'), 11),
#  (('timeline', 'policy'), 11),
#  (('policy', 'lead'), 11),
#  (('lead', 'department'), 11),
#  (('department', 'short'), 11),
#  (('short', 'long'), 11),
#  (('long', 'ordinance'), 11),
#  (('ordinance', 'agency'), 11),
#  (('agency', 'going'), 11),
#  (('going', 'legislation'), 11),
#  (('study', 'plan'), 11),
#  (('interagency', 'coordination'), 11),
#  (('ongoing', 'public'), 11),
#  (('hate', 'bias'), 11),
#  (('bias', 'crime'), 11),
#  (('daily', 'student'), 11),
#  (('road', 'sidewalk'), 11),
#  (('development', 'needs'), 11),
#  (('community', 'foundation'), 11),
#  (('city', 'employees'), 11),
#  (('past', 'five'), 11),
#  (('shall', 'furnished'), 11),
#  (('shall', 'delivered'), 11),
#  (('gauge', 'minimum'), 11),
#  (('minimum', 'gauge'), 11),
#  (('next', 'steps'), 11),
#  (('washington', 'lincoln'), 11),
#  (('blue', 'ridge'), 11),
#  (('pedestrian', 'zone'), 11),
#  (('streets', 'would'), 11),
#  (('connector', 'general'), 11),
#  (('provide', 'connection'), 11),
#  (('greenway', 'protected'), 11),
#  (('jackson', 'creek'), 11),
#  (('ashwood', 'ashwood'), 11),
#  (('gourley', 'pike'), 11),
#  (('sunny', 'slopes'), 11),
#  (('club', 'house'), 11),
#  (('clark', 'clark'), 11),
#  (('vaughn', 'clipp'), 11),
#  (('overhill', 'overhill'), 11),
#  ...]

# %%
bigram_frequency_pd = pd.DataFrame(bigram_frequency, columns=['counts', 'words'])
bigram_frequency_pd = bigram_frequency_pd[['words','counts']]

# %% [markdown]
# ### Section 7: count 3-gram frequency

# %%
trigram_frequency = Counter(ngrams(keywords, 3)).most_common()
trigram_frequency
# Out:
# [(('neighborhood', 'greenway', 'neighborhood'), 486),
#  (('greenway', 'neighborhood', 'greenway'), 486),
#  (('protected', 'bike', 'lane'), 371),
#  (('lane', 'protected', 'bike'), 327),
#  (('bike', 'lane', 'protected'), 326),
#  (('consolidated', 'plan', 'control'), 250),
#  (('bike', 'lane', 'multi‐'), 242),
#  (('lane', 'multi‐', 'path'), 242),
#  (('path', 'bike', 'lane'), 203),
#  (('multi‐', 'path', 'bike'), 202),
#  (('state', 'road', 'state'), 168),
#  (('road', 'state', 'road'), 163),
#  (('bike', 'lane', 'bike'), 157),
#  (('lane', 'bike', 'lane'), 157),
#  (('walnut', 'walnut', 'walnut'), 119),
#  (('dunn', 'dunn', 'dunn'), 92),
#  (('state', 'road', 'bypass'), 87),
#  (('multi‐', 'path', 'multi‐'), 81),
#  (('path', 'multi‐', 'path'), 81),
#  (('rogers', 'rogers', 'rogers'), 77),
#  (('lincoln', 'lincoln', 'lincoln'), 73),
#  (('grant', 'grant', 'grant'), 68),
#  (('affordable', 'housing', 'units'), 63),
#  (('smith', 'smith', 'smith'), 63),
#  (('road', 'bypass', 'state'), 58),
#  (('bypass', 'state', 'road'), 58),
#  (('four', 'housing', 'problems'), 56),
#  (('henderson', 'henderson', 'henderson'), 54),
#  (('housing', 'neighborhood', 'development'), 52),
#  (('attached', 'attached', 'attached'), 52),
#  (('madison', 'madison', 'madison'), 51),
#  (('woodlawn', 'woodlawn', 'woodlawn'), 49),
#  (('pike', 'pike', 'pike'), 48),
#  (('washington', 'washington', 'washington'), 45),
#  (('fairview', 'fairview', 'fairview'), 41),
#  (('park', 'park', 'park'), 41),
#  (('area', 'median', 'income'), 40),
#  (('neighborhood', 'development', 'department'), 38),
#  (('sare', 'sare', 'sare'), 38),
#  (('maple', 'maple', 'maple'), 37),
#  (('hillside', 'hillside', 'hillside'), 35),
#  (('data', 'source', 'chas'), 34),
#  (('neighborhood', 'greenway', 'appendix'), 33),
#  (('severe', 'housing', 'problems'), 33),
#  (('economic', 'sustainable', 'development'), 32),
#  (('jordan', 'jordan', 'jordan'), 32),
#  (('league', 'american', 'bicyclists'), 31),
#  (('college', 'college', 'college'), 31),
#  (('mayor', 'john', 'hamilton'), 29),
#  (('shalom', 'community', 'center'), 29),
#  (('fess', 'fess', 'fess'), 29),
#  (('morton', 'morton', 'morton'), 29),
#  (('bicycle', 'friendly', 'community'), 28),
#  (('kirkwood', 'kirkwood', 'kirkwood'), 28),
#  (('indicators', 'status', 'level'), 28),
#  (('disproportionately', 'greater', 'need'), 28),
#  (('blvd', 'blvd', 'blvd'), 26),
#  (('costs', 'lead', 'agency'), 26),
#  (('tenant', 'based', 'rental'), 25),
#  (('based', 'rental', 'assistance'), 25),
#  (('south', 'central', 'housing'), 25),
#  (('central', 'housing', 'network'), 25),
#  (('maxwell', 'maxwell', 'maxwell'), 24),
#  (('public', 'works', 'parks'), 24),
#  (('works', 'parks', 'recreation'), 24),
#  (('none', 'four', 'housing'), 24),
#  (('housing', 'problems', 'household'), 24),
#  (('problems', 'household', 'negative'), 24),
#  (('household', 'negative', 'income'), 24),
#  (('negative', 'income', 'none'), 24),
#  (('income', 'none', 'housing'), 24),
#  (('none', 'housing', 'problems'), 24),
#  (('housing', 'community', 'development'), 24),
#  (('info', 'info', 'items'), 24),
#  (('info', 'items', 'info'), 24),
#  (('items', 'info', 'items'), 24),
#  (('protected', 'bike', 'lanes'), 23),
#  (('complete', 'streets', 'exempt'), 23),
#  (('monroe', 'monroe', 'monroe'), 23),
#  (('park', 'ridge', 'park'), 23),
#  (('state', 'road', 'ramp'), 23),
#  (('road', 'ramp', 'state'), 23),
#  (('ramp', 'state', 'road'), 23),
#  (('housing', 'problems', 'none'), 23),
#  (('problems', 'none', 'four'), 23),
#  (('city', 'housing', 'neighborhood'), 22),
#  (('university', 'university', 'university'), 22),
#  (('short', 'short', 'short'), 22),
#  (('respect', 'integrity', 'service'), 22),
#  (('integrity', 'service', 'excellence'), 22),
#  (('morningside', 'morningside', 'morningside'), 22),
#  (('rockport', 'rockport', 'rockport'), 22),
#  (('union', 'union', 'union'), 22),
#  (('winston', 'winston', 'winston'), 22),
#  (('homeless', 'individuals', 'families'), 22),
#  (('white', 'black', 'african'), 22),
#  (('black', 'african', 'american'), 22),
#  (('native', 'pacific', 'islander'), 22),
#  (('comm', 'energytransport', 'transportation'), 22),
#  (('next', 'five', 'years'), 21),
#  (('jackson', 'jackson', 'jackson'), 21),
#  (('leonard', 'springs', 'leonard'), 21),
#  (('springs', 'leonard', 'springs'), 21),
#  (('ridge', 'park', 'ridge'), 21),
#  (('miss', 'mplementation', 'strategy'), 21),
#  (('mplementation', 'strategy', 'chapter'), 21),
#  (('improvement', 'public', 'facilities'), 21),
#  (('social', 'service', 'agencies'), 20),
#  (('street', 'trees', 'landscaping'), 20),
#  (('american', 'indian', 'alaska'), 20),
#  (('indian', 'alaska', 'native'), 20),
#  (('kinser', 'kinser', 'kinser'), 20),
#  (('thornton', 'thornton', 'thornton'), 20),
#  (('final', 'miss', 'mplementation'), 20),
#  (('lead', 'agency', 'support'), 20),
#  (('permanently', 'supportive', 'housing'), 20),
#  (('public', 'service', 'assistance'), 20),
#  (('jack', 'hopkins', 'council'), 20),
#  (('hopkins', 'council', 'social'), 20),
#  (('victims', 'domestic', 'violence'), 20),
#  (('unified', 'development', 'ordinance'), 19),
#  (('master', 'thoroughfare', 'plan'), 19),
#  (('african', 'american', 'asian'), 19),
#  (('allen', 'allen', 'allen'), 19),
#  (('forrest', 'forrest', 'forrest'), 19),
#  (('hillsdale', 'hillsdale', 'hillsdale'), 19),
#  (('rock', 'creek', 'rock'), 19),
#  (('creek', 'rock', 'creek'), 19),
#  (('sheffield', 'sheffield', 'sheffield'), 19),
#  (('winslow', 'winslow', 'winslow'), 19),
#  (('status', 'level', 'action'), 19),
#  (('american', 'asian', 'american'), 19),
#  (('alaska', 'native', 'pacific'), 19),
#  (('programs', 'services', 'comm'), 19),
#  (('growth', 'policies', 'plan'), 18),
#  (('american', 'community', 'survey'), 18),
#  (('land', 'development', 'approvals'), 18),
#  (('allendale', 'allendale', 'allendale'), 18),
#  (('‐line', 'trail', '‐line'), 18),
#  (('trail', '‐line', 'trail'), 18),
#  (('provide', 'funding', 'profit'), 18),
#  (('funding', 'profit', 'organizations'), 18),
#  (('homeless', 'special', 'needs'), 18),
#  (('housing', 'problems', 'table'), 18),
#  (('housing', 'problems', 'lacks'), 18),
#  (('jurisdiction', 'whole', 'white'), 18),
#  (('whole', 'white', 'black'), 18),
#  (('pacific', 'islander', 'hispanic'), 18),
#  (('council', 'social', 'service'), 18),
#  (('social', 'service', 'grant'), 18),
#  (('within', 'city', 'limits'), 17),
#  (('certified', 'technology', 'park'), 17),
#  (('platinum', 'biking', 'task'), 17),
#  (('biking', 'task', 'force'), 17),
#  (('minimum', 'yield', 'steel'), 17),
#  (('complete', 'streets', 'compliant'), 17),
#  (('complete', 'streets', 'pending'), 17),
#  (('bryan', 'bryan', 'bryan'), 17),
#  (('graham', 'graham', 'graham'), 17),
#  (('highland', 'highland', 'highland'), 17),
#  (('rose', 'rose', 'rose'), 17),
#  (('sheridan', 'sheridan', 'sheridan'), 17),
#  (('stands', 'stands', 'stands'), 17),
#  (('lead', 'agency', 'planning'), 17),
#  (('profit', 'profit', 'developers'), 17),
#  (('create', 'improve', 'infrastructure'), 17),
#  (('asian', 'american', 'indian'), 17),
#  (('public', 'housing', 'residents'), 17),
#  (('goal', 'name', 'goal'), 17),
#  (('name', 'goal', 'description'), 17),
#  (('action', 'lead', 'partners'), 17),
#  (('operations', 'infrastructure', 'govt'), 17),
#  (('cottage', 'grove', 'cottage'), 16),
#  (('grove', 'cottage', 'grove'), 16),
#  (('global', 'outdoor', 'market'), 16),
#  (('neighborhood', 'greenway', 'bike'), 16),
#  (('bike', 'lane', 'neighborhood'), 16),
#  (('lane', 'neighborhood', 'greenway'), 16),
#  (('bloomfield', 'bloomfield', 'bloomfield'), 16),
#  (('bike', 'lane', 'appendix'), 16),
#  (('hawthorne', 'hawthorne', 'hawthorne'), 16),
#  (('high', 'high', 'high'), 16),
#  (('team', 'pursuit', 'platinum'), 16),
#  (('provide', 'financial', 'assistance'), 16),
#  (('racial', 'ethnic', 'group'), 16),
#  (('housing', 'problems', 'jurisdiction'), 16),
#  (('problems', 'jurisdiction', 'whole'), 16),
#  (('problems', 'lacks', 'complete'), 16),
#  (('lacks', 'complete', 'kitchen'), 16),
#  (('complete', 'kitchen', 'facilities'), 16),
#  (('kitchen', 'facilities', 'lacks'), 16),
#  (('facilities', 'lacks', 'complete'), 16),
#  (('lacks', 'complete', 'plumbing'), 16),
#  (('complete', 'plumbing', 'facilities'), 16),
#  (('room', 'cost', 'burden'), 16),
#  (('boys', 'girls', 'club'), 16),
#  (('barriers', 'affordable', 'housing'), 16),
#  (('policy', 'decisions', 'govt'), 16),
#  (('facebook', 'follow', 'twitter'), 15),
#  (('city', 'common', 'council'), 15),
#  (('federal', 'highway', 'administration'), 15),
#  (('breaking', 'away', 'journey'), 15),
#  (('away', 'journey', 'platinum'), 15),
#  (('smart', 'water', 'meters'), 15),
#  (('metropolitan', 'planning', 'organization'), 15),
#  (('greenway', 'bike', 'lane'), 15),
#  (('adams', 'adams', 'adams'), 15),
#  (('atwater', 'atwater', 'atwater'), 15),
#  (('moores', 'moores', 'moores'), 15),
#  (('wylie', 'wylie', 'wylie'), 15),
#  (('time', 'trials', 'five'), 15),
#  (('trials', 'five', 'priorities'), 15),
#  (('pursuit', 'platinum', 'resources'), 15),
#  (('agency', 'planning', 'department'), 15),
#  (('homeless', 'risk', 'homelessness'), 15),
#  (('street', 'social', 'worker'), 15),
#  (('chronically', 'homeless', 'individuals'), 15),
#  (('families', 'families', 'children'), 15),
#  (('source', 'chas', 'four'), 15),
#  (('improve', 'existing', 'structures'), 15),
#  (('education', 'campaigns', 'comm'), 15),
#  (('connect', 'facebook', 'follow'), 14),
#  (('city', 'comprehensive', 'plan'), 14),
#  (('safe', 'routes', 'school'), 14),
#  (('city', 'environmental', 'commission'), 14),
#  (('housing', 'cost', 'burden'), 14),
#  (('disease', 'control', 'prevention'), 14),
#  (('avenue', 'walnut', 'street'), 14),
#  (('outdoor', 'market', 'segmentation'), 14),
#  (('service', 'excellence', 'fire'), 14),
#  (('excellence', 'fire', 'department'), 14),
#  (('multi‐', 'path', 'appendix'), 14),
#  (('winslow', 'farm', 'winslow'), 14),
#  (('rosewood', 'rosewood', 'rosewood'), 14),
#  (('spicewood', 'spicewood', 'spicewood'), 14),
#  (('public', 'comments', 'received'), 14),
#  (('platinum', 'estimated', 'costs'), 14),
#  (('community', 'development', 'block'), 14),
#  (('development', 'block', 'grant'), 14),
#  (('plan', 'make', 'homelessness'), 14),
#  (('make', 'homelessness', 'rare'), 14),
#  (('homelessness', 'rare', 'brief'), 14),
#  (('plan', 'control', 'housing'), 14),
#  (('hispanic', 'four', 'housing'), 14),
#  (('housing', 'units', 'improve'), 14),
#  (('units', 'improve', 'existing'), 14),
#  (('sustainability', 'action', 'plan'), 13),
#  (('department', 'economic', 'sustainable'), 13),
#  (('monroe', 'county', 'community'), 13),
#  (('peak', 'task', 'force'), 13),
#  (('complete', 'streets', 'policy'), 13),
#  (('pedestrian', 'priority', 'areas'), 13),
#  (('county', 'metropolitan', 'planning'), 13),
#  (('general', 'urban', 'street'), 13),
#  (('street', 'candidate', 'streets'), 13),
#  (('blvd', 'olcott', 'blvd'), 13),
#  (('dodds', 'dodds', 'dodds'), 13),
#  (('hunter', 'hunter', 'hunter'), 13),
#  (('lindbergh', 'lindbergh', 'lindbergh'), 13),
#  (('farm', 'winslow', 'farm'), 13),
#  (('ramble', 'ramble', 'ramble'), 13),
#  (('southdowns', 'southdowns', 'southdowns'), 13),
#  (('sweetbriar', 'sweetbriar', 'sweetbriar'), 13),
#  (('westminster', 'westminster', 'westminster'), 13),
#  (('lead', 'agency', 'public'), 13),
#  (('estimated', 'costs', 'none'), 13),
#  (('rare', 'brief', 'nonrepeating'), 13),
#  (('attached', 'mailed', 'survey'), 13),
#  (('total', 'owner', 'total'), 13),
#  (('estimate', 'number', 'type'), 13),
#  (('number', 'type', 'families'), 13),
#  (('tenant', 'based', 'special'), 13),
#  (('based', 'special', 'purpose'), 13),
#  (('special', 'purpose', 'voucher'), 13),
#  (('purpose', 'voucher', 'veterans'), 13),
#  (('voucher', 'veterans', 'family'), 13),
#  (('housing', 'choice', 'voucher'), 13),
#  (('info', 'items', 'started'), 13),
#  (('□', '□', '□'), 13),
#  (('county', 'community', 'school'), 12),
#  (('community', 'school', 'corporation'), 12),
#  (('economic', 'development', 'corporation'), 12),
#  (('community', 'role', 'regional'), 12),
#  (('following', 'vision', 'statement'), 12),
#  (('land', 'development', 'activity'), 12),
#  (('city', 'utilities', 'department'), 12),
#  (('college', 'avenue', 'walnut'), 12),
#  (('going', 'going', 'going'), 12),
#  (('market', 'segmentation', 'analysis'), 12),
#  (('segmentation', 'analysis', 'recent'), 12),
#  (('analysis', 'recent', 'trends'), 12),
#  (('recent', 'trends', 'development'), 12),
#  (('trends', 'development', 'growth'), 12),
#  (('development', 'growth', 'trending'), 12),
#  (('growth', 'trending', 'regions'), 12),
#  (('general', 'fund', 'support'), 12),
#  (('bloomingtonmonroe', 'county', 'metropolitan'), 12),
#  (('neighborhood', 'residential', 'street'), 12),
#  (('path', 'protected', 'bike'), 12),
#  (('description', 'capacity', 'expansion'), 12),
#  (('description', 'capital', 'assistance'), 12),
#  (('walnut', 'grove', 'walnut'), 12),
#  (('walnut', 'street', 'pike'), 12),
#  (('covenanter', 'covenanter', 'covenanter'), 12),
#  (('heatherwood', 'heatherwood', 'heatherwood'), 12),
#  (('meadowbrook', 'meadowbrook', 'meadowbrook'), 12),
#  (('olcott', 'olcott', 'olcott'), 12),
#  (('pleasant', 'ridge', 'pleasant'), 12),
#  (('ridge', 'pleasant', 'ridge'), 12),
#  (('skyline', 'skyline', 'skyline'), 12),
#  (('summit', 'view', 'summit'), 12),
#  (('view', 'summit', 'view'), 12),
#  (('tamarack', 'tamarack', 'tamarack'), 12),
#  (('willis', 'willis', 'willis'), 12),
#  (('wilson', 'wilson', 'wilson'), 12),
#  (('chapter', 'team', 'pursuit'), 12),
#  (('alta', 'planning', 'design'), 12),
#  (('number', 'type', 'silver'), 12),
#  (('action', 'status', 'level'), 12),
#  (('year', 'year', 'year'), 12),
#  (('payment', 'closing', 'cost'), 12),
#  (('closing', 'cost', 'assistance'), 12),
#  (('profit', 'organizations', 'provide'), 12),
#  (('heading', 'home', 'regional'), 12),
#  (('home', 'regional', 'plan'), 12),
#  (('regional', 'plan', 'make'), 12),
#  (('cost', 'burden', 'greater'), 12),
#  (('income', 'individuals', 'families'), 12),
#  (('total', 'project', 'based'), 12),
#  (('housing', 'market', 'analysis'), 12),
#  (('service', 'grant', 'program'), 12),
#  (('high', 'school', 'graduate'), 12),
#  (('government', 'industrial', 'residential'), 12),
#  (('industrial', 'residential', 'unknown'), 12),
#  (('city', 'city', 'mayor'), 11),
#  (('city', 'mayor', 'john'), 11),
#  (('john', 'hamilton', 'feedback'), 11),
#  (('hamilton', 'feedback', 'type'), 11),
#  (('sustainable', 'development', 'department'), 11),
#  (('morton', 'connect', 'facebook'), 11),
#  (('follow', 'twitter', 'city'), 11),
#  (('city', 'jobs', 'subscribe'), 11),
#  (('jobs', 'subscribe', 'email'), 11),
#  (('subscribe', 'email', 'lists'), 11),
#  (('policy', 'report', 'problem'), 11),
#  (('report', 'problem', 'city'), 11),
#  (('problem', 'city', 'intranet'), 11),
#  (('urban', 'village', 'center'), 11),
#  (('safe', 'efficient', 'accessible'), 11),
#  (('census', 'bureau', 'american'), 11),
#  (('county', 'convention', 'center'), 11),
#  (('urban', 'village', 'centers'), 11),
#  (('centers', 'disease', 'control'), 11),
#  (('bicycle', 'pedestrian', 'transportation'), 11),
#  (('motor', 'vehicle', 'traffic'), 11),
#  (('vehicle', 'miles', 'traveled'), 11),
#  (('used', 'development', 'approvals'), 11),
#  (('comprehensive', 'plan', 'chapter'), 11),
#  (('city', 'general', 'action'), 11),
#  (('general', 'action', 'expected'), 11),
#  (('action', 'expected', 'timeline'), 11),
#  (('expected', 'timeline', 'policy'), 11),
#  (('timeline', 'policy', 'lead'), 11),
#  (('policy', 'lead', 'department'), 11),
#  (('lead', 'department', 'short'), 11),
#  (('department', 'short', 'long'), 11),
#  (('short', 'long', 'ordinance'), 11),
#  (('long', 'ordinance', 'agency'), 11),
#  (('ordinance', 'agency', 'going'), 11),
#  (('agency', 'going', 'legislation'), 11),
#  (('ongoing', 'public', 'education'), 11),
#  (('public', 'education', 'outreach'), 11),
#  (('open', 'source', 'software'), 11),
#  (('hate', 'bias', 'crime'), 11),
#  (('past', 'five', 'years'), 11),
#  (('gauge', 'minimum', 'yield'), 11),
#  (('street', 'street', 'street'), 11),
#  (('suburban', 'connector', 'street'), 11),
#  (('bicycle', 'facility', 'type'), 11),
#  (('connector', 'general', 'urban'), 11),
#  (('neighborhood', 'greenway', 'protected'), 11),
#  (('greenway', 'protected', 'bike'), 11),
#  (('start', 'description', 'capital'), 11),
#  (('basswood', 'basswood', 'basswood'), 11),
#  (('davis', 'davis', 'davis'), 11),
#  (('pike', 'kinser', 'pike'), 11),
#  (('tamarron', 'tamarron', 'tamarron'), 11),
#  (('mitchell', 'mitchell', 'mitchell'), 11),
#  (('pete', 'ellis', 'pete'), 11),
#  (('ellis', 'pete', 'ellis'), 11),
#  (('platinum', 'bike', 'summit'), 11),
#  (('vulnerable', 'road', 'user'), 11),
#  (('platinum', 'task', 'force'), 11),
#  (('final', 'ndividual', 'time'), 11),
#  (('ndividual', 'time', 'trials'), 11),
#  (('agency', 'public', 'works'), 11),
#  (('estimated', 'capital', 'costs'), 11),
#  (('number', 'number', 'number'), 11),
#  (('home', 'investment', 'partnership'), 11),
#  (('affordable', 'rental', 'units'), 11),
#  (('program', 'general', 'fund'), 11),
#  (('individuals', 'families', 'families'), 11),
#  (('families', 'children', 'veterans'), 11),
#  (('section', 'plan', 'addressed'), 11),
#  (('plan', 'addressed', 'consultation'), 11),
#  (('consulted', 'anticipated', 'outcomes'), 11),
#  (('anticipated', 'outcomes', 'consultation'), 11),
#  (('outcomes', 'consultation', 'areas'), 11),
#  (('consultation', 'areas', 'improved'), 11),
#  (('areas', 'improved', 'coordination'), 11),
#  (('attached', 'attached', 'mailed'), 11),
#  (('municipal', 'code', 'title'), 11),
#  (('islander', 'hispanic', 'four'), 11),
#  (('project', 'based', 'tenant'), 11),
#  (('based', 'tenant', 'based'), 11),
#  (('developer', 'subsidy', 'owneroccupied'), 11),
#  (('existing', 'structures', 'infrastructure'), 11),
#  (('structures', 'infrastructure', 'improvements'), 11),
#  (('similar', 'action', 'recommended'), 11),
#  (('commercial', 'government', 'industrial'), 11),
#  (('residential', 'unknown', 'totals'), 11),
#  (('policy', 'decisions', 'comm'), 11),
#  (('ordinance', 'changes', 'comm'), 11),
#  (('comm', 'energystationary', 'comm'), 11),
#  (('feedback', 'type', 'news'), 10),
#  (('type', 'news', 'release'), 10),
#  (('information', 'please', 'contact'), 10),
#  (('related', 'categories', 'department'), 10),
#  (('twitter', 'city', 'jobs'), 10),
#  (('email', 'lists', 'policy'), 10),
#  (('lists', 'policy', 'report'), 10),
#  (('city', 'intranet', 'home'), 10),
#  (('utilities', 'service', 'board'), 10),
#  (('vision', 'statement', 'objectives'), 10),
#  (('bicycle', 'pedestrian', 'safety'), 10),
#  (('role', 'regional', 'economic'), 10),
#  (('tech', 'community', 'college'), 10),
#  (('monroe', 'county', 'convention'), 10),
#  (('development', 'department', 'hand'), 10),
#  (('regional', 'activity', 'center'), 10),
#  (('theme', 'used', 'development'), 10),
#  (('study', 'plan', 'interagency'), 10),
#  (('plan', 'interagency', 'coordination'), 10),
#  (('development', 'review', 'ongoing'), 10),
#  (('review', 'ongoing', 'public'), 10),
#  (('open', 'data', 'hate'), 10),
#  (('street', 'main', 'street'), 10),
#  (('street', 'general', 'urban'), 10),
#  (('description', 'capacity', 'preservation'), 10),
#  (('side', 'road', 'sidewalk'), 10),
#  (('multi‐', 'path', 'neighborhood'), 10),
#  (('path', 'neighborhood', 'greenway'), 10),
#  (('bell', 'trace', 'bell'), 10),
#  (('trace', 'bell', 'trace'), 10),
#  (('countryside', 'countryside', 'countryside'), 10),
#  (('polly', 'grimshaw', 'trail'), 10),
#  (('kinser', 'pike', 'kinser'), 10),
#  (('olcott', 'blvd', 'olcott'), 10),
#  (('palmer', 'palmer', 'palmer'), 10),
#  (('summit', 'summit', 'summit'), 10),
#  (('tapp', 'tapp', 'tapp'), 10),
#  (('woodburn', 'woodburn', 'woodburn'), 10),
#  (('relevant', 'sections', 'changes'), 10),
#  (('creating', 'affordable', 'housing'), 10),
#  (('planning', 'department', 'support'), 10),
#  (('year', 'estimated', 'costs'), 10),
#  (('final', 'chapter', 'team'), 10),
#  (('assist', 'profit', 'profit'), 10),
#  (('provide', 'technical', 'assistance'), 10),
#  (('existing', 'owneroccupied', 'structures'), 10),
#  (('provide', 'funding', 'make'), 10),
#  (('objective', 'create', 'opportunity'), 10),
#  (('development', 'affordable', 'housing'), 10),
#  (('mailed', 'survey', 'mailed'), 10),
#  (('survey', 'mailed', 'survey'), 10),
#  (('residential', 'rental', 'lodging'), 10),
#  (('rental', 'lodging', 'establishment'), 10),
#  (('lodging', 'establishment', 'inspection'), 10),
#  (('establishment', 'inspection', 'program'), 10),
#  (('renter', 'total', 'owner'), 10),
#  (('housing', 'problems', 'data'), 10),
#  (('problems', 'data', 'source'), 10),
#  (('households', 'area', 'median'), 10),
#  (('need', 'racial', 'ethnic'), 10),
#  (('veterans', 'family', 'disabled'), 10),
#  (('developer', 'subsidy', 'rental'), 10),
#  (('expected', 'amount', 'available'), 10),
#  (('service', 'delivery', 'system'), 10),
#  (('income', 'housing', 'benefit'), 10),
#  (('goal', 'description', 'goal'), 10),
#  (('description', 'goal', 'name'), 10),
#  (('govt', 'energystationary', 'buildings'), 10),
#  (('energystationary', 'buildings', 'facilities'), 10),
#  (('advocacy', 'info', 'info'), 10),
#  (('items', 'started', 'started'), 10),
#  (('intranet', 'home', 'login'), 9),
#  (('ensure', 'land', 'development'), 9),
#  (('development', 'activity', 'makes'), 9),
#  (('activity', 'makes', 'positive'), 9),
#  (('makes', 'positive', 'lasting'), 9),
#  (('positive', 'lasting', 'community'), 9),
#  (('lasting', 'community', 'contribution'), 9),
#  (('multimodal', 'transportation', 'system'), 9),
#  (('efficient', 'accessible', 'connected'), 9),
#  (('enhance', 'options', 'reduce'), 9),
#  (('options', 'reduce', 'overall'), 9),
#  (('reduce', 'overall', 'dependence'), 9),
#  (('local', 'food', 'production'), 9),
#  (('accessory', 'dwelling', 'units'), 9),
#  (('housing', 'supportive', 'services'), 9),
#  (('multimodal', 'transportation', 'planning'), 9),
#  (('survey', 'year', 'estimates'), 9),
#  (('pedestrian', 'bicycle', 'facilities'), 9),
#  (('following', 'provide', 'additional'), 9),
#  (('provide', 'additional', 'land'), 9),
#  (('additional', 'land', 'development'), 9),
#  (('land', 'development', 'policy'), 9),
#  (('development', 'policy', 'guidance'), 9),
#  (('development', 'redevelopment', 'projects'), 9),
#  (('going', 'legislation', 'study'), 9),
#  (('legislation', 'study', 'plan'), 9),
#  (('releasing', 'open', 'data'), 9),
#  (('data', 'hate', 'bias'), 9),
#  (('public', 'works', 'department'), 9),
#  (('cart', 'lifter', 'shall'), 9),
#  (('○', '○', '○'), 9),
#  (('bicycle', 'facility', 'types'), 9),
#  (('neighborhood', 'residential', 'streets'), 9),
#  (('neighborhood', 'connector', 'street'), 9),
#  (('street', 'parking', 'street'), 9),
#  (('improve', 'quality', 'life'), 9),
#  (('provide', 'neighborhood', 'greenway'), 9),
#  (('pathway', 'side', 'road'), 9),
#  (('cobble', 'creek', 'cobble'), 9),
#  (('creek', 'cobble', 'creek'), 9),
#  (('jefferson', 'jefferson', 'jefferson'), 9),
#  (('longview', 'longview', 'longview'), 9),
#  (('blvd', 'renwick', 'blvd'), 9),
#  (('grove', 'walnut', 'grove'), 9),
#  (('wintersweet', 'wintersweet', 'wintersweet'), 9),
#  (('wylie', 'farm', 'wylie'), 9),
#  (('farm', 'wylie', 'farm'), 9),
#  (('parks', 'recreation', 'department'), 9),
#  (('support', 'planning', 'department'), 9),
#  (('estimated', 'costs', 'lead'), 9),
#  (('affordable', 'housing', 'projects'), 9),
#  (('create', 'opportunity', 'development'), 9),
#  (('opportunity', 'development', 'affordable'), 9),
#  (('needs', 'homeless', 'persons'), 9),
#  (('citizen', 'advisory', 'council'), 9),
#  (('owner', 'total', 'table'), 9),
#  (('data', 'source', 'comments'), 9),
#  (('plan', 'control', 'public'), 9),
#  (('family', 'disabled', 'affairs'), 9),
#  (('disabled', 'affairs', 'unification'), 9),
#  (('supportive', 'program', 'housing'), 9),
#  (('children', 'veterans', 'families'), 9),
#  (('veterans', 'families', 'unaccompanied'), 9),
#  (('families', 'unaccompanied', 'youth'), 9),
#  (('interfaith', 'winter', 'shelter'), 9),
#  (('community', 'development', 'needs'), 9),
#  (('public', 'housing', 'units'), 9),
#  (('discussion', 'consolidated', 'plan'), 9),
#  (('housing', 'trust', 'fund'), 9),
#  (('direct', 'housing', 'assistance'), 9),
#  (('housing', 'assistance', 'owneroccupied'), 9),
#  (('department', 'environmental', 'management'), 9),
#  (('needs', 'addressed', 'affordable'), 9),
#  (('addressed', 'affordable', 'housing'), 9),
#  (('type', 'families', 'benefit'), 9),
#  (('families', 'benefit', 'proposed'), 9),
#  (('benefit', 'proposed', 'activities'), 9),
#  (('local', 'government', 'operations'), 9),
#  (('energy', 'emissions', 'inventory'), 9),
#  (('leed', 'cities', 'communities'), 8),
#  (('goals', 'policies', 'programs'), 8),
#  (('quality', 'life', 'residents'), 8),
#  (('enhance', 'community', 'role'), 8),
#  (('accessible', 'connected', 'system'), 8),
#  (('connected', 'system', 'transportation'), 8),
#  (('system', 'transportation', 'emphasizes'), 8),
#  (('transit', 'walking', 'biking'), 8),
#  (('environmental', 'action', 'plan'), 8),
#  (('locally', 'owned', 'businesses'), 8),
#  (('moderate', 'income', 'households'), 8),
#  (('community', 'survey', 'year'), 8),
#  (('accessible', 'safe', 'efficient'), 8),
#  (('pedestrian', 'bicycle', 'infrastructure'), 8),
#  (('parks', 'open', 'space'), 8),
#  (('redevelopment', 'projects', 'utilities'), 8),
#  (('projects', 'utilities', 'placed'), 8),
#  (('utilities', 'placed', 'underground'), 8),
#  (('located', 'minimize', 'potential'), 8),
#  (('minimize', 'potential', 'conflicts'), 8),
#  (('potential', 'conflicts', 'trees'), 8),
#  (('conflicts', 'trees', 'landscaping'), 8),
#  (('trees', 'landscaping', 'features'), 8),
#  (('short', 'parks', 'short'), 8),
#  (('short', 'going', 'going'), 8),
#  (('open', 'source', 'alliance'), 8),
#  (('source', 'alliance', 'innovation'), 8),
#  (('police', 'releasing', 'open'), 8),
#  (('students', 'working', 'cities'), 8),
#  (('working', 'cities', 'inventory'), 8),
#  (('cities', 'inventory', 'greenhouse'), 8),
#  (('inventory', 'greenhouse', 'emissions'), 8),
#  (('monroe', 'county', 'solid'), 8),
#  (('county', 'solid', 'waste'), 8),
#  (('federal', 'motor', 'carrier'), 8),
#  (('motor', 'carrier', 'safety'), 8),
#  (('unit', 'shall', 'delivered'), 8),
#  (('shall', 'less', 'five'), 8),
#  (('less', 'five', 'years'), 8),
#  (('national', 'association', 'city'), 8),
#  (('association', 'city', 'transportation'), 8),
#  (('city', 'transportation', 'officials'), 8),
#  (('pedestrian', 'activity', 'bike'), 8),
#  (('activity', 'bike', 'traffic'), 8),
#  (('volumes', 'autos', 'transit'), 8),
#  (('main', 'street', 'general'), 8),
#  (('street', 'neighborhood', 'residential'), 8),
#  (('provide', 'street', 'grid'), 8),
#  (('street', 'grid', 'part'), 8),
#  (('grid', 'part', 'future'), 8),
#  (('part', 'future', 'redevelopment'), 8),
#  (('future', 'redevelopment', 'area'), 8),
#  (('redevelopment', 'area', 'grid'), 8),
#  (('area', 'grid', 'established'), 8),
#  (('grid', 'established', 'block'), 8),
#  (('established', 'block', 'length'), 8),
#  (('multiuse', 'path', 'bike'), 8),
#  (('arlington', 'arlington', 'arlington'), 8),
#  (('brighton', 'brighton', 'brighton'), 8),
#  (('clark', 'clark', 'clark'), 8),
#  (('patterson', 'patterson', 'patterson'), 8),
#  (('grimes', 'grimes', 'grimes'), 8),
#  (('heather', 'heather', 'heather'), 8),
#  (('illinois', 'illinois', 'illinois'), 8),
#  (('miller', 'miller', 'miller'), 8),
#  (('renwick', 'blvd', 'renwick'), 8),
#  (('overhill', 'overhill', 'overhill'), 8),
#  (('southern', 'oaks', 'southern'), 8),
#  (('valley', 'forge', 'valley'), 8),
#  (('forge', 'valley', 'forge'), 8),
#  (('woodside', 'woodside', 'woodside'), 8),
#  (('monroe', 'county', 'public'), 8),
#  (('county', 'public', 'library'), 8),
#  (('sunday', 'open', 'streets'), 8),
#  (('costs', 'none', 'minim'), 8),
#  (('status', 'level', 'encouragement'), 8),
#  (('objective', 'provide', 'financial'), 8),
#  (('affordable', 'senior', 'housing'), 8),
#  (('resource', 'officers', 'street'), 8),
#  (('officers', 'street', 'social'), 8),
#  (('particularly', 'chronically', 'homeless'), 8),
#  (('mailed', 'survey', 'attached'), 8),
#  (('years', 'consolidated', 'plan'), 8),
#  (('hamfi', 'hamfi', 'hamfi'), 8),
#  (('complete', 'plumbing', 'kitchen'), 8),
#  (('plumbing', 'kitchen', 'facilities'), 8),
#  (('need', 'housing', 'assistance'), 8),
#  (('gross', 'monthly', 'income'), 8),
#  (('monthly', 'income', 'housing'), 8),
#  (('plan', 'control', 'disproportionately'), 8),
#  (('control', 'disproportionately', 'greater'), 8),
#  (('greater', 'need', 'housing'), 8),
#  (('ethnic', 'group', 'disproportionately'), 8),
#  (('group', 'disproportionately', 'greater'), 8),
#  (('median', 'income', 'housing'), 8),
#  (('income', 'housing', 'problems'), 8),
#  (('problems', 'table', 'disproportionally'), 8),
#  (('table', 'disproportionally', 'greater'), 8),
#  (('disproportionally', 'greater', 'need'), 8),
#  (('greater', 'need', 'data'), 8),
#  (('need', 'data', 'source'), 8),
#  (('chas', 'four', 'housing'), 8),
#  (('plumbing', 'facilities', 'person'), 8),
#  (('facilities', 'person', 'room'), 8),
#  (('person', 'room', 'cost'), 8),
#  (('plan', 'control', 'four'), 8),
#  (('median', 'income', 'severe'), 8),
#  (('income', 'severe', 'housing'), 8),
#  (('problems', 'table', 'severe'), 8),
#  (('table', 'severe', 'housing'), 8),
#  (('four', 'severe', 'housing'), 8),
#  (('plumbing', 'facilities', 'persons'), 8),
#  (('facilities', 'persons', 'room'), 8),
#  (('persons', 'room', 'cost'), 8),
#  (('public', 'housing', 'program'), 8),
#  (('housing', 'program', 'type'), 8),
#  (('affairs', 'unification', 'supportive'), 8),
#  (('unification', 'supportive', 'program'), 8),
#  (('includes', 'elderly', 'disabled'), 8),
#  (('elderly', 'disabled', 'mainstream'), 8),
#  (('disabled', 'mainstream', 'year'), 8),
#  (('mainstream', 'year', 'mainstream'), 8),
#  (('year', 'mainstream', 'fiveyear'), 8),
#  (('mainstream', 'fiveyear', 'nursing'), 8),
#  (('fiveyear', 'nursing', 'home'), 8),
#  (('nursing', 'home', 'transition'), 8),
#  (('plan', 'control', 'homeless'), 8),
#  (('bedroom', 'bedroom', 'bedroom'), 8),
#  (('lead', 'based', 'paint'), 8),
#  (('targeted', 'homeless', 'persons'), 8),
#  (('insufficient', 'financial', 'resources'), 8),
#  (('bill', 'bill', 'proposes'), 8),
#  (('bill', 'proposes', 'amending'), 8),
#  (('proposes', 'amending', 'follows'), 8),
#  (('educational', 'attainment', 'less'), 8),
#  (('affordable', 'housing', 'citywide'), 8),
#  (('community', 'development', 'citywide'), 8),
#  (('household', 'housing', 'unit'), 8),
#  (('activities', 'moderate', 'income'), 8),
#  (('moderate', 'income', 'housing'), 8),
#  (('valign', 'width', 'aligncenter'), 8),
#  (('width', 'aligncenter', 'valign'), 8),
#  (('aligncenter', 'valign', 'width'), 8),
#  (('city', 'utilities', 'water'), 8),
#  (('thinking', 'policy', 'decisions'), 8),
#  (('energytransport', 'transportation', 'defending'), 8),
#  (('sheltered', 'unsheltered', 'optional'), 8),
#  (('hand', 'program', 'manager'), 8),
#  (('said', 'mayor', 'john'), 7),
#  (('comprehensive', 'plan', 'city'), 7),
#  (('common', 'council', 'current'), 7),
#  (('greater', 'chamber', 'commerce'), 7),
#  (('pedestrian', 'safety', 'commission'), 7),
#  (('plan', 'comprehensive', 'plan'), 7),
#  (('adopted', 'vision', 'statement'), 7),
#  (('encourage', 'healthy', 'lifestyles'), 7),
#  (('healthy', 'lifestyles', 'providing'), 7),
#  (('lifestyles', 'providing', 'high'), 7),
#  (('providing', 'high', 'quality'), 7),
#  (('high', 'quality', 'public'), 7),
#  (('quality', 'public', 'places'), 7),
#  (('parks', 'array', 'recreational'), 7),
#  (('array', 'recreational', 'activities'), 7),
#  (('recreational', 'activities', 'events'), 7),
#  (('public', 'transit', 'walking'), 7),
#  (('overall', 'dependence', 'automobile'), 7),
#  (('bureau', 'american', 'community'), 7),
#  (('wastewater', 'treatment', 'plant'), 7),
#  (('climate', 'protection', 'agreement'), 7),
#  (('action', 'plan', 'city'), 7),
#  (('monroe', 'county', 'energy'), 7),
#  (('tree', 'canopy', 'coverage'), 7),
#  (('vision', 'infill', 'strategy'), 7),
#  (('infill', 'strategy', 'plan'), 7),
#  (('units', 'within', 'city'), 7),
#  (('median', 'household', 'income'), 7),
#  (('center', 'disease', 'control'), 7),
#  (('motor', 'vehicle', 'speeds'), 7),
#  (('parking', 'street', 'trees'), 7),
#  (('update', 'unified', 'development'), 7),
#  (('development', 'approvals', 'following'), 7),
#  (('approvals', 'following', 'provide'), 7),
#  (('underlying', 'land', 'district'), 7),
#  (('land', 'district', 'designations'), 7),
#  (('district', 'designations', 'within'), 7),
#  (('designations', 'within', 'chapter'), 7),
#  (('within', 'chapter', 'apply'), 7),
#  (('dunn', 'grant', 'lincoln'), 7),
#  (('interagency', 'coordination', 'development'), 7),
#  (('coordination', 'development', 'review'), 7),
#  (('going', 'short', 'short'), 7),
#  (('hand', 'short', 'hand'), 7),
#  (('short', 'hand', 'short'), 7),
#  (('going', 'going', 'short'), 7),
#  (('short', 'short', 'going'), 7),
#  (('bias', 'crime', 'daily'), 7),
#  (('crime', 'daily', 'student'), 7),
#  (('digital', 'cities', 'survey'), 7),
#  (('greenhouse', 'emissions', 'news'), 7),
#  (('emissions', 'news', 'university'), 7),
#  (('city', 'community', 'foundation'), 7),
#  (('signed', 'letter', 'intent'), 7),
#  (('solid', 'waste', 'management'), 7),
#  (('waste', 'management', 'district'), 7),
#  (('large', 'item', 'appliance'), 7),
#  (('shall', 'minimum', 'gauge'), 7),
#  (('minimum', 'gauge', 'minimum'), 7),
#  (('pedestrian', 'transportation', 'greenways'), 7),
#  (('transportation', 'greenways', 'system'), 7),
#  (('greenways', 'system', 'plan'), 7),
#  (('planning', 'public', 'works'), 7),
#  (('street', 'typical', 'crosssection'), 7),
#  (('center', 'turn', 'lane'), 7),
#  (('sidewalks', 'bike', 'lanes'), 7),
#  (('shared', 'street', 'neighborhood'), 7),
#  (('bike', 'lanes', 'provide'), 7),
#  (('conventional', 'bike', 'lanes'), 7),
#  (('bicycle', 'facility', 'selection'), 7),
#  (('neighborhood', 'residential', 'extension'), 7),
#  (('path', 'bike', 'lanes'), 7),
#  (('provide', 'multiuse', 'path'), 7),
#  (('capacity', 'expansion', 'road'), 7),
#  (('description', 'trailmotorized', 'multiuse'), 7),
#  (('karst', 'farm', 'greenway'), 7),
#  (('multi‐', 'path', 'protected'), 7),
#  (('ashwood', 'ashwood', 'ashwood'), 7),
#  (('ballantine', 'ballantine', 'ballantine'), 7),
#  (('walnut', 'state', 'road'), 7),
#  (('curry', 'curry', 'curry'), 7),
#  (('longwood', 'longwood', 'longwood'), 7),
#  (('moss', 'creek', 'moss'), 7),
#  (('creek', 'moss', 'creek'), 7),
#  (('rechter', 'rechter', 'rechter'), 7),
#  (('sugar', 'maple', 'sugar'), 7),
#  (('maple', 'sugar', 'maple'), 7),
#  (('twin', 'oaks', 'twin'), 7),
#  (('oaks', 'twin', 'oaks'), 7),
#  (('walker', 'walker', 'walker'), 7),
#  (('winding', 'winding', 'winding'), 7),
#  (('education', 'encouragement', 'enforcement'), 7),
#  (('redefining', 'prosperity', 'report'), 7),
#  (('city', 'planning', 'department'), 7),
#  (('final', 'qualifications', 'platinum'), 7),
#  (('niple', 'alta', 'planning'), 7),
#  (('lead', 'agency', 'parks'), 7),
#  (('agency', 'parks', 'recreation'), 7),
#  (('agency', 'monroe', 'county'), 7),
#  (('capital', 'costs', 'lead'), 7),
#  (('none', 'none', 'none'), 7),
#  (('parks', 'recreation', 'depar'), 7),
#  (('none', 'minim', 'costs'), 7),
#  (('trips', 'work', 'bike'), 7),
#  (('needs', 'assessment', 'overview'), 7),
#  (('increase', 'number', 'affordable'), 7),
#  (('number', 'affordable', 'housing'), 7),
#  (('energy', 'efficiency', 'upgrades'), 7),
#  (('efficiency', 'upgrades', 'accessibility'), 7),
#  (('upgrades', 'accessibility', 'modifications'), 7),
#  (('make', 'accessibility', 'modifications'), 7),
#  (('profit', 'organizations', 'serve'), 7),
#  (('organizations', 'serve', 'income'), 7),
#  (('food', 'shelter', 'health'), 7),
#  (('shelter', 'health', 'care'), 7),
#  (('services', 'improve', 'quality'), 7),
#  (('home', 'buyer', 'club'), 7),
#  (('rental', 'assistance', 'tbra'), 7),
#  (('service', 'community', 'assessment'), 7),
#  (('hope', 'family', 'shelter'), 7),
#  (('survey', 'attached', 'attached'), 7),
#  (('housing', 'needs', 'assessment'), 7),
#  (('number', 'housing', 'units'), 7),
#  (('control', 'four', 'housing'), 7),
#  (('chas', 'four', 'severe'), 7),
#  (('control', 'public', 'housing'), 7),
#  (('data', 'source', 'name'), 7),
#  (('mother', 'hubbard', 'cupboard'), 7),
#  (('rental', 'inspection', 'program'), 7),
#  (('special', 'needs', 'facilities'), 7),
#  (('needs', 'facilities', 'services'), 7),
#  (('influence', 'market', 'conditions'), 7),
#  (('citywide', 'affordable', 'housing'), 7),
#  (('public', 'facility', 'infrastructure'), 7),
#  (('facility', 'infrastructure', 'activities'), 7),
#  (('target', 'area', 'citywide'), 7),
#  (('area', 'citywide', 'goals'), 7),
#  (('citywide', 'goals', 'supported'), 7),
#  (('target', 'date', 'estimate'), 7),
#  (('date', 'estimate', 'number'), 7),
#  (('description', 'funds', 'used'), 7),
#  (('action', 'recommended', 'environmental'), 7),
#  (('recommended', 'environmental', 'quality'), 7),
#  (('environmental', 'quality', 'natural'), 7),
#  (('quality', 'natural', 'systems'), 7),
#  (('natural', 'systems', 'working'), 7),
#  (('systems', 'working', 'group'), 7),
#  (('working', 'group', 'discussions'), 7),
#  (('reduce', 'energy', 'consumption'), 7),
#  (('responsible', 'party', 'time'), 7),
#  (('party', 'time', 'frame'), 7),
#  (('change', 'usage', 'previous'), 7),
#  (('usage', 'previous', 'year'), 7),
#  (('previous', 'year', 'total'), 7),
#  (('total', 'cost', 'cost'), 7),
#  (('campaigns', 'comm', 'energytransport'), 7),
#  (('infrastructure', 'govt', 'energystationary'), 7),
#  (('govt', 'energytransport', 'govt'), 7),
#  (('energytransport', 'govt', 'transport'), 7),
#  (('changes', 'comm', 'energystationary'), 7),
#  (('energystationary', 'comm', 'started'), 7),
#  (('started', 'started', 'policy'), 7),
#  (('started', 'policy', 'decisions'), 7),
#  (('green', 'building', 'council'), 6),
#  (('suite', 'connect', 'facebook'), 6),
#  (('overall', 'chapter', 'supports'), 6),
#  (('chapter', 'supports', 'following'), 6),
#  (('supports', 'following', 'vision'), 6),
#  (('offer', 'wide', 'variety'), 6),
#  (('flourishing', 'center', 'community'), 6),
#  (('provide', 'safe', 'efficient'), 6),
#  (('transportation', 'emphasizes', 'public'), 6),
#  (('emphasizes', 'public', 'transit'), 6),
#  (('walking', 'biking', 'enhance'), 6),
#  (('biking', 'enhance', 'options'), 6),
#  (('existing', 'housing', 'stock'), 6),
#  (('affordable', 'housing', 'stock'), 6),
#  (('goals', 'policies', 'policies'), 6),
#  (('policies', 'policies', 'chapter'), 6),
#  (('policies', 'chapter', 'closely'), 6),
#  (('chapter', 'closely', 'respond'), 6),
#  (('closely', 'respond', 'adopted'), 6),
#  (('respond', 'adopted', 'vision'), 6),
#  (('policies', 'chapter', 'also'), 6),
#  (('chapter', 'also', 'respond'), 6),
#  (('also', 'respond', 'following'), 6),
#  (('respond', 'following', 'vision'), 6),
#  (('meet', 'needs', 'community'), 6),
#  (('education', 'health', 'care'), 6),
#  (('city', 'department', 'economic'), 6),
#  (('enhance', 'quality', 'life'), 6),
#  (('outcomes', 'indicators', 'outcome'), 6),
#  (('county', 'comprehensive', 'plan'), 6),
#  (('health', 'care', 'services'), 6),
#  (('county', 'energy', 'challenge'), 6),
#  (('vision', 'statement', 'objective'), 6),
#  (('best', 'management', 'practices'), 6),
#  (('residences', 'businesses', 'city'), 6),
#  (('persons', 'experiencing', 'homelessness'), 6),
#  (('downtown', 'vision', 'infill'), 6),
#  (('economic', 'development', 'tool'), 6),
#  (('housing', 'choice', 'vouchers'), 6),
#  (('housing', 'transportation', 'affordability'), 6),
#  (('surrounding', 'land', 'uses'), 6),
#  (('people', 'ages', 'abilities'), 6),
#  (('architectural', 'site', 'design'), 6),
#  (('placed', 'underground', 'feasible'), 6),
#  (('underground', 'feasible', 'located'), 6),
#  (('feasible', 'located', 'minimize'), 6),
#  (('development', 'theme', 'approvals'), 6),
#  (('utilize', 'underlying', 'land'), 6),
#  (('short', 'short', 'parks'), 6),
#  (('short', 'short', 'hand'), 6),
#  (('eyes', 'switch', 'smart'), 6),
#  (('switch', 'smart', 'water'), 6),
#  (('\uf053', '\uf0d5', '\uf0d2'), 6),
#  (('\uf017', 'june', 'general'), 6),
#  (('june', 'general', 'news'), 6),
#  (('contact', 'join', 'search'), 6),
#  (('open', 'data', 'challenge'), 6),
#  (('cities', 'survey', 'winners'), 6),
#  (('city', 'bedc', 'chamber'), 6),
#  (('community', 'foundation', 'receive'), 6),
#  (('foundation', 'receive', 'partners'), 6),
#  (('receive', 'partners', 'places'), 6),
#  (('partners', 'places', 'grant'), 6),
#  (('places', 'grant', 'support'), 6),
#  (('grant', 'support', 'energy'), 6),
#  (('support', 'energy', 'challenge'), 6),
#  (('jacqui', 'bauer', 'sustainability'), 6),
#  (('bauer', 'sustainability', 'coordinator'), 6),
#  (('sustainability', 'coordinator', 'city'), 6),
#  (('support', 'monroe', 'county'), 6),
#  (('launch', 'dockless', 'bike'), 6),
#  (('mayor', 'hamilton', 'announces'), 6),
#  (('hamilton', 'announces', 'signed'), 6),
#  (('announces', 'signed', 'letter'), 6),
#  (('letter', 'intent', 'axia'), 6),
#  (('intent', 'axia', 'gigabitclass'), 6),
#  (('axia', 'gigabitclass', 'broadband'), 6),
#  (('sanitation', 'modernization', 'advisory'), 6),
#  (('modernization', 'advisory', 'committee'), 6),
#  (('public', 'works', 'city'), 6),
#  (('shelby', 'walker', 'director'), 6),
#  (('walker', 'director', 'sanitation'), 6),
#  (('member', 'city', 'common'), 6),
#  (('council', 'current', 'utilities'), 6),
#  (('current', 'utilities', 'service'), 6),
#  (('service', 'board', 'member'), 6),
#  (('waste', 'industry', 'trash'), 6),
#  (('industry', 'trash', 'service'), 6),
#  (('mcglasson', 'executive', 'director'), 6),
#  (('executive', 'director', 'monroe'), 6),
#  (('director', 'monroe', 'county'), 6),
#  (('fixed', 'capital', 'recovery'), 6),
#  (('solid', 'waste', 'recycling'), 6),
#  (('yard', 'waste', 'collection'), 6),
#  (('gallon', 'solid', 'waste'), 6),
#  (('solid', 'waste', 'cart'), 6),
#  (('waste', 'cart', 'range'), 6),
#  (('total', 'monthly', 'charge'), 6),
#  (('mounted', 'left', 'hand'), 6),
#  (('rear', 'brakes', 'shall'), 6),
#  (('shall', 'comply', 'federal'), 6),
#  (('comply', 'federal', 'motor'), 6),
#  (('carrier', 'safety', 'regulations'), 6),
#  (('subpart', 'emergency', 'equipment'), 6),
#  (('wear', 'thick', 'wide'), 6),
#  (('fire', 'department', 'operations'), 6),
#  (('college', 'mall', 'road'), 6),
#  (('city', 'transportation', 'network'), 6),
#  (('street', 'atwater', 'avenue'), 6),
#  (('campus', 'master', 'plan'), 6),
#  (('university', 'master', 'plan'), 6),
#  (('walking', 'biking', 'routes'), 6),
#  (('average', 'daily', 'traffic'), 6),
#  (('goals', 'comprehensive', 'plan'), 6),
#  (('street', 'grid', 'network'), 6),
#  ...]

# %%
trigram_frequency_pd = pd.DataFrame(trigram_frequency, columns=['counts', 'words'])
trigram_frequency_pd = trigram_frequency_pd[['words','counts']]

# %% [markdown]
# ### Section 8: print everyting into Excel tab named with the name of the city

# %% [markdown]
# ##### 1) create a new tab named with the city name

# %%
f = 'Bloomington-Frequency.xlsx'

# %%
wb2 = load_workbook(f)
wb2.create_sheet()
wb2.save(f)

# %% [markdown]
# ##### 2) save the Dataframes in this tab

# %%
writer = pd.ExcelWriter(f,engine='xlsxwriter') 
workbook=writer.book
unigram_frequency_pd.to_excel(writer,startrow=0 , startcol=0, header=True)
bigram_frequency_pd.to_excel(writer,startrow=0 , startcol=4, header=True)
trigram_frequency_pd.to_excel(writer,startrow=0 , startcol=8, header=True)
nouns_frequency_pd.to_excel(writer,startrow=0 , startcol=12, header=True)
verbs_frequency_pd.to_excel(writer,startrow=0 , startcol=16, header=True)
adjs_frequency_pd.to_excel(writer,startrow=0 , startcol=20, header=True)
writer.save()
workbook.close()
